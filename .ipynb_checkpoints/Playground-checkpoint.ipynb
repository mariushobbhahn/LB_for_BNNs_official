# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.tri as tri
import matplotlib 
import math
from functools import reduce
from math import gamma
from operator import mul
from scipy.special import loggamma
from scipy.stats import dirichlet, multivariate_normal

import torch
#import tikzplotlib

# %% [markdown]
# # Define calculations and plottings tools

# %%
from scipy.special import gammaln, xlogy

corners = np.array([[0, 0], [1, 0], [0.5, 0.75**0.5]])
triangle = tri.Triangulation(corners[:, 0], corners[:, 1])

refiner = tri.UniformTriRefiner(triangle)
trimesh = refiner.refine_triangulation(subdiv=4)


midpoints = [(corners[(i + 1) % 3] + corners[(i + 2) % 3]) / 2.0 \
             for i in range(3)]
def xy2bc(xy, tol=1.e-3):
    '''Converts 2D Cartesian coordinates to barycentric.'''
    s = [(corners[i] - midpoints[i]).dot(xy - midpoints[i]) / 0.75 \
         for i in range(3)]
    return np.clip(s, tol, 1.0 - tol)


def softmax_transform(a):
    x = np.exp(a)/np.sum(np.exp(a))
    return(x)

def beta_function(alpha):
    return(np.exp(np.sum([loggamma(a_i) for a_i in alpha]) - loggamma(np.sum(alpha))))    

class Dirichlet(object):
    def __init__(self, alpha):
        self._alpha = np.array(alpha)
        self._coef = np.sum(gammaln(alpha)) - gammaln(np.sum(alpha))    
        
    def pdf(self, x):
        '''Returns pdf value for `x`.'''
        return(np.exp(- self._coef+ np.sum((xlogy(self._alpha-1, x.T)).T, 0)))
    
class Normal3D(object):
    
    def __init__(self, mu, Sigma):
        self.mu = np.array(mu)
        self.Sigma = np.array(Sigma)
        self.const = 1 / (np.sqrt((2*np.pi)**3 * np.linalg.det(Sigma)))
        
    def pdf(self, x):
        """Calculate 3D Gaussian"""
        y = self.const * np.exp(-0.5 * (x - self.mu).T @ self.Sigma @ (x - self.mu))
        return(y)
    
class logitNormal3D(object):
    
    def __init__(self, mu, Sigma):
        self.mu = np.array(mu)
        self.Sigma = np.array(Sigma)
        self.const = 1/ (np.sqrt(np.linalg.det(2 * np.pi * self.Sigma)))
        
    def pdf(self, x):
        part_one = self.const / np.prod(x)
        logistic = logistic_transform(x)
        part_two = np.exp(-0.5*(logistic - self.mu).T @ self.Sigma @ (logistic - self.mu))
        y = part_one * part_two
        return(y)

def draw_pdf_contours(dist, nlevels=200, subdiv=5, **kwargs):

    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    pvals = [dist.pdf(xy2bc(xy)) for xy in zip(trimesh.x, trimesh.y)]
    xys = [xy2bc(xy) for xy in zip(trimesh.x, trimesh.y)]
    #print(len(pvals))
    #print(xys)
    print(len(xys))

    plt.tricontourf(trimesh, pvals, nlevels, **kwargs)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    
draw_pdf_contours(Dirichlet([5, 5, 5]))
# Out:
# 561

# %%
def argmin_norm(sample, positions):
    return(np.argmin(np.sum(np.square(sample - positions), axis=1)))

def sample_dirichlet_contours(alpha, nlevels=200, subdiv=5, num_samples=100000, **kwargs):

    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    xys = np.array([xy2bc(xy) for xy in zip(trimesh.x, trimesh.y)])
    dirichlet_samples = dirichlet.rvs(alpha, size=num_samples)
    counts = np.zeros(len(xys))
    for x in dirichlet_samples:
        counts[argmin_norm(x, xys)] += 1
    
    pvals = counts/num_samples

    plt.tricontourf(trimesh, pvals, nlevels, **kwargs)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.show()
    
def sample_Normal_contours(mu, sigma, nlevels=200, subdiv=5, num_samples=100000, **kwargs):

    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    xys = np.array([xy2bc(xy) for xy in zip(trimesh.x, trimesh.y)])
    gaussian_samples = multivariate_normal.rvs(mean=mu, cov=sigma, size=num_samples)
    softmax_gaussian_samples = np.array([softmax_transform(x) for x in gaussian_samples])
    counts = np.zeros(len(xys))
    for x in softmax_gaussian_samples:
        counts[argmin_norm(x, xys)] += 1
    
    pvals = counts/num_samples

    plt.tricontourf(trimesh, pvals, nlevels, **kwargs)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.show()
    
sample_dirichlet_contours(np.array([5, 5, 5]))
sample_Normal_contours(np.array([-1, 2, -1]), 0.1*np.eye(3))

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %%
new_cool = cm.get_cmap('cool', 256)
new_cool = new_cool(np.linspace(0.3,1 ,256))
new_cool = ListedColormap(new_cool, name='new_cool')

# %%
new_coolwarm = cm.get_cmap('coolwarm', 256)
new_coolwarm = new_coolwarm(np.linspace(0.35,0.95,256))
new_coolwarm = ListedColormap(new_coolwarm, name='new_coolwarm')

# %%
new_bupu = cm.get_cmap('BuPu', 256)
new_bupu = new_bupu(np.linspace(0.4,1 ,256))
new_bupu = ListedColormap(new_bupu, name='new_bupu')

# %%
#test the transformations from Gaussian to Dirichlet and back

def get_mu_from_Dirichlet(alpha):
    K = len(alpha)
    mu = []
    for i in range(K):
        mu_i = np.log(alpha[i]) - 1/K * np.sum(np.log(alpha))
        mu.append(mu_i)
        
    return(np.array(mu))

def sigma_regularizer(Sigma):
    
    Sigma_new = np.zeros(np.shape(Sigma))
    n = len(Sigma[0])
    for i in range(n):
        for j in range(n):
            Sigma_new[i][j] = Sigma[i][j]  - Sigma[i] @ Sigma[:,j] * 1/Sigma.sum()
        
    return(Sigma_new)

def get_Sigma_from_Dirichlet(alpha):
    K = len(alpha)
    sum_of_inv = 1/K * np.sum(1/np.array(alpha))
    Sigma = np.zeros((K,K))
    for k in range(K):
        for l in range(K):
            delta = 1 if k==l else 0
            Sigma[k][l] = delta * 1/alpha[k] - 1/K*(1/alpha[k] + 1/alpha[l] - sum_of_inv)
            
    return(Sigma)

def correct_mu(mu, Sigma):
    return(mu - Sigma.sum(0) * mu.sum() / Sigma.sum())

def correct_Sigma(mu, Sigma):
    return(Sigma - np.outer(Sigma.sum(0), Sigma.sum(1)) / Sigma.sum())



def get_alpha_from_Normal(mu, Sigma):
    alpha = []
    K = len(Sigma[0])
    sum_exp = np.sum(np.exp(-1*np.array(mu)))
    for k in range(K):
        alpha.append(1/Sigma[k][k]*(1 - 2/K + np.exp(mu[k])/K**2 * sum_exp))
        
    return(np.array(alpha))

def get_alpha_from_Normal2(mu, Sigma):
    alpha = []
    K = len(Sigma[0])
    sum_exp = np.sum(np.exp(-1*np.array(mu)))
    for k in range(K):
        alpha.append(1/Sigma[k][k]*(1 - 2/K + np.max([np.log(np.exp(mu[k])/K**2), 0.01]) * sum_exp))
        
    return(np.array(alpha))

def get_alpha_from_Normal_full(mu, Sigma):
    K = len(Sigma[0])
    alpha = np.zeros(K)
    sum_exp = np.sum(np.exp(-np.array(mu)))
    for k in range(K):
        for l in range(K):
            core = (1/K + np.exp(mu[k] - mu[l])/K) + np.exp(mu[k])/K**2 * sum_exp
            if l == k:
                alpha[k] += 1/Sigma[k][l] * (1 - 1/K - np.exp(mu[k] - mu[l])/K + np.exp(mu[k])/K**2 * sum_exp)
            elif Sigma[k][l] != 0:
                alpha[k] += 1/Sigma[k][l] * (-1/K - np.exp(mu[k] - mu[l])/K + np.exp(mu[k])/K**2 * sum_exp)
                
    #correct for K
    alpha/= K
        
    return(alpha)

def get_alpha_from_Normal_dissect(mu, Sigma):
    alpha = []
    K = len(Sigma[0])
    sum_exp = np.sum(np.exp(-np.array(mu)))
    print("sum_exp: ", sum_exp)
    for k in range(K):
        print("Sigma[k][k]: ", Sigma[k][k])
        print("np.exp(mu[k])/K**2 * sum_exp: ", np.exp(mu[k])/K**2 * sum_exp)
        alpha.append(1/Sigma[k][k]*(1 - 2/K + np.exp(mu[k])/K**2 * sum_exp))
        
    return(np.array(alpha))

def get_alpha_from_Normal_batch(mu, Sigma):
    mu, Sigma = torch.from_numpy(mu), torch.from_numpy(Sigma)
    batch_size, K = mu.size(0), mu.size(-1)
    Sigma_d = torch.diagonal(Sigma, dim1=1, dim2=2)
    sum_exp = torch.sum(torch.exp(-1*torch.Tensor(mu)), dim=1).view(-1,1)
    alpha = 1/Sigma_d * (1 - 2/K + torch.exp(mu)/K**2 * sum_exp)
    
    assert(alpha.size() == mu.size())
    
    return(alpha)

def alphas_norm(alphas):
    alphas = np.array(alphas)
    return(alphas/alphas.sum(axis=1).reshape(-1,1))

def alphas_variance(alphas):
    alphas = np.array(alphas)
    norm = alphas_norm(alphas)
    nom = norm * (1 - norm)
    den = alphas.sum(axis=1).reshape(-1,1) + 1
    return(nom/den)

def get_norm_variance_alphas(alphas):
    eps=10e-20
    a = np.array(alphas)
    a /= (np.sqrt(alphas_variance(a)) + eps)
    #a /= a.sum(1).reshape(-1,1)
    return(a)

def get_alphas_mS_batch(mu, Sigma):
    
    n = mu.size(0)
    alphas = torch.zeros(n, mu.size(1))
    for i in range(n):
        alphas[i] = get_alphas_from_mS(mu[i], Sigma[i])
        
    return(alphas)

from scipy.special import digamma, polygamma

alpha_test = np.array([1.3, 1.3, 1.6])
print("alpha start: ", alpha_test)
mu_test = get_mu_from_Dirichlet(alpha_test)
print("mu: ", mu_test)
Sigma_test = get_Sigma_from_Dirichlet(alpha_test)
print("Sigma: ", Sigma_test)
alpha_end = get_alpha_from_Normal(mu_test, Sigma_test)
print("alpha end: ", alpha_end)
alpha_end_full = get_alpha_from_Normal_full(mu_test, Sigma_test)
print("alpha end full: ", alpha_end_full)
# Out:
# alpha start:  [1.3 1.3 1.6]
# mu:  [-0.06921312 -0.06921312  0.13842624]
# Sigma:  [[ 0.49679487 -0.2724359  -0.22435897]
#  [-0.2724359   0.49679487 -0.22435897]
#  [-0.22435897 -0.22435897  0.44871795]]
# alpha end:  [1.3 1.3 1.6]
# alpha end full:  [1.3 1.3 1.6]

# %%
# check Agustinus condition from paper
def condition(alpha):
    alpha_sum = alpha.sum()
    alpha_sum_not_l = alpha_sum - alpha
    rhs = 1/4 * (np.sqrt(9* alpha_sum_not_l**2 + 10 * alpha_sum_not_l + 1) - alpha_sum_not_l + 1)
    return(alpha > rhs)

# %%
def correct_alpha(alpha, kappa):
    K = len(alpha)
    log_a_c = np.log(alpha) - kappa * (np.log(alpha) - 1/K * np.log(alpha).sum())
    return(np.exp(log_a_c))

# %%
mu_test1 = np.array([-1,-2,1])
#Sigma_test1 = np.eye(3)
Sigma_test1 = np.array([[1,     -0.3, -0.5],
                        [-0.3,     2, -0.3],
                        [-0.5, -0.3, 0.5]])
mu_test1 = correct_mu(mu_test1, Sigma_test1)
Sigma_test1 = correct_Sigma(mu_test1, Sigma_test1)
print("mu_test1: ", mu_test1)
print("Sigma_test1: ", Sigma_test1)
alpha_test1 = get_alpha_from_Normal(mu_test1, Sigma_test1)
alpha_test1_full = get_alpha_from_Normal_full(mu_test1, Sigma_test1)

print(alpha_test1)
print(alpha_test1_full)
print(condition(alpha_test1))
# Out:
# mu_test1:  [-0.69230769  0.15384615  0.53846154]
# Sigma_test1:  [[ 0.96923077 -0.51538462 -0.45384615]
#  [-0.51538462  0.49230769  0.02307692]
#  [-0.45384615  0.02307692  0.43076923]]
# [0.541223   1.58242904 2.29380653]
# [ 0.54068108 -0.69704407 -1.06350155]
# [False False  True]

# %%
alpha_test2 = np.array([2e-2,3e-2,1e-3])
mu_test2 = get_mu_from_Dirichlet(alpha_test2)
Sigma_test2 = get_Sigma_from_Dirichlet(alpha_test2)
print(Sigma_test2)
# Out:
# [[ 137.03703704   92.59259259 -229.62962963]
#  [  92.59259259  131.48148148 -224.07407407]
#  [-229.62962963 -224.07407407  453.7037037 ]]

# %%
correct_Sigma(mu_test2, Sigma_test2)
# Out:
# array([[ 137.03703704,   92.59259259, -229.62962963],
#        [  92.59259259,  131.48148148, -224.07407407],
#        [-229.62962963, -224.07407407,  453.7037037 ]])

# %%
def correct_mu_batch(mu, Sigma):
    return(mu - (Sigma.sum(-1) * mu.sum(-1).reshape(-1,1)) / Sigma.sum(axis=(1,2)).reshape(-1,1))

def correct_Sigma_batch(mu, Sigma):
    return(Sigma - np.einsum('bi,bj->bij', Sigma.sum(-1), Sigma.sum(-2)) / Sigma.sum(axis=(1,2)).reshape(-1,1,1))

# %%
mu_test1_batch = np.stack([np.array([0,0,0]), np.array([1,1,1]), np.array([10,2,3]), np.array([1,1,-2])])
Sigma_test1_batch = np.stack([np.eye(3), 2*np.eye(3), 3*np.eye(3), 4*np.eye(3)])
print(np.shape(mu_test1_batch))
print(np.shape(Sigma_test1_batch))

mu_test1_batch_corrected = correct_mu_batch(mu_test1_batch, Sigma_test1_batch)
Sigma_test1_batch_corrected = correct_Sigma_batch(mu_test1_batch, Sigma_test1_batch)

print(mu_test1_batch_corrected)
print(Sigma_test1_batch_corrected)

print(correct_mu(mu_test1_batch[0], Sigma_test1_batch[0]))
print(correct_Sigma(mu_test1_batch[0], Sigma_test1_batch[0]))
# Out:
# (4, 3)
# (4, 3, 3)
# [[ 0.  0.  0.]
#  [ 0.  0.  0.]
#  [ 5. -3. -2.]
#  [ 1.  1. -2.]]
# [[[ 0.66666667 -0.33333333 -0.33333333]
#   [-0.33333333  0.66666667 -0.33333333]
#   [-0.33333333 -0.33333333  0.66666667]]
#
#  [[ 1.33333333 -0.66666667 -0.66666667]
#   [-0.66666667  1.33333333 -0.66666667]
#   [-0.66666667 -0.66666667  1.33333333]]
#
#  [[ 2.         -1.         -1.        ]
#   [-1.          2.         -1.        ]
#   [-1.         -1.          2.        ]]
#
#  [[ 2.66666667 -1.33333333 -1.33333333]
#   [-1.33333333  2.66666667 -1.33333333]
#   [-1.33333333 -1.33333333  2.66666667]]]
# [0. 0. 0.]
# [[ 0.66666667 -0.33333333 -0.33333333]
#  [-0.33333333  0.66666667 -0.33333333]
#  [-0.33333333 -0.33333333  0.66666667]]

# %%
# OOD sample; we expect alpha_0 == alpha_1 - at least approximately
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

mu_real1 = np.array([ 6.4000, -8.4087])
Sigma_real1 = np.array([[13975.7568, 0.0000],
                        [0.0000, 13975.7529]])

mu_real1_c = np.array([7.4044, -7.4044])
Sigma_real1_c = np.array([[ 6987.8774, -6987.8774],
                          [-6987.8774,  6987.8774]])

mu_real1_c /= np.sqrt(np.diag(Sigma_real1_c))
Sigma_real1_c /= Sigma_real1_c

alpha_real1 = get_alpha_from_Normal(mu_real1, Sigma_real1)
alpha_real1_full = get_alpha_from_Normal_full(mu_real1, Sigma_real1)
print(alpha_real1)
print(alpha_real1_full)

alpha_real1_c = get_alpha_from_Normal(mu_real1_c, Sigma_real1_c)
alpha_real1_c_alt = get_alpha_from_Normal2(mu_real1_c, Sigma_real1_c)
alpha_real1_c_full = get_alpha_from_Normal_full(mu_real1_c, Sigma_real1_c)
print("alpha: ", alpha_real1_c)
print("alpha alt: ", alpha_real1_c_alt)
#print(alpha_real1_c_full)

#_ = get_alpha_from_Normal_dissect(mu_real1_c, Sigma_real1_c)
alpha_real1_cc = correct_alpha(alpha_real1_c, kappa=0.9)
print("after alpha correction: ", alpha_real1_cc)
# Out:
# [48.2949  0.    ]
# [24.1475  0.    ]
# alpha:  [0.5485 0.4594]
# alpha alt:  [0.0201 0.0201]
# after alpha correction:  [0.5064 0.4975]

# %%
# OOD sample; we expect alpha_0 == alpha_1 - at least approximately
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

mu_real1_c = np.array([100, 100])
Sigma_real1_c = np.array([[ 50, -50],
                          [-50,  50]])

#mu_real1_c /= np.sqrt(np.diag(Sigma_real1_c))
#Sigma_real1_c /= Sigma_real1_c

alpha_real1 = get_alpha_from_Normal(mu_real1, Sigma_real1)
alpha_real1_full = get_alpha_from_Normal_full(mu_real1, Sigma_real1)
print(alpha_real1)
print(alpha_real1_full)

alpha_real1_c = get_alpha_from_Normal(mu_real1_c, Sigma_real1_c)
alpha_real1_c_alt = get_alpha_from_Normal2(mu_real1_c, Sigma_real1_c)
alpha_real1_c_full = get_alpha_from_Normal_full(mu_real1_c, Sigma_real1_c)
print("alpha: ", alpha_real1_c)
print("alpha alt: ", alpha_real1_c_alt)
#print(alpha_real1_c_full)

#_ = get_alpha_from_Normal_dissect(mu_real1_c, Sigma_real1_c)
alpha_real1_cc = correct_alpha(alpha_real1_c, kappa=0.9)
print("after alpha correction: ", alpha_real1_cc)
# Out:
# [48.2949  0.    ]
# [24.1475  0.    ]
# alpha:  [0.01 0.01]
# alpha alt:  [0. 0.]
# after alpha correction:  [0.01 0.01]

# %%
from scipy.stats import norm
from scipy.special import gamma as gamma_func
from scipy.special import beta as beta_func

"""Transforms"""
def logit_transform(theta):
    return(np.log(theta/(1-theta)))

def logit_derivative(x):
    return(1/x + 1/(1-x))

def logistic_transform(a):
    return(1 / (1 + np.exp(-a)))

def logistic_derivative(x):
    return(logistic_transform(x) * (1- logistic_transform(x)))

def alpha_from_mu_var(mu, var):
    return((np.exp(mu) + 1) / var)

def beta_from_mu_var(mu, var):
    return((np.exp(-mu) + 1) / var)

def beta_pdf(x, a, b):
    nom = x ** (a-1) * (1 - x) ** (b-1)
    denom = beta_func(a, b)
    return(nom/denom)

def beta_t_logit_pdf(x, a, b):
    x_t = logistic_transform(x)
    nom = (x_t) ** (a) * (1- x_t) ** (b)
    denom = beta_func(a, b)
    return((nom/denom))

def beta_mu(a, b):
    return((a-1)/(a+b-2))

def beta_var(a, b):
    return(((a-1)*(b-1))/(a+b-2)**3)

"""transform: logit"""

def beta_t_logit_mu(a,b):
    return(np.log(a/b))

def beta_t_logit_var(a,b):
    return((a+b)/(a*b))

def logit_normal_back(x, mu, sigma):
    x_ = logit_transform(x)
    return(norm.pdf(x_, mu, sigma) * logit_derivative(x))

def plot_beta_t_logit(alpha2D, x_len):

    x = np.linspace(0,1, 1000 +1)
    x_t = np.linspace(-x_len/2,x_len/2, 1000 +1)
    
    a = alpha2D[0]
    b = alpha2D[1]
    mu = beta_t_logit_mu(a,b)
    sigma = np.sqrt(beta_t_logit_var(a, b))
    
    #plot 1: transform to other base
    y_t_logit = beta_t_logit_pdf(x_t, a, b)
    LP_approx_t_logit = norm.pdf(x_t, mu, sigma)

    #plot 2: transform back and reconstruct
    y_back = logit_normal_back(x, mu, sigma)
    y = beta_pdf(x, a, b)

    """Plots"""    
    plt.rc('text', usetex=True)
    plt.rc('xtick', labelsize=12)
    plt.rc('ytick', labelsize=15)
    plt.rc('axes', labelsize=15)
    
    legend_size=14
    xlabel_size=15
    ylabel_size=15
    title_size=15
    lw_size=2
    
    fig, axs = plt.subplots(nrows=1, ncols=2, sharex=False, figsize=(10, 3))

    #plot beta distribution in the transformed basis
    axs[0].plot(x_t, y_t_logit, 'r-', lw=lw_size)
    axs[0].plot(x_t, LP_approx_t_logit, 'r--', lw=lw_size)
    axs[0].set_xlabel('x', fontsize=xlabel_size)
    #axs[0].set_ylabel('$p(x)dx$', fontsize=ylabel_size)
    #axs[0].set_yticklabels([])
    #axs[0].set_yticks([])
    axs[0].set_title('Laplace in logit basis', fontsize=title_size)
    #axs[0].legend(prop={'size': legend_size});

    #plot backwards transformation of the LPA from the transformed to the standard basis
    axs[1].plot(x, y, 'k-', lw=lw_size)
    axs[1].plot(x, y_back, 'k--', lw=lw_size)
    #axs[1].set_yticklabels([])
    #axs[1].set_yticks([])
    axs[1].set_xlabel('$\pi$', fontsize=xlabel_size)
    #axs[1].set_ylabel('$p(\pi)d\pi$', fontsize=ylabel_size)
    axs[1].set_title('Back to standard basis', fontsize=title_size)
    #axs[1].legend(prop={'size': legend_size});

    plt.tight_layout()
        
    plt.show();

# %%
#plot_beta_t_logit(np.array([115, 0.07]), 100)
plot_beta_t_logit(np.array([2.6e3, 2.2e-2]), 100)
# Out:
# /tmp/ipykernel_2533/4190239306.py:7: RuntimeWarning: divide by zero encountered in true_divide
#   return(np.log(theta/(1-theta)))
# /tmp/ipykernel_2533/4190239306.py:7: RuntimeWarning: divide by zero encountered in log
#   return(np.log(theta/(1-theta)))
# /tmp/ipykernel_2533/4190239306.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   return(1/x + 1/(1-x))
# /tmp/ipykernel_2533/4190239306.py:51: RuntimeWarning: invalid value encountered in multiply
#   return(norm.pdf(x_, mu, sigma) * logit_derivative(x))
# /tmp/ipykernel_2533/4190239306.py:25: RuntimeWarning: divide by zero encountered in power
#   nom = x ** (a-1) * (1 - x) ** (b-1)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     251         try:
# --> 252             report = subprocess.check_output(
#     253                 command, cwd=cwd if cwd is not None else self.texcache,
#
# ~/anaconda3/lib/python3.9/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     423
# --> 424     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425                **kwargs).stdout
#
# ~/anaconda3/lib/python3.9/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# ~/anaconda3/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~/anaconda3/lib/python3.9/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1820                         err_msg = os.strerror(errno_num)
# -> 1821                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1822                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_2533/597285020.py in <module>
#       1 #plot_beta_t_logit(np.array([115, 0.07]), 100)
# ----> 2 plot_beta_t_logit(np.array([2.6e3, 2.2e-2]), 100)
#
# /tmp/ipykernel_2533/4190239306.py in plot_beta_t_logit(alpha2D, x_len)
#     103     #axs[1].legend(prop={'size': legend_size});
#     104
# --> 105     plt.tight_layout()
#     106
#     107     plt.show();
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1659         subplots area (including labels) will fit.
#    1660     """
# -> 1661     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1662
#    1663
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in tight_layout(self, pad, h_pad, w_pad, rect)
#    3162                else suppress())
#    3163         with ctx:
# -> 3164             kwargs = get_tight_layout_figure(
#    3165                 self, self.axes, subplotspec_list, renderer,
#    3166                 pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     310                               (colNum2 + 1) * div_col - 1))
#     311
# --> 312     kwargs = auto_adjust_subplotpars(fig, renderer,
#     313                                      nrows_ncols=(max_nrows, max_ncols),
#     314                                      num1num2_list=num1num2_list,
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      82             if ax.get_visible():
#      83                 try:
# ---> 84                     bb += [ax.get_tightbbox(renderer, for_layout_only=True)]
#      85                 except TypeError:
#      86                     bb += [ax.get_tightbbox(renderer)]
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4428             if self.xaxis.get_visible():
#    4429                 try:
# -> 4430                     bb_xaxis = self.xaxis.get_tightbbox(
#    4431                         renderer, for_layout_only=for_layout_only)
#    4432                 except TypeError:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1086         ticks_to_draw = self._update_ticks()
#    1087
# -> 1088         self._update_label_position(renderer)
#    1089
#    1090         # go back to just this axis's tick labels
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    2083         # get bounding boxes for this axis and any siblings
#    2084         # that have been set by `fig.align_xlabels()`
# -> 2085         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2086
#    2087         x, y = self.label.get_position()
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    1871             axis = ax._get_axis_map()[axis_name]
#    1872             ticks_to_draw = axis._update_ticks()
# -> 1873             tlb, tlb2 = axis._get_tick_bboxes(ticks_to_draw, renderer)
#    1874             bboxes.extend(tlb)
#    1875             bboxes2.extend(tlb2)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1066     def _get_tick_bboxes(self, ticks, renderer):
#    1067         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1068         return ([tick.label1.get_window_extent(renderer)
#    1069                  for tick in ticks if tick.label1.get_visible()],
#    1070                 [tick.label2.get_window_extent(renderer)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1066     def _get_tick_bboxes(self, ticks, renderer):
#    1067         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1068         return ([tick.label1.get_window_extent(renderer)
#    1069                  for tick in ticks if tick.label1.get_visible()],
#    1070                 [tick.label2.get_window_extent(renderer)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     901
#     902         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 903             bbox, info, descent = self._get_layout(self._renderer)
#     904             x, y = self.get_unitless_position()
#     905             x, y = self.get_transform().transform((x, y))
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     304
#     305         # Full vertical extent of font, including ascenders and descenders:
# --> 306         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     307             "lp", self._fontproperties,
#     308             ismath="TeX" if self.get_usetex() else False)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     227             texmanager = self.get_texmanager()
#     228             fontsize = prop.get_size_in_points()
# --> 229             w, h, d = texmanager.get_text_width_height_descent(
#     230                 s, fontsize, renderer=self)
#     231             return w, h, d
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     397         else:
#     398             # use dviread.
# --> 399             dvifile = self.make_dvi(tex, fontsize)
#     400             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     401                 page, = dvi
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     289             # and thus replace() works atomically.
#     290             with TemporaryDirectory(dir=Path(dvifile).parent) as tmpdir:
# --> 291                 self._run_checked_subprocess(
#     292                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     293                      texfile], tex, cwd=tmpdir)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     254                 stderr=subprocess.STDOUT)
#     255         except FileNotFoundError as exc:
# --> 256             raise RuntimeError(
#     257                 'Failed to process string with tex because {} could not be '
#     258                 'found'.format(command[0])) from exc
#
# RuntimeError: Failed to process string with tex because latex could not be found
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     251         try:
# --> 252             report = subprocess.check_output(
#     253                 command, cwd=cwd if cwd is not None else self.texcache,
#
# ~/anaconda3/lib/python3.9/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     423
# --> 424     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425                **kwargs).stdout
#
# ~/anaconda3/lib/python3.9/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# ~/anaconda3/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~/anaconda3/lib/python3.9/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1820                         err_msg = os.strerror(errno_num)
# -> 1821                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1822                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2228                        else suppress())
#    2229                 with ctx:
# -> 2230                     self.figure.draw(renderer)
#    2231
#    2232             if bbox_inches:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2788
#    2789             self.patch.draw(renderer)
# -> 2790             mimage._draw_list_compositing_images(
#    2791                 renderer, self, artists, self.suppressComposite)
#    2792
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2879                 artists.remove(spine)
#    2880
# -> 2881         self._update_title_position(renderer)
#    2882
#    2883         if not self.axison or inframe:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    2820                 _log.debug('top of axes not in the figure, so title not moved')
#    2821                 return
# -> 2822             if title.get_window_extent(renderer).ymin < top:
#    2823                 _, y = self.transAxes.inverted().transform((0, top))
#    2824                 title.set_position((x, y))
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     901
#     902         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 903             bbox, info, descent = self._get_layout(self._renderer)
#     904             x, y = self.get_unitless_position()
#     905             x, y = self.get_transform().transform((x, y))
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     304
#     305         # Full vertical extent of font, including ascenders and descenders:
# --> 306         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     307             "lp", self._fontproperties,
#     308             ismath="TeX" if self.get_usetex() else False)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     227             texmanager = self.get_texmanager()
#     228             fontsize = prop.get_size_in_points()
# --> 229             w, h, d = texmanager.get_text_width_height_descent(
#     230                 s, fontsize, renderer=self)
#     231             return w, h, d
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     397         else:
#     398             # use dviread.
# --> 399             dvifile = self.make_dvi(tex, fontsize)
#     400             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     401                 page, = dvi
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     289             # and thus replace() works atomically.
#     290             with TemporaryDirectory(dir=Path(dvifile).parent) as tmpdir:
# --> 291                 self._run_checked_subprocess(
#     292                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     293                      texfile], tex, cwd=tmpdir)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     254                 stderr=subprocess.STDOUT)
#     255         except FileNotFoundError as exc:
# --> 256             raise RuntimeError(
#     257                 'Failed to process string with tex because {} could not be '
#     258                 'found'.format(command[0])) from exc
#
# RuntimeError: Failed to process string with tex because latex could not be found

# %%
plot_beta_t_logit(alpha_real1_c, 500)

# %%
plot_beta_t_logit(alpha_real1_cc, 500)

# %%
# in dist sample; we expect alpha_0 << alpha_1 or alpha_1 << alpha_0

mu_real2 = np.array([2.6606,  -2.7122])
Sigma_real2 = np.array([[  41.8984,    0.0000],
                        [   0.0000,   41.8984]])

mu_real2_c = correct_mu(mu_real2, Sigma_real2)
Sigma_real2_c = correct_Sigma(mu_real2, Sigma_real2)
mu_real2_c /= np.sqrt(np.diag(Sigma_real2_c))
Sigma_real2_c /= Sigma_real2_c

print(mu_real2_c)
print(Sigma_real2_c)

alpha_real2 = get_alpha_from_Normal(mu_real2, Sigma_real2)
alpha_real2_full = get_alpha_from_Normal_full(mu_real2, Sigma_real2)
print(alpha_real2)
print(alpha_real2_full)

alpha_real2_c = get_alpha_from_Normal(mu_real2_c, Sigma_real2_c)
alpha_real2_c_alt = get_alpha_from_Normal2(mu_real2_c, Sigma_real2_c)
alpha_real2_c_full = get_alpha_from_Normal_full(mu_real2_c, Sigma_real2_c)
print("alpha: ", alpha_real2_c)
print("alpha alt: ", alpha_real2_c_alt)
#print(alpha_real2_c_full)

print("mean2: ", alpha_real2 / alpha_real2.sum())
print("mean2_c: ", alpha_real2_c / alpha_real2_c.sum())

alpha_real2_cc = correct_alpha(alpha_real2_c, kappa=0.9)
print("after alpha2 correction: ", alpha_real2_cc)
# Out:
# [ 0.5869 -0.5869]
# [[1. 1.]
#  [1. 1.]]
# [1.2916 0.006 ]
# [0.6458 0.003 ]
# alpha:  [1.0586 0.3273]
# alpha alt:  [0.0235 0.0235]
# mean2:  [0.9954 0.0046]
# mean2_c:  [0.7638 0.2362]
# after alpha2 correction:  [0.6242 0.5551]

# %%
plot_beta_t_logit(alpha_real2_c, 40)

# %%
plot_beta_t_logit(alpha_real2_cc, 40)

# %%
mu_real3 = np.array([ -8.2520,  -2.1058,  16.4355,  -5.7994,  -4.0799])
Sigma_real3 = np.array([[  6988.7236,      0.0000,      0.0000,      0.0000,      0.0000],
                     [     0.0000,  16933.8125,      0.0000,      0.0000,      0.0000],
                     [     0.0000,      0.0000,   4263.9048,      0.0000,      0.0000],
                     [     0.0000,      0.0000,      0.0000,   4575.6382,      0.0000],
                     [     0.0000,      0.0000,      0.0000,      0.0000,  69514.2812]])

mu_real3_c = correct_mu(mu_real3, Sigma_real3)
Sigma_real3_c = correct_Sigma(mu_real3, Sigma_real3)
mu_real3_c /= np.diag(Sigma_real3_c)
Sigma_real3_c /= Sigma_real3_c

print(mu_real3_c)
print(Sigma_real3_c)

alpha_real3 = get_alpha_from_Normal(mu_real3, Sigma_real3)
print("alpha_real3: ", alpha_real3)

alpha_real3_c = get_alpha_from_Normal(mu_real3_c, Sigma_real3_c)
print("alpha_real3_c: ", alpha_real3_c)

print("mean3: ", alpha_real3 / alpha_real3.sum())
print("mean3_c: ", alpha_real3_c / alpha_real3_c.sum())

# %%
# first in-dist MNIST sample
mu_real4_c = np.array([-4.8810,  1.9949,  2.7766,  3.6046, -4.9315, -1.5197, -8.8093, 13.4708, -3.3499,  1.6446])
Sigma_real4_c = np.array([
        [ 20.2388,  -1.4815,  -0.7205,  -1.3855,  -3.0852,  -2.2861,  -7.8814, -0.5418,  -1.7603,  -1.0965],
        [ -1.4815,  13.3855,  -0.4572,  -0.8793,  -1.9579,  -1.4508,  -5.0018, -0.3438,  -1.1172,  -0.6958],
        [ -0.7205,  -0.4572,   6.7443,  -0.4276,  -0.9522,  -0.7056,  -2.4324, -0.1672,  -0.5433,  -0.3384],
        [ -1.3855,  -0.8793,  -0.4276,  12.5754,  -1.8311,  -1.3569,  -4.6778, -0.3216,  -1.0448,  -0.6508],
        [ -3.0852,  -1.9579,  -0.9522,  -1.8311,  25.7555,  -3.0214, -10.4161, -0.7160,  -2.3265,  -1.4491],
        [ -2.2861,  -1.4508,  -0.7056,  -1.3569,  -3.0214,  19.8675,  -7.7184, -0.5306,  -1.7239,  -1.0738],
        [ -7.8814,  -5.0018,  -2.4324,  -4.6778, -10.4161,  -7.7184,  49.6024, -1.8292,  -5.9433,  -3.7019],
        [ -0.5418,  -0.3438,  -0.1672,  -0.3216,  -0.7160,  -0.5306,  -1.8292, 5.1133,  -0.4086,  -0.2545],
        [ -1.7603,  -1.1172,  -0.5433,  -1.0448,  -2.3265,  -1.7239,  -5.9433, -0.4086,  15.6947,  -0.8268],
        [ -1.0965,  -0.6958,  -0.3384,  -0.6508,  -1.4491,  -1.0738,  -3.7019, -0.2545,  -0.8268,  10.0875]])


kappa = 1
#mu_real4_cc = mu_real4_c / np.sqrt(np.min(np.diag(Sigma_real4_c)))
#Sigma_real4_cc = Sigma_real4_c/ np.min(np.diag(Sigma_real4_c))
#mu_real4_cc = mu_real4_c / np.sqrt(np.diag(Sigma_real4_c))
#Sigma_real4_cc = Sigma_real4_c / Sigma_real4_c
#mu_real4_c_std = mu_real4_c.std()
#mu_real4_cc = np.sqrt(mu_real4_c_std) * mu_real4_c / np.sqrt(np.diag(Sigma_real4_c + 1/np.sqrt(Sigma_real4_c)))
#Sigma_real4_cc = mu_real4_c_std * Sigma_real4_c / (Sigma_real4_c + 1/np.sqrt(Sigma_real4_c))
#Sigma_real4_c_diag_mean = np.min(np.diag(Sigma_real4_c))
#mu_real4_cc = mu_real4_c / np.sqrt(Sigma_real4_c_diag_mean + 1/np.sqrt(Sigma_real4_c_diag_mean))
#Sigma_real4_cc = Sigma_real4_c / (Sigma_real4_c_diag_mean + 1/np.sqrt(Sigma_real4_c_diag_mean))
mu_real4_cc, Sigma_real4_cc = mu_sigma_cc(mu_real4_c, Sigma_real4_c)

alpha_real4_c = get_alpha_from_Normal(mu_real4_c, Sigma_real4_c)
alpha_real4_cc = get_alpha_from_Normal(mu_real4_cc, Sigma_real4_cc)
print("alpha_real4_c: ", alpha_real4_c)
print("alpha_real4_cc: ", alpha_real4_cc)

print("mean4_c: ", alpha_real4_c / alpha_real4_c.sum())
print("mean4_cc: ", alpha_real4_cc / alpha_real4_cc.sum())
# sm mean: 
#[2.4344677e-06 2.9705160e-03 4.6617063e-03 5.6950189e-03 1.3493338e-05
# 1.4253784e-03 9.4698429e-08 9.8440039e-01 1.8027768e-05 8.1300479e-04]

# %%
# FMNIST OOD example
mu_real5_c = np.array([ 3.5397e-01,  6.3125e+00,  5.3475e+00, -2.1314e+00, -1.2655e+00,  
                       -5.0167e-03,  4.6985e+00, -3.0206e+00, -3.3208e+00, -6.9691e+00])
Sigma_real5_c = np.array([[ 5.6529, -0.6200, -0.3312, -0.6499, -0.8346, -0.5978, -0.6116, -0.9482, -0.4800, -0.5795],
        [-0.6200,  5.1464, -0.2979, -0.5845, -0.7506, -0.5376, -0.5501, -0.8528, -0.4317, -0.5212],
        [-0.3312, -0.2979,  2.8880, -0.3123, -0.4010, -0.2872, -0.2938, -0.4555, -0.2306, -0.2784],
        [-0.6499, -0.5845, -0.3123,  5.3665, -0.7868, -0.5636, -0.5766, -0.8939, -0.4525, -0.5463],
        [-0.8346, -0.7506, -0.4010, -0.7868,  6.6677, -0.7237, -0.7404, -1.1479, -0.5811, -0.7016],
        [-0.5978, -0.5376, -0.2872, -0.5636, -0.7237,  4.9811, -0.5303, -0.8222, -0.4162, -0.5025],
        [-0.6116, -0.5501, -0.2938, -0.5766, -0.7404, -0.5303,  5.0840, -0.8412, -0.4259, -0.5141],
        [-0.9482, -0.8528, -0.4555, -0.8939, -1.1479, -0.8222, -0.8412,  7.4189, -0.6602, -0.7971],
        [-0.4800, -0.4317, -0.2306, -0.4525, -0.5811, -0.4162, -0.4259, -0.6602,  4.0818, -0.4035],
        [-0.5795, -0.5212, -0.2784, -0.5463, -0.7016, -0.5025, -0.5141, -0.7971, -0.4035,  4.8442]])

kappa = 0.1
#mu_real5_cc = mu_real5_c / np.sqrt(np.diag(kappa * Sigma_real5_c + (1-kappa) * np.eye(10)))
#Sigma_real5_cc = Sigma_real5_c/ (kappa * Sigma_real5_c + (1-kappa) * np.eye(10))
#mu_real5_cc = mu_real5_c / np.sqrt(np.diag(Sigma_real5_c))
#Sigma_real5_cc = Sigma_real5_c / (Sigma_real5_c)
#Sigma_real5_c_diag_mean = np.mean(np.diag(Sigma_real5_c))
#Sigma_real5_c_diag_mean = np.min(np.diag(Sigma_real5_c))
#mu_real5_cc = mu_real5_c / np.sqrt(Sigma_real5_c_diag_mean + 1/np.sqrt(Sigma_real5_c_diag_mean))
#Sigma_real5_cc = Sigma_real5_c / (Sigma_real5_c_diag_mean + 1/np.sqrt(Sigma_real5_c_diag_mean))
mu_real5_cc, Sigma_real5_cc = mu_sigma_cc(mu_real5_c, Sigma_real5_c)
print("mu_real5_cc: ", mu_real5_cc)

alpha_real5_c = get_alpha_from_Normal(mu_real5_c, Sigma_real5_c)
alpha_real5_cc = get_alpha_from_Normal(mu_real5_cc, Sigma_real5_cc)
print("alpha_real5_c: ", alpha_real5_c)
print("alpha_real5_cc: ", alpha_real5_cc)

print("mean5_c: ", alpha_real5_c / alpha_real5_c.sum())
print("mean5_cc: ", alpha_real5_cc / alpha_real5_cc.sum())
#sm mean:
#[1.30892254e-03 5.30074775e-01 3.59952837e-01 1.74922723e-04 2.62023357e-04
# 1.05871470e-03 1.06884345e-01 7.99269619e-05 1.29940396e-04 7.35641661e-05]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2533/1154717446.py in <module>
#      22 #mu_real5_cc = mu_real5_c / np.sqrt(Sigma_real5_c_diag_mean + 1/np.sqrt(Sigma_real5_c_diag_mean))
#      23 #Sigma_real5_cc = Sigma_real5_c / (Sigma_real5_c_diag_mean + 1/np.sqrt(Sigma_real5_c_diag_mean))
# ---> 24 mu_real5_cc, Sigma_real5_cc = mu_sigma_cc(mu_real5_c, Sigma_real5_c)
#      25 print("mu_real5_cc: ", mu_real5_cc)
#      26
#
# NameError: name 'mu_sigma_cc' is not defined

# %%
from scipy.stats import multivariate_normal as mvnorm

normal_real1 = mvnorm(mu_real1, Sigma_real1)
samples1 = normal_real1.rvs(1000)
samples1_sm = np.exp(samples1) / np.exp(samples1).sum(1).reshape(-1, 1)
print(samples1_sm.mean(0))
#print(samples_sm)
# Out:
# [0.533 0.467]

# %%
# compare in plots
from scipy.stats import beta
x_ = np.linspace(0, 1, 10000+1)
beta1 = beta.pdf(x_, alpha_real1[0], alpha_real1[1])
beta1_c = beta.pdf(x_, alpha_real1_c[0], alpha_real1_c[1])

plt.figure(figsize=(10, 5))

plt.hist(samples1_sm[:,0], density=True, bins=100, alpha=0.2)
plt.plot(x_, 100*beta1)
plt.plot(x_, 100*beta1_c)
plt.show();
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     251         try:
# --> 252             report = subprocess.check_output(
#     253                 command, cwd=cwd if cwd is not None else self.texcache,
#
# ~/anaconda3/lib/python3.9/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     423
# --> 424     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     425                **kwargs).stdout
#
# ~/anaconda3/lib/python3.9/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     504
# --> 505     with Popen(*popenargs, **kwargs) as process:
#     506         try:
#
# ~/anaconda3/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~/anaconda3/lib/python3.9/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1820                         err_msg = os.strerror(errno_num)
# -> 1821                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1822                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2228                        else suppress())
#    2229                 with ctx:
# -> 2230                     self.figure.draw(renderer)
#    2231
#    2232             if bbox_inches:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2788
#    2789             self.patch.draw(renderer)
# -> 2790             mimage._draw_list_compositing_images(
#    2791                 renderer, self, artists, self.suppressComposite)
#    2792
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2919             renderer.stop_rasterizing()
#    2920
# -> 2921         mimage._draw_list_compositing_images(renderer, self, artists)
#    2922
#    2923         renderer.close_group('axes')
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1140
#    1141         ticks_to_draw = self._update_ticks()
# -> 1142         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1143                                                                 renderer)
#    1144
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1066     def _get_tick_bboxes(self, ticks, renderer):
#    1067         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1068         return ([tick.label1.get_window_extent(renderer)
#    1069                  for tick in ticks if tick.label1.get_visible()],
#    1070                 [tick.label2.get_window_extent(renderer)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1066     def _get_tick_bboxes(self, ticks, renderer):
#    1067         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1068         return ([tick.label1.get_window_extent(renderer)
#    1069                  for tick in ticks if tick.label1.get_visible()],
#    1070                 [tick.label2.get_window_extent(renderer)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     901
#     902         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 903             bbox, info, descent = self._get_layout(self._renderer)
#     904             x, y = self.get_unitless_position()
#     905             x, y = self.get_transform().transform((x, y))
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     304
#     305         # Full vertical extent of font, including ascenders and descenders:
# --> 306         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     307             "lp", self._fontproperties,
#     308             ismath="TeX" if self.get_usetex() else False)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     227             texmanager = self.get_texmanager()
#     228             fontsize = prop.get_size_in_points()
# --> 229             w, h, d = texmanager.get_text_width_height_descent(
#     230                 s, fontsize, renderer=self)
#     231             return w, h, d
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     397         else:
#     398             # use dviread.
# --> 399             dvifile = self.make_dvi(tex, fontsize)
#     400             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     401                 page, = dvi
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     289             # and thus replace() works atomically.
#     290             with TemporaryDirectory(dir=Path(dvifile).parent) as tmpdir:
# --> 291                 self._run_checked_subprocess(
#     292                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
#     293                      texfile], tex, cwd=tmpdir)
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     254                 stderr=subprocess.STDOUT)
#     255         except FileNotFoundError as exc:
# --> 256             raise RuntimeError(
#     257                 'Failed to process string with tex because {} could not be '
#     258                 'found'.format(command[0])) from exc
#
# RuntimeError: Failed to process string with tex because latex could not be found

# %%
normal_real2 = mvnorm(mu_real2, Sigma_real2)
samples2 = normal_real2.rvs(50)
samples2_sm = np.exp(samples2) / np.exp(samples2).sum(1).reshape(-1, 1)
print(samples2_sm.mean(0))
#print(samples_sm)
# Out:
# [0.7651 0.2349]

# %%
x_ = np.linspace(0, 1, 1000+1)
beta2 = beta.pdf(x_, alpha_real2[0], alpha_real2[1])
beta2_c = beta.pdf(x_, alpha_real2_c[0], alpha_real2_c[1])

plt.figure(figsize=(10, 5))

plt.hist(samples2_sm[:,0], density=True, bins=100, alpha=0.2)
plt.plot(x_, beta2)
plt.plot(x_, beta2_c)
plt.show();

# %% [markdown]
# # Analysis: why does it translate badly and when?

# %%
#check the mean
from scipy.stats import beta

x_ = np.linspace(0, 1, 1000+1)
a_test, b_test = 0.5, 0.2
a_test2, b_test2 = 0.9, 0.02
a_test3, b_test3 = 4, 5

beta1_pdf = beta.pdf(x_, a_test, b_test)
beta2_pdf = beta.pdf(x_, a_test2, b_test2)
beta3_pdf = beta.pdf(x_, a_test3, b_test3)

beta1_samples = beta(a_test, b_test).rvs(10000)
beta2_samples = beta(a_test2, b_test2).rvs(10000)
beta3_samples = beta(a_test3, b_test3).rvs(10000)

beta1_mean = a_test / (a_test + b_test)
beta2_mean = a_test2 / (a_test2 + b_test2)
beta3_mean = a_test3 / (a_test3 + b_test3)

x2_ = np.linspace(-10, 30, 1000+1)

beta1_logit = beta_t_logit_pdf(x2_, a_test, b_test)
beta2_logit = beta_t_logit_pdf(x2_, a_test2, b_test2)
beta3_logit = beta_t_logit_pdf(x2_, a_test3, b_test3)

beta1_logit_samples = logit_transform(beta1_samples.clip(1e-10, 1-1e-10))
beta2_logit_samples = logit_transform(beta2_samples.clip(1e-10, 1-1e-10))
beta3_logit_samples = logit_transform(beta3_samples.clip(1e-10, 1-1e-10))

beta1_logit_mean = logit_transform(beta1_mean)
beta2_logit_mean = logit_transform(beta2_mean)
beta3_logit_mean = logit_transform(beta3_mean)

beta1_logit_samples_mean = beta1_logit_samples.mean()
print("beta1_logit_samples_mean: ", beta1_logit_samples_mean)
print("beta1_logit_samples_mean logistic: ", logistic_transform(beta1_logit_samples_mean))
print("beta1_mean: ", beta1_mean)
print("beta1_logit_mean: ", beta1_logit_mean)
print("beta2_logit_samples_mean: ", beta2_logit_samples_mean)
print("beta2_logit_samples_mean logistic: ", logistic_transform(beta2_logit_samples_mean))
print("beta2_mean: ", beta2_mean)
print("beta2_logit_mean: ", beta2_logit_mean)
print("beta3_logit_samples_mean: ", beta3_logit_samples_mean)
print("beta3_logit_samples_mean logistic: ", logistic_transform(beta3_logit_samples_mean))
print("beta3_mean: ", beta3_mean)
print("beta3_logit_mean: ", beta3_logit_mean)
beta2_logit_samples_mean = beta2_logit_samples.mean()
beta3_logit_samples_mean = beta3_logit_samples.mean()

fig, ax = plt.subplots(1, 2, figsize=(14, 5))

ax[0].plot(x_, beta1_pdf, label='beta1')
#ax[0].plot(x_, beta2_pdf, label='beta2')
#ax[0].plot(x_, beta3_pdf, label='beta3')
ax[0].hist(beta1_samples, bins=100, range=[0,1], alpha=0.2, density=True)
#ax[0].hist(beta2_samples, bins=100, range=[0,1], alpha=0.2, density=True)
#ax[0].hist(beta3_samples, bins=100, range=[0,1], alpha=0.2, density=True)
ax[0].axvline(beta1_mean)
#ax[0].axvline(beta2_mean)
#ax[0].axvline(beta3_mean)

ax[1].plot(x2_, beta1_logit, label='beta1')
#ax[1].plot(x2_, beta2_logit, label='beta2')
#ax[1].plot(x2_, beta3_logit, label='beta3')
ax[1].hist(beta1_logit_samples, bins=100, alpha=0.2, density=True)
#ax[1].hist(beta2_logit_samples, bins=100, alpha=0.2, density=True)
#ax[1].hist(beta3_logit_samples, bins=100, alpha=0.2, density=True)
ax[1].axvline(beta1_logit_mean)
ax[1].axvline(beta1_logit_samples_mean)
#ax[1].axvline(beta2_logit_mean)
#ax[1].axvline(beta2_logit_samples_mean)
#ax[1].axvline(beta3_logit_mean)
#ax[1].axvline(beta3_logit_samples_mean)

plt.show();
# Out:
# beta1_logit_samples_mean:  3.2852034055250727
# beta1_logit_samples_mean logistic:  0.9639176975095193
# beta1_mean:  0.7142857142857143
# beta1_logit_mean:  0.9162907318741551
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-353-e171150b4bff> in <module>
#      38 print("beta1_mean: ", beta1_mean)
#      39 print("beta1_logit_mean: ", beta1_logit_mean)
# ---> 40 print("beta2_logit_samples_mean: ", beta2_logit_samples_mean)
#      41 print("beta2_logit_samples_mean logistic: ", logistic_transform(beta2_logit_samples_mean))
#      42 print("beta2_mean: ", beta2_mean)
#
# NameError: name 'beta2_logit_samples_mean' is not defined

# %%
# test how the mean changes when alpha < 1
a_test4 = 1
b_test4 = 1
means_logit = []
means_logit_samples = []
betas = []
beta_mus = []
beta_vars = []

for i in range(15):
    
    b_ = b_test4 * 0.8**i
    print("a: ", a_test4, "b: ", b_)
    betas.append(b_)
    
    x_ = np.linspace(0, 1, 1000+1)

    beta4_pdf = beta.pdf(x_, a_test4, b_)
    beta4_samples = beta(a_test4, b_).rvs(10000)
    beta4_mean = a_test4 / (a_test4 + b_)
    beta4_mu = beta_t_logit_mu(a_test4, b_)
    beta4_var = beta_t_logit_var(a_test4, b_)

    x2_ = np.linspace(-10, 30, 1000+1)

    beta4_logit = beta_t_logit_pdf(x2_, a_test4, b_)
    beta4_logit_samples = logit_transform(beta4_samples.clip(1e-15, 1-1e-15))
    beta4_logit_mean = logit_transform(beta4_mean)
    beta4_logit_samples_mean = beta4_logit_samples.mean()
    print("beta4_logit_samples_mean: ", beta4_logit_samples_mean)
    print("beta4_logit_samples_mean logistic: ", logistic_transform(beta4_logit_samples_mean))
    print("beta4_mean: ", beta4_mean)
    print("beta4_logit_mean: ", beta4_logit_mean)
    print("beta4_mu: ", beta4_mu)
    print("beta4_var: ", beta4_var)
    means_logit.append(beta4_logit_mean)
    means_logit_samples.append(beta4_logit_samples_mean)
    beta_mus.append(beta4_mu)
    beta_vars.append(beta4_var)
    
    norm4_pdf = norm.pdf(x2_, beta4_mu, np.sqrt(beta4_var))
    a_back = alpha_from_mu_var(beta4_mu, beta4_var)
    b_back = beta_from_mu_var(beta4_mu, beta4_var)
    beta4_pdf_back = beta.pdf(x_, a_back, b_back)
    
    mu_c = beta4_mu * 2
    var_c = beta4_var
    a_c = alpha_from_mu_var(mu_c, var_c)
    b_c = beta_from_mu_var(mu_c, var_c)
    norm_pdf_c = norm.pdf(x2_, mu_c, np.sqrt(var_c))
    beta_pdf_c = beta.pdf(x_, a_c, b_c)

    fig, ax = plt.subplots(1, 2, figsize=(14, 5))

    ax[0].plot(x_, beta4_pdf, label='beta4')
    ax[0].plot(x_, beta4_pdf_back, label='beta4_back')
    ax[0].plot(x_, beta_pdf_c, label='beta4_c')
    ax[0].hist(beta4_samples, bins=100, range=[0,1], alpha=0.2, density=True)
    ax[0].axvline(beta4_mean)

    ax[1].plot(x2_, beta4_logit, label='beta4')
    ax[1].plot(x2_, norm4_pdf, label="norm4")
    ax[1].plot(x2_, norm_pdf_c, label="norm_c")
    ax[1].hist(beta4_logit_samples, bins=100, alpha=0.2, density=True)
    ax[1].axvline(beta4_logit_mean)
    ax[1].axvline(beta4_logit_samples_mean, color='red')

    plt.show();
# Out:
# a:  1 b:  1.0
# beta4_logit_samples_mean:  -0.04087438327073225
# beta4_logit_samples_mean logistic:  0.4897828266416178
# beta4_mean:  0.5
# beta4_logit_mean:  0.0
# beta4_mu:  0.0
# beta4_var:  2.0
# a:  1 b:  0.8
# beta4_logit_samples_mean:  0.35389030230237406
# beta4_logit_samples_mean logistic:  0.5875606481174265
# beta4_mean:  0.5555555555555556
# beta4_logit_mean:  0.22314355131420993
# beta4_mu:  0.22314355131420976
# beta4_var:  2.25
# a:  1 b:  0.6400000000000001
# beta4_logit_samples_mean:  0.8424859714219226
# beta4_logit_samples_mean logistic:  0.6989885318544596
# beta4_mean:  0.6097560975609756
# beta4_logit_mean:  0.44628710262841953
# beta4_mu:  0.44628710262841936
# beta4_var:  2.5624999999999996
# a:  1 b:  0.5120000000000001
# beta4_logit_samples_mean:  1.3210450372033677
# beta4_logit_samples_mean logistic:  0.789355520936349
# beta4_mean:  0.6613756613756614
# beta4_logit_mean:  0.6694306539426294
# beta4_mu:  0.669430653942629
# beta4_var:  2.953124999999999
# a:  1 b:  0.4096000000000001
# beta4_logit_samples_mean:  1.9141652015139443
# beta4_logit_samples_mean logistic:  0.8714863638543393
# beta4_mean:  0.7094211123723041
# beta4_logit_mean:  0.8925742052568385
# beta4_mu:  0.8925742052568388
# beta4_var:  3.44140625
# a:  1 b:  0.3276800000000001
# beta4_logit_samples_mean:  2.606920430600838
# beta4_logit_samples_mean logistic:  0.9313056409487078
# beta4_mean:  0.7531935406121957
# beta4_logit_mean:  1.1157177565710485
# beta4_mu:  1.1157177565710485
# beta4_var:  4.051757812499999
# a:  1 b:  0.2621440000000001
# beta4_logit_samples_mean:  3.4353197979676477
# beta4_logit_samples_mean logistic:  0.9687903169953992
# beta4_mean:  0.7923026215709141
# beta4_logit_mean:  1.3388613078852578
# beta4_mu:  1.3388613078852583
# beta4_var:  4.814697265624999
# a:  1 b:  0.20971520000000007
# beta4_logit_samples_mean:  4.502836960800829
# beta4_logit_samples_mean logistic:  0.9890438417090855
# beta4_mean:  0.82664084901967
# beta4_logit_mean:  1.5620048591994682
# beta4_mu:  1.562004859199468
# beta4_var:  5.768371582031248
# a:  1 b:  0.1677721600000001
# beta4_logit_samples_mean:  5.761279985028567
# beta4_logit_samples_mean logistic:  0.9968627922433019
# beta4_mean:  0.8563314268427155
# beta4_logit_mean:  1.7851484105136768
# beta4_mu:  1.7851484105136777
# beta4_var:  6.96046447753906
# a:  1 b:  0.13421772800000006
# beta4_logit_samples_mean:  7.177219236171933
# beta4_logit_samples_mean logistic:  0.9992367941199881
# beta4_mean:  0.8816649354999324
# beta4_logit_mean:  2.008291961827887
# beta4_mu:  2.0082919618278874
# beta4_var:  8.450580596923825
# a:  1 b:  0.10737418240000006
# beta4_logit_samples_mean:  8.90242884346772
# beta4_logit_samples_mean logistic:  0.999863960448176
# beta4_mean:  0.9030371268298045
# beta4_logit_mean:  2.231435513142096
# beta4_mu:  2.231435513142097
# beta4_var:  10.31322574615478
# a:  1 b:  0.08589934592000005
# beta4_logit_samples_mean:  10.962254183106406
# beta4_logit_samples_mean logistic:  0.9999826561317172
# beta4_mean:  0.9208956647384071
# beta4_logit_mean:  2.454579064456306
# beta4_mu:  2.454579064456307
# beta4_var:  12.641532182693476
# a:  1 b:  0.06871947673600004
# beta4_logit_samples_mean:  13.111976361908013
# beta4_logit_samples_mean logistic:  0.9999979791217884
# beta4_mean:  0.9356992379835
# beta4_logit_mean:  2.6777226157705174
# beta4_mu:  2.6777226157705165
# beta4_var:  15.551915228366843
# a:  1 b:  0.054975581388800036
# beta4_logit_samples_mean:  15.206978209591023
# beta4_logit_samples_mean logistic:  0.9999997512900448
# beta4_mean:  0.9478892380462223
# beta4_logit_mean:  2.900866167084726
# beta4_mu:  2.900866167084726
# beta4_var:  19.18989403545855
# a:  1 b:  0.043980465111040035
# beta4_logit_samples_mean:  17.83850438402494
# beta4_logit_samples_mean logistic:  0.9999999821007032
# beta4_mean:  0.9578723294344763
# beta4_logit_mean:  3.1240097183989346
# beta4_mu:  3.124009718398936
# beta4_var:  23.737367544323188

# %%
plt.figure(figsize=(10,5))
plt.plot(betas, np.array(means_logit_samples) / np.array(means_logit))
#plt.plot(betas, np.log(np.array(means_logit_samples) / np.array(means_logit)))
#plt.plot(betas, beta_mus)
#plt.plot(betas, beta_vars)
#plt.plot(betas, np.array(beta_mus) / np.array(beta_vars))
plt.show();
# Out:
# <ipython-input-355-a8ced2fbb408>:2: RuntimeWarning: divide by zero encountered in true_divide
#   plt.plot(betas, np.array(means_logit_samples) / np.array(means_logit))

# %%
from scipy.stats import norm

# %%
# keep cov constant and change mean
cov = 0.2*np.eye(2)
x_ = np.linspace(0, 1, 1000+1)
x2_ = np.linspace(-5, 30, 1000+1)

for i in range(20):
    
    mu = np.array([i,-i])
    mu_c = correct_mu(mu, cov)
    cov_c = correct_Sigma(mu, cov)
    print("ratio: ", np.max(mu)/np.max(cov_c))
    kappa = logistic_transform(np.log(np.sqrt(np.max(cov_c))))
    print("kappa: ", kappa)
    #mu_c_std = mu_c.std()
    cov_c_diag_mean = np.diag(cov_c).mean()
    mu_cc =  mu_c / np.sqrt(cov_c_diag_mean + 1/(np.sqrt(cov_c_diag_mean)))
    cov_cc =  cov_c / (cov_c_diag_mean + 1/(np.sqrt(cov_c_diag_mean)))
    
    print("mu c: ", mu_c)
    print("Sigma c: ", cov_c)
    print("mu cc: ", mu_cc)
    print("Sigma cc: ", cov_cc)
    samples = mvnorm(mu, cov).rvs(1000)
    samples_sm = np.exp(samples) / np.exp(samples).sum(1).reshape(-1, 1)
    mean_samples_sm = np.mean(samples_sm, axis=0)[0]
    
    alpha_c = get_alpha_from_Normal(mu_c, cov_c)
    alpha_cc = get_alpha_from_Normal(mu_cc, cov_cc)
    print("alpha: ", alpha_c)
    print("alpha_cc: ", alpha_cc)
    beta_c = beta.pdf(x_, alpha_c[0], alpha_c[1])
    beta_cc = beta.pdf(x_, alpha_cc[0], alpha_cc[1])
    
    norm_c = norm.pdf(x2_, mu_c[0], cov_c[0,0])
    norm_cc = norm.pdf(x2_, mu_cc[0], cov_cc[0,0])
    beta_logit_c = beta_t_logit_pdf(x2_, alpha_c[0], alpha_c[1])
    beta_logit_cc = beta_t_logit_pdf(x2_, alpha_cc[0], alpha_cc[1])
    mean_beta_cc = alpha_cc[0] / alpha_cc.sum()
    mean_beta_cc_logit = logit_transform(mean_beta_cc)
    
    fig, ax = plt.subplots(1, 2, figsize=(15, 4))

    ax[0].hist(samples_sm[:,0], density=True, bins=100, range=[0,1], alpha=0.5)
    ax[0].axvline(mean_samples_sm, label="sample mean")
    ax[0].axvline(mean_beta_cc, color='red', label='mean beta cc')
    ax[0].set_xlim(0,1)
    ax[0].plot(x_, beta_c, label="beta c")
    ax[0].plot(x_, beta_cc, label="beta cc")
    ax[0].legend()
    
    ax[1].plot(x2_, norm_c, label="norm c", color='blue')
    ax[1].plot(x2_, norm_cc, label="norm cc")
    ax[1].plot(x2_, beta_logit_c, label="beta c")
    ax[1].plot(x2_, beta_logit_cc, label="beta cc")
    ax[1].axvline(mu_c[0], color='blue', label='mean norm c')
    ax[1].axvline(mean_beta_cc_logit, color='red', label='mean beta cc')
    ax[1].legend()
    plt.show();
    
# beta_cc should look like norm_c.
# Out:
# ratio:  0.0
# kappa:  0.24025307335204216
# mu c:  [0. 0.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [0. 0.]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [5. 5.]
# alpha_cc:  [16.3114 16.3114]
# ratio:  10.0
# kappa:  0.24025307335204216
# mu c:  [ 1. -1.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 0.5537 -0.5537]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [20.9726  2.8383]
# alpha_cc:  [32.8365 10.8507]
# ratio:  20.0
# kappa:  0.24025307335204216
# mu c:  [ 2. -2.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 1.1073 -1.1073]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [138.9954   2.5458]
# alpha_cc:  [82.8451  9.0463]
# ratio:  30.000000000000004
# kappa:  0.24025307335204216
# mu c:  [ 3. -3.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 1.661 -1.661]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [1011.072     2.5062]
# alpha_cc:  [234.1814   8.45  ]
# ratio:  40.0
# kappa:  0.24025307335204216
# mu c:  [ 4. -4.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 2.2146 -2.2146]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [7454.895     2.5008]
# alpha_cc:  [692.1568   8.2529]
# ratio:  50.00000000000001
# kappa:  0.24025307335204216
# mu c:  [ 5. -5.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 2.7683 -2.7683]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [55068.6645     2.5001]
# alpha_cc:  [2078.0862    8.1878]
# ratio:  60.00000000000001
# kappa:  0.24025307335204216
# mu c:  [ 6. -6.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 3.3219 -3.3219]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [406889.4785      2.5   ]
# alpha_cc:  [6272.1989    8.1663]
# ratio:  70.0
# kappa:  0.24025307335204216
# mu c:  [ 7. -7.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 3.8756 -3.8756]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [3006513.2104       2.5   ]
# alpha_cc:  [18964.4618     8.1592]
# ratio:  80.0
# kappa:  0.24025307335204216
# mu c:  [ 8. -8.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 4.4292 -4.4292]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [22215278.8013        2.5   ]
# alpha_cc:  [57373.9065     8.1569]
# ratio:  90.00000000000001
# kappa:  0.24025307335204216
# mu c:  [ 9. -9.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 4.9829 -4.9829]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [1.6415e+08 2.5000e+00]
# alpha_cc:  [173608.9272      8.1561]
# ratio:  100.00000000000001
# kappa:  0.24025307335204216
# mu c:  [ 10. -10.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 5.5366 -5.5366]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [1.2129e+09 2.5000e+00]
# alpha_cc:  [525360.4339      8.1558]
# ratio:  110.00000000000001
# kappa:  0.24025307335204216
# mu c:  [ 11. -11.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 6.0902 -6.0902]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [8.9623e+09 2.5000e+00]
# alpha_cc:  [1589834.1325       8.1557]
# ratio:  120.00000000000001
# kappa:  0.24025307335204216
# mu c:  [ 12. -12.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 6.6439 -6.6439]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [6.6223e+10 2.5000e+00]
# alpha_cc:  [4811154.3931       8.1557]
# ratio:  130.0
# kappa:  0.24025307335204216
# mu c:  [ 13. -13.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 7.1975 -7.1975]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [4.8932e+11 2.5000e+00]
# alpha_cc:  [14559543.8885        8.1557]
# ratio:  140.0
# kappa:  0.24025307335204216
# mu c:  [ 14. -14.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 7.7512 -7.7512]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [3.6156e+12 2.5000e+00]
# alpha_cc:  [44060211.3368        8.1557]
# ratio:  150.0
# kappa:  0.24025307335204216
# mu c:  [ 15. -15.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 8.3048 -8.3048]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [2.6716e+13 2.5000e+00]
# alpha_cc:  [1.3334e+08 8.1557e+00]
# ratio:  160.0
# kappa:  0.24025307335204216
# mu c:  [ 16. -16.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 8.8585 -8.8585]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [1.9741e+14 2.5000e+00]
# alpha_cc:  [4.0350e+08 8.1557e+00]
# ratio:  170.0
# kappa:  0.24025307335204216
# mu c:  [ 17. -17.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 9.4121 -9.4121]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [1.4587e+15 2.5000e+00]
# alpha_cc:  [1.2211e+09 8.1557e+00]
# ratio:  180.00000000000003
# kappa:  0.24025307335204216
# mu c:  [ 18. -18.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 9.9658 -9.9658]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [1.0778e+16 2.5000e+00]
# alpha_cc:  [3.6952e+09 8.1557e+00]
# ratio:  190.00000000000003
# kappa:  0.24025307335204216
# mu c:  [ 19. -19.]
# Sigma c:  [[ 0.1 -0.1]
#  [-0.1  0.1]]
# mu cc:  [ 10.5195 -10.5195]
# Sigma cc:  [[ 0.0307 -0.0307]
#  [-0.0307  0.0307]]
# alpha:  [7.964e+16 2.500e+00]
# alpha_cc:  [1.1183e+10 8.1557e+00]

# %%
# keep mean constant and change cov
base_cov = np.eye(2)
x_ = np.linspace(0, 1, 1000+1)
#mu = np.array([0,0])
mu = np.array([5, -5])

for i in range(20):
    
    cov = (i+1) * 2 * base_cov
    mu_c = correct_mu(mu, cov)
    cov_c = correct_Sigma(mu, cov)
    print("mu: ", mu_c)
    print("Sigma: ", cov_c)
    mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
    cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
    samples = mvnorm(mu_c, cov).rvs(1000)
    samples_sm = np.exp(samples) / np.exp(samples).sum(1).reshape(-1, 1)
    
    alpha_c = get_alpha_from_Normal(mu_c, cov_c)
    alpha_cc = get_alpha_from_Normal(mu_cc, cov_cc)
    print("alpha: ", alpha_c)
    print("alpha_cc: ", alpha_cc)
    beta_c = beta.pdf(x_, alpha_c[0], alpha_c[1])
    beta_cc = beta.pdf(x_, alpha_cc[0], alpha_cc[1])
    
    plt.figure(figsize=(10, 4))

    plt.hist(samples_sm[:,0], density=True, bins=100, range=[0,1], alpha=0.5)
    plt.xlim(0,1)
    plt.plot(x_, beta_c)
    plt.plot(x_, beta_cc)
    plt.show();
    
## looks kinda good
# Out:
# mu:  [ 5. -5.]
# Sigma:  [[ 1. -1.]
#  [-1.  1.]]
# alpha:  [5506.8664    0.25  ]
# alpha_cc:  [589.2023   0.5004]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 2. -2.]
#  [-2.  2.]]
# alpha:  [2753.4332    0.125 ]
# alpha_cc:  [147.9008   0.3392]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 3. -3.]
#  [-3.  3.]]
# alpha:  [1835.6221    0.0833]
# alpha_cc:  [59.2568  0.2996]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 4. -4.]
#  [-4.  4.]]
# alpha:  [1376.7166    0.0625]
# alpha_cc:  [31.6413  0.2838]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 5. -5.]
#  [-5.  5.]]
# alpha:  [1101.3733    0.05  ]
# alpha_cc:  [20.039   0.2761]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 6. -6.]
#  [-6.  6.]]
# alpha:  [917.8111   0.0417]
# alpha_cc:  [14.1385  0.2721]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 7. -7.]
#  [-7.  7.]]
# alpha:  [786.6952   0.0357]
# alpha_cc:  [10.7266  0.2701]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 8. -8.]
#  [-8.  8.]]
# alpha:  [688.3583   0.0313]
# alpha_cc:  [8.566  0.2693]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 9. -9.]
#  [-9.  9.]]
# alpha:  [611.874    0.0278]
# alpha_cc:  [7.103  0.2691]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 10. -10.]
#  [-10.  10.]]
# alpha:  [550.6866   0.025 ]
# alpha_cc:  [6.0603 0.2694]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 11. -11.]
#  [-11.  11.]]
# alpha:  [500.6242   0.0227]
# alpha_cc:  [5.2866 0.27  ]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 12. -12.]
#  [-12.  12.]]
# alpha:  [458.9055   0.0208]
# alpha_cc:  [4.6936 0.2708]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 13. -13.]
#  [-13.  13.]]
# alpha:  [423.6051   0.0192]
# alpha_cc:  [4.227  0.2717]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 14. -14.]
#  [-14.  14.]]
# alpha:  [393.3476   0.0179]
# alpha_cc:  [3.8517 0.2728]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 15. -15.]
#  [-15.  15.]]
# alpha:  [367.1244   0.0167]
# alpha_cc:  [3.5441 0.274 ]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 16. -16.]
#  [-16.  16.]]
# alpha:  [344.1792   0.0156]
# alpha_cc:  [3.288  0.2752]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 17. -17.]
#  [-17.  17.]]
# alpha:  [323.9333   0.0147]
# alpha_cc:  [3.0718 0.2764]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 18. -18.]
#  [-18.  18.]]
# alpha:  [305.937    0.0139]
# alpha_cc:  [2.8871 0.2776]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 19. -19.]
#  [-19.  19.]]
# alpha:  [289.8351   0.0132]
# alpha_cc:  [2.7278 0.2789]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu:  [ 5. -5.]
# Sigma:  [[ 20. -20.]
#  [-20.  20.]]
# alpha:  [275.3433   0.0125]
# alpha_cc:  [2.5889 0.2802]
# <ipython-input-358-537fed08d389>:14: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-358-537fed08d389>:15: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))

# %%
# change mean and cov
base_cov = 1*np.eye(2)
x_ = np.linspace(0, 1, 1000+1)


for i in range(20):
    
    mu = np.array([i/5, -i/5])
    cov = (i+1) * 5 * base_cov
    
    mu_c = correct_mu(mu, cov)
    cov_c = correct_Sigma(mu, cov)
    mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
    cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
    print("mu_c: ", mu_c)
    print("Sigma_c: ", cov_c)
    print("mu_cc: ", mu_cc)
    print("Sigma_cc: ", cov_cc)
    samples = mvnorm(mu, cov).rvs(1000)
    samples_sm = np.exp(samples) / np.exp(samples).sum(1).reshape(-1, 1)
    
    alpha_c = get_alpha_from_Normal(mu_c, cov_c)
    alpha_cc = get_alpha_from_Normal(mu_cc, cov_cc)
    print("alpha: ", alpha_c)
    print("alpha_cc: ", alpha_cc)
    beta_c = beta.pdf(x_, alpha_c[0], alpha_c[1])
    beta_cc = beta.pdf(x_, alpha_cc[0], alpha_cc[1])
    
    plt.figure(figsize=(10, 4))

    plt.hist(samples_sm[:,0], density=True, bins=100, range=[0,1], alpha=0.5)
    plt.axvline(samples_sm.mean(0)[0], label='sample mean')
    plt.axvline(alpha_cc[0] / alpha_cc.sum(), color='red', label='beta_cc mean')
    plt.xlim(0,1)
    plt.plot(x_, beta_c)
    plt.plot(x_, beta_cc)
    plt.show();
# Out:
# mu_c:  [0. 0.]
# Sigma_c:  [[ 2.5 -2.5]
#  [-2.5  2.5]]
# mu_cc:  [0. 0.]
# Sigma_cc:  [[0.7981    nan]
#  [   nan 0.7981]]
# alpha:  [0.2 0.2]
# alpha_cc:  [0.6265 0.6265]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 0.2 -0.2]
# Sigma_c:  [[ 5. -5.]
#  [-5.  5.]]
# mu_cc:  [ 0.0857 -0.0857]
# Sigma_cc:  [[0.9179    nan]
#  [   nan 0.9179]]
# alpha:  [0.1246 0.0835]
# alpha_cc:  [0.5956 0.5018]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 0.4 -0.4]
# Sigma_c:  [[ 7.5 -7.5]
#  [-7.5  7.5]]
# mu_cc:  [ 0.1426 -0.1426]
# Sigma_cc:  [[0.9536    nan]
#  [   nan 0.9536]]
# alpha:  [0.1075 0.0483]
# alpha_cc:  [0.6109 0.4593]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 0.6 -0.6]
# Sigma_c:  [[ 10. -10.]
#  [-10.  10.]]
# mu_cc:  [ 0.1868 -0.1868]
# Sigma_cc:  [[0.9693    nan]
#  [   nan 0.9693]]
# alpha:  [0.108  0.0325]
# alpha_cc:  [0.6326 0.4354]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 0.8 -0.8]
# Sigma_c:  [[ 12.5 -12.5]
#  [-12.5  12.5]]
# mu_cc:  [ 0.2238 -0.2238]
# Sigma_cc:  [[0.9779    nan]
#  [   nan 0.9779]]
# alpha:  [0.1191 0.024 ]
# alpha_cc:  [0.6556 0.4191]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 1. -1.]
# Sigma_c:  [[ 15. -15.]
#  [-15.  15.]]
# mu_cc:  [ 0.256 -0.256]
# Sigma_cc:  [[0.9831    nan]
#  [   nan 0.9831]]
# alpha:  [0.1398 0.0189]
# alpha_cc:  [0.6786 0.4067]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 1.2 -1.2]
# Sigma_c:  [[ 17.5 -17.5]
#  [-17.5  17.5]]
# mu_cc:  [ 0.2849 -0.2849]
# Sigma_cc:  [[0.9865    nan]
#  [   nan 0.9865]]
# alpha:  [0.1718 0.0156]
# alpha_cc:  [0.7014 0.3968]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 1.4 -1.4]
# Sigma_c:  [[ 20. -20.]
#  [-20.  20.]]
# mu_cc:  [ 0.3113 -0.3113]
# Sigma_cc:  [[0.9889    nan]
#  [   nan 0.9889]]
# alpha:  [0.2181 0.0133]
# alpha_cc:  [0.724  0.3884]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 1.6 -1.6]
# Sigma_c:  [[ 22.5 -22.5]
#  [-22.5  22.5]]
# mu_cc:  [ 0.3357 -0.3357]
# Sigma_cc:  [[0.9907    nan]
#  [   nan 0.9907]]
# alpha:  [0.2837 0.0116]
# alpha_cc:  [0.7462 0.3813]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 1.8 -1.8]
# Sigma_c:  [[ 25. -25.]
#  [-25.  25.]]
# mu_cc:  [ 0.3586 -0.3586]
# Sigma_cc:  [[0.9921    nan]
#  [   nan 0.9921]]
# alpha:  [0.376  0.0103]
# alpha_cc:  [0.7682 0.375 ]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 2. -2.]
# Sigma_c:  [[ 27.5 -27.5]
#  [-27.5  27.5]]
# mu_cc:  [ 0.3801 -0.3801]
# Sigma_cc:  [[0.9931    nan]
#  [   nan 0.9931]]
# alpha:  [0.5054 0.0093]
# alpha_cc:  [0.7901 0.3694]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 2.2 -2.2]
# Sigma_c:  [[ 30. -30.]
#  [-30.  30.]]
# mu_cc:  [ 0.4004 -0.4004]
# Sigma_cc:  [[0.994   nan]
#  [  nan 0.994]]
# alpha:  [0.6871 0.0084]
# alpha_cc:  [0.8118 0.3644]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 2.4 -2.4]
# Sigma_c:  [[ 32.5 -32.5]
#  [-32.5  32.5]]
# mu_cc:  [ 0.4199 -0.4199]
# Sigma_cc:  [[0.9946    nan]
#  [   nan 0.9946]]
# alpha:  [0.9424 0.0078]
# alpha_cc:  [0.8334 0.3599]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 2.6 -2.6]
# Sigma_c:  [[ 35. -35.]
#  [-35.  35.]]
# mu_cc:  [ 0.4384 -0.4384]
# Sigma_cc:  [[0.9952    nan]
#  [   nan 0.9952]]
# alpha:  [1.3019 0.0072]
# alpha_cc:  [0.8549 0.3557]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 2.8 -2.8]
# Sigma_c:  [[ 37.5 -37.5]
#  [-37.5  37.5]]
# mu_cc:  [ 0.4562 -0.4562]
# Sigma_cc:  [[0.9957    nan]
#  [   nan 0.9957]]
# alpha:  [1.8095 0.0067]
# alpha_cc:  [0.8764 0.3519]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 3. -3.]
# Sigma_c:  [[ 40. -40.]
#  [-40.  40.]]
# mu_cc:  [ 0.4734 -0.4734]
# Sigma_cc:  [[0.9961    nan]
#  [   nan 0.9961]]
# alpha:  [2.5277 0.0063]
# alpha_cc:  [0.8979 0.3484]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 3.2 -3.2]
# Sigma_c:  [[ 42.5 -42.5]
#  [-42.5  42.5]]
# mu_cc:  [ 0.49 -0.49]
# Sigma_cc:  [[0.9964    nan]
#  [   nan 0.9964]]
# alpha:  [3.5461 0.0059]
# alpha_cc:  [0.9194 0.3451]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 3.4 -3.4]
# Sigma_c:  [[ 45. -45.]
#  [-45.  45.]]
# mu_cc:  [ 0.506 -0.506]
# Sigma_cc:  [[0.9967    nan]
#  [   nan 0.9967]]
# alpha:  [4.9936 0.0056]
# alpha_cc:  [0.9409 0.342 ]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 3.6 -3.6]
# Sigma_c:  [[ 47.5 -47.5]
#  [-47.5  47.5]]
# mu_cc:  [ 0.5215 -0.5215]
# Sigma_cc:  [[0.997   nan]
#  [  nan 0.997]]
# alpha:  [7.0549 0.0053]
# alpha_cc:  [0.9624 0.3391]
# <ipython-input-359-48a189c56a59>:13: RuntimeWarning: invalid value encountered in sqrt
#   mu_cc = mu_c / np.sqrt(np.diag(cov_c + 1/(np.sqrt(cov_c))))
# <ipython-input-359-48a189c56a59>:14: RuntimeWarning: invalid value encountered in sqrt
#   cov_cc = cov_c / (cov_c + 1/(np.sqrt(cov_c)))
# mu_c:  [ 3.8 -3.8]
# Sigma_c:  [[ 50. -50.]
#  [-50.  50.]]
# mu_cc:  [ 0.5366 -0.5366]
# Sigma_cc:  [[0.9972    nan]
#  [   nan 0.9972]]
# alpha:  [9.996 0.005]
# alpha_cc:  [0.984  0.3364]

# %%
# in dist sample; we expect alpha_0 << alpha_1 or alpha_1 << alpha_0

mu_real2 = np.array([ -2.4562,   2.4562] )
Sigma_real2 = np.array([[   5.2452,   -5.2452],
                        [  -5.2452,    5.2452]])

mu_real2_c = correct_mu(mu_real2, Sigma_real2)
Sigma_real2_c = correct_Sigma(mu_real2, Sigma_real2)

print(mu_real2_c)
print(Sigma_real2_c)

alpha_real2 = get_alpha_from_Normal(mu_real2, Sigma_real2)
alpha_real2_full = get_alpha_from_Normal_full(mu_real2, Sigma_real2)
print(alpha_real2)
print(alpha_real2_full)

alpha_real2_c = get_alpha_from_Normal(mu_real2_c, Sigma_real2_c)
alpha_real2_c_alt = get_alpha_from_Normal2(mu_real2_c, Sigma_real2_c)
alpha_real2_c_full = get_alpha_from_Normal_full(mu_real2_c, Sigma_real2_c)
print("alpha: ", alpha_real2_c)
print("alpha alt: ", alpha_real2_c_alt)
#print(alpha_real2_c_full)

print("mean2: ", alpha_real2 / alpha_real2.sum())
print("mean2_c: ", alpha_real2_c / alpha_real2_c.sum())

alpha_real2_cc = correct_alpha(alpha_real2_c, kappa=0.9)
print("after alpha2 correction: ", alpha_real2_cc)
# Out:
# [nan nan]
# [[nan nan]
#  [nan nan]]
# [0.048  6.5281]
# [0.048  6.5281]
# alpha:  [nan nan]
# alpha alt:  [nan nan]
# mean2:  [0.0073 0.9927]
# mean2_c:  [nan nan]
# after alpha2 correction:  [nan nan]
# <ipython-input-8-5f37d3c0b954>:34: RuntimeWarning: invalid value encountered in true_divide
#   return(mu - Sigma.sum(0) * mu.sum() / Sigma.sum())
# <ipython-input-8-5f37d3c0b954>:37: RuntimeWarning: invalid value encountered in true_divide
#   return(Sigma - np.outer(Sigma.sum(0), Sigma.sum(1)) / Sigma.sum())

# %% [markdown]
# # whats the role of K?

# %%
from scipy.stats import multivariate_normal as mvnorm

# %%
def mu_sigma_cc(mu_c, cov_c):
    cov_c_diag = np.diag(cov_c)
    cov_c_diag_mean = np.diag(cov_c).mean()
    #mu_cc = mu_c / np.sqrt(cov_c_diag + 1/(np.sqrt(cov_c_diag)))
    #cov_cc = cov_c / (cov_c_diag + 1/(np.sqrt(cov_c_diag)))
    mu_cc = mu_c / np.sqrt(1 + )
    #cov_c_diag = np.diag(cov_c)
    #ratio = np.sqrt(np.mean(cov_c_diag)) / (np.max(mu_c)-np.min(mu_c))
    #print("ratio: ", ratio)
#   # p = 1 / (1 + np.exp(-np.log(ratio)))
    #p = 1 / (1 + np.exp(-ratio+1))
    #print("p: ", p)
    #mean_dist = np.max(mu_c)# - np.min(mu_c)
    #mu_cc = (1-p) * mu_c / np.sqrt(mean_dist) + p * mu_c/ np.sqrt(cov_c_diag)
    #cov_cc = (1-p) * cov_c / mean_dist + p * cov_c/ cov_c_diag
    return(mu_cc, cov_cc)

# TODO: alternative without the mean adaption

# %%
#mu_real1 = np.array([ 6.4000, -8.4087])
#Sigma_real1 = np.array([[13975.7568, 0.0000],
#                        [0.0000, 13975.7529]])
mu_K1 = np.array([5, -5])
Sigma_K1 = 1* np.eye(2)

mu_K1_c = correct_mu(mu_K1, Sigma_K1)
Sigma_K1_c = correct_Sigma(mu_K1, Sigma_K1)
print("mu_K1_c: ", mu_K1_c)
print("Sigma_K1_c: ", Sigma_K1_c)

mu_K1_cc, Sigma_K1_cc = mu_sigma_cc(mu_K1_c, Sigma_K1_c)
print("mu_K1_cc: ", mu_K1_cc)
print("Sigma_K1_cc: ", Sigma_K1_cc)

alpha_K1_c = get_alpha_from_Normal(mu_K1_c, Sigma_K1_c)
print("alpha c: ", alpha_K1_c)
print("alpha c mean: ", alpha_K1_c/alpha_K1_c.sum())
alpha_K1_cc = get_alpha_from_Normal(mu_K1_cc, Sigma_K1_cc)
print("alpha cc: ", alpha_K1_cc)
print("alpha cc mean: ", alpha_K1_cc/alpha_K1_cc.sum())

samples_K1 = mvnorm(mu_K1, Sigma_K1).rvs(10000)
samples_K1_sm = np.exp(samples_K1) / np.exp(samples_K1).sum(1).reshape(-1, 1)
print("softmax mean: ", samples_K1_sm.mean(0))
# Out:
# mu_K1_c:  [ 5. -5.]
# Sigma_K1_c:  [[ 0.5 -0.5]
#  [-0.5  0.5]]
# mu_K1_cc:  [ 3.6139 -3.6139]
# Sigma_K1_cc:  [[ 0.2612 -0.2612]
#  [-0.2612  0.2612]]
# alpha c:  [11013.7329     0.5   ]
# alpha c mean:  [1. 0.]
# alpha cc:  [1319.0454    0.9578]
# alpha cc mean:  [0.9993 0.0007]
# softmax mean:  [0.9999 0.0001]

# %%
#mu_real1 = np.array([ 6.4000, -8.4087])
#Sigma_real1 = np.array([[13975.7568, 0.0000],
#                        [0.0000, 13975.7529]])
mu_K1 = np.array([-0.7905, -0.9332, -1.2690, 10.5045, -1.5546,  0.2726, -1.2620, -1.6381,-1.6235, -1.7063])
Sigma_K1 = np.array([[ 3.2606, -0.4161, -0.1790, -0.4349, -0.4699, -0.5202, -0.4494, -0.5012,
          0.0200, -0.3099],
        [-0.4161,  3.9552, -0.5869, -0.5756, -0.6580, -0.6232, -0.5139, -0.6391,
         -0.2174,  0.2752],
        [-0.1790, -0.5869,  3.1958, -0.2689, -0.1786, -0.3279, -0.2783, -0.3555,
         -0.4697, -0.5508],
        [-0.4349, -0.5756, -0.2689,  2.7029, -0.2256,  0.3011, -0.2345, -0.2283,
         -0.5333, -0.5029],
        [-0.4699, -0.6580, -0.1786, -0.2256,  3.3719, -0.1773, -0.3391, -0.1216,
         -0.5848, -0.6170],
        [-0.5202, -0.6232, -0.3279,  0.3011, -0.1773,  3.0037, -0.3620, -0.1397,
         -0.5931, -0.5614],
        [-0.4494, -0.5140, -0.2783, -0.2345, -0.3391, -0.3620,  3.7240, -0.4921,
         -0.5095, -0.5451],
        [-0.5012, -0.6391, -0.3555, -0.2283, -0.1216, -0.1397, -0.4921,  3.6577,
         -0.6042, -0.5759],
        [ 0.0200, -0.2174, -0.4698, -0.5333, -0.5848, -0.5931, -0.5095, -0.6042,
          3.6229, -0.1309],
        [-0.3099,  0.2752, -0.5508, -0.5029, -0.6170, -0.5614, -0.5451, -0.5759,
         -0.1309,  3.5187]])

mu_K1_c = correct_mu(mu_K1, Sigma_K1)
Sigma_K1_c = correct_Sigma(mu_K1, Sigma_K1)
print("mu_K1_c: ", mu_K1_c)
print("Sigma_K1_c: ", Sigma_K1_c)

mu_K1_cc, Sigma_K1_cc = mu_sigma_cc(mu_K1_c, Sigma_K1_c)
print("mu_K1_cc: ", mu_K1_cc)
print("Sigma_K1_cc: ", Sigma_K1_cc)

alpha_K1_c = get_alpha_from_Normal(mu_K1_c, Sigma_K1_c)
print("alpha c: ", alpha_K1_c)
print("alpha c mean: ", alpha_K1_c/alpha_K1_c.sum())
alpha_K1_cc = get_alpha_from_Normal(mu_K1_cc, Sigma_K1_cc)
print("alpha cc: ", alpha_K1_cc)
print("alpha cc mean: ", alpha_K1_cc/alpha_K1_cc.sum())

samples_K1 = mvnorm(mu_K1, Sigma_K1).rvs(10000)
samples_K1_sm = np.exp(samples_K1) / np.exp(samples_K1).sum(1).reshape(-1, 1)
print("softmax mean: ", samples_K1_sm.mean(0))
# Out:
# mu_K1_c:  [-0.7905 -0.9332 -1.269  10.5045 -1.5546  0.2726 -1.262  -1.6381 -1.6235
#  -1.7063]
# Sigma_K1_c:  [[ 3.2606 -0.4161 -0.179  -0.4349 -0.4699 -0.5202 -0.4494 -0.5012  0.02
#   -0.3099]
#  [-0.4161  3.9552 -0.5869 -0.5756 -0.658  -0.6232 -0.5139 -0.6391 -0.2174
#    0.2752]
#  [-0.179  -0.5869  3.1958 -0.2689 -0.1786 -0.3279 -0.2783 -0.3555 -0.4697
#   -0.5508]
#  [-0.4349 -0.5756 -0.2689  2.7029 -0.2256  0.3011 -0.2345 -0.2283 -0.5333
#   -0.5029]
#  [-0.4699 -0.658  -0.1786 -0.2256  3.3719 -0.1773 -0.3391 -0.1216 -0.5848
#   -0.617 ]
#  [-0.5202 -0.6232 -0.3279  0.3011 -0.1773  3.0037 -0.362  -0.1397 -0.5931
#   -0.5614]
#  [-0.4494 -0.514  -0.2784 -0.2345 -0.3391 -0.362   3.724  -0.4921 -0.5095
#   -0.5451]
#  [-0.5012 -0.6392 -0.3556 -0.2283 -0.1216 -0.1397 -0.4921  3.6577 -0.6042
#   -0.5759]
#  [ 0.02   -0.2174 -0.4698 -0.5333 -0.5848 -0.5931 -0.5095 -0.6042  3.6229
#   -0.1309]
#  [-0.3099  0.2752 -0.5508 -0.5029 -0.617  -0.5614 -0.5451 -0.5759 -0.1309
#    3.5187]]
# mu_K1_cc:  [-0.3981 -0.4699 -0.639   5.2897 -0.7828  0.1373 -0.6355 -0.8249 -0.8175
#  -0.8592]
# Sigma_K1_cc:  [[ 0.8268 -0.1055 -0.0454 -0.1103 -0.1192 -0.1319 -0.114  -0.1271  0.0051
#   -0.0786]
#  [-0.1055  1.0029 -0.1488 -0.146  -0.1669 -0.158  -0.1303 -0.1621 -0.0551
#    0.0698]
#  [-0.0454 -0.1488  0.8104 -0.0682 -0.0453 -0.0831 -0.0706 -0.0902 -0.1191
#   -0.1397]
#  [-0.1103 -0.146  -0.0682  0.6854 -0.0572  0.0764 -0.0595 -0.0579 -0.1352
#   -0.1275]
#  [-0.1192 -0.1669 -0.0453 -0.0572  0.855  -0.045  -0.086  -0.0308 -0.1483
#   -0.1565]
#  [-0.1319 -0.158  -0.0831  0.0764 -0.045   0.7617 -0.0918 -0.0354 -0.1504
#   -0.1424]
#  [-0.114  -0.1304 -0.0706 -0.0595 -0.086  -0.0918  0.9443 -0.1248 -0.1292
#   -0.1382]
#  [-0.1271 -0.1621 -0.0902 -0.0579 -0.0308 -0.0354 -0.1248  0.9275 -0.1532
#   -0.146 ]
#  [ 0.0051 -0.0551 -0.1191 -0.1352 -0.1483 -0.1504 -0.1292 -0.1532  0.9187
#   -0.0332]
#  [-0.0786  0.0698 -0.1397 -0.1275 -0.1565 -0.1424 -0.1382 -0.146  -0.0332
#    0.8923]]
# alpha c:  [   0.2913    0.2351    0.2794 4461.6347    0.258     0.4109    0.24
#     0.2363    0.2388    0.2444]
# alpha c mean:  [0.0001 0.0001 0.0001 0.9995 0.0001 0.0001 0.0001 0.0001 0.0001 0.0001]
# alpha cc:  [ 1.1044  0.9026  1.0969 49.8961  1.0257  1.304   0.9416  0.9421  0.9518
#   0.9765]
# alpha cc mean:  [0.0187 0.0153 0.0185 0.8437 0.0173 0.022  0.0159 0.0159 0.0161 0.0165]
# softmax mean:  [0.0003 0.0005 0.0002 0.9978 0.0001 0.0004 0.0002 0.0001 0.0002 0.0001]
# /home/marius/anaconda3/lib/python3.9/site-packages/scipy/stats/_multivariate.py:653: RuntimeWarning: covariance is not positive-semidefinite.
#   out = random_state.multivariate_normal(mean, cov, size)

# %%
mu_K2 = np.array([7, 2, -7])
#Sigma_K2 = 140 * np.eye(3)
Sigma_K2 = np.array([[30, 0, 0],
                     [0, 2, 0],
                     [0, 0, 1]])

mu_K2_c = correct_mu(mu_K2, Sigma_K2)
Sigma_K2_c = correct_Sigma(mu_K2, Sigma_K2)
print("mu_K2_c: ", mu_K2_c)
print("Sigma_K2_c: ", Sigma_K2_c)

mu_K2_cc, Sigma_K2_cc = mu_sigma_cc(mu_K2_c, Sigma_K2_c)
print("mu_K2_cc: ", mu_K2_cc)
print("Sigma_K2_cc: ", Sigma_K2_cc)

alpha_K2_c = get_alpha_from_Normal(mu_K2_c, Sigma_K2_c)
print("alpha c: ", alpha_K2_c)
print("alpha c mean: ", alpha_K2_c / alpha_K2_c.sum())
alpha_K2_cc = get_alpha_from_Normal(mu_K2_cc, Sigma_K2_cc)
print("alpha cc: ", alpha_K2_cc)
print("alpha cc mean: ", alpha_K2_cc/alpha_K2_cc.sum())

samples_K2 = mvnorm(mu_K2, Sigma_K2).rvs(10000)
samples_K2_sm = np.exp(samples_K2) / np.exp(samples_K2).sum(1).reshape(-1, 1)
print("softmax mean: ", samples_K2_sm.mean(0))
# Out:
# mu_K2_c:  [ 5.1818  1.8788 -7.0606]
# Sigma_K2_c:  [[ 2.7273 -1.8182 -0.9091]
#  [-1.8182  1.8788 -0.0606]
#  [-0.9091 -0.0606  0.9697]]
# mu_K2_cc:  [ 3.2185  1.1669 -4.3855]
# Sigma_K2_cc:  [[ 1.0521 -0.7014 -0.3507]
#  [-0.7014  0.7248 -0.0234]
#  [-0.3507 -0.0234  0.3741]]
# alpha c:  [8451.0667  451.2726    0.4583]
# alpha c mean:  [0.9493 0.0507 0.0001]
# alpha cc:  [213.1053  40.1619   1.1893]
# alpha cc mean:  [0.8375 0.1578 0.0047]
# softmax mean:  [0.7943 0.2056 0.0001]

# %%
mu_K3 = np.array([7, 7, 7, -7])
Sigma_K3 = 140 * np.eye(4)

mu_K3_c = correct_mu(mu_K3, Sigma_K3)
Sigma_K3_c = correct_Sigma(mu_K3, Sigma_K3)
print("mu_K3_c: ", mu_K3_c)
print("Sigma_K3_c: ", Sigma_K3_c)

mu_K3_cc, Sigma_K3_cc = mu_sigma_cc(mu_K3_c, Sigma_K3_c)

alpha_K3_c = get_alpha_from_Normal(mu_K3_c, Sigma_K3_c)
print("alpha c: ", alpha_K3_c)
print("alpha c mean: ", alpha_K3_c / alpha_K3_c.sum())
alpha_K3_cc = get_alpha_from_Normal(mu_K3_cc, Sigma_K3_cc)
print("alpha cc: ", alpha_K3_cc)
print("alpha cc mean: ", alpha_K3_cc/alpha_K3_cc.sum())

samples_K3 = mvnorm(mu_K3, Sigma_K3).rvs(10000)
samples_K3_sm = np.exp(samples_K3) / np.exp(samples_K3).sum(1).reshape(-1, 1)
print("softmax mean: ", samples_K3_sm.mean(0))
# Out:
# mu_K3_c:  [  3.5   3.5   3.5 -10.5]
# Sigma_K3_c:  [[105. -35. -35. -35.]
#  [-35. 105. -35. -35.]
#  [-35. -35. 105. -35.]
#  [-35. -35. -35. 105.]]
# alpha c:  [715.8424 715.8424 715.8424   0.0054]
# alpha c mean:  [0.3333 0.3333 0.3333 0.    ]
# alpha cc:  [0.9333 0.9333 0.9333 0.6109]
# alpha cc mean:  [0.2736 0.2736 0.2736 0.1791]
# softmax mean:  [0.3229 0.3162 0.3086 0.0522]

# %%
mu_K4 = np.array([7, 0, 2, 0, -7])
Sigma_K4 = 140 * np.eye(5)

mu_K4_c = correct_mu(mu_K4, Sigma_K4)
Sigma_K4_c = correct_Sigma(mu_K4, Sigma_K4)
print("mu_K4_c: ", mu_K4_c)
print("Sigma_K4_c: ", Sigma_K4_c)

mu_K4_cc, Sigma_K4_cc = mu_sigma_cc(mu_K4_c, Sigma_K4_c)

alpha_K4_c = get_alpha_from_Normal(mu_K4_c, Sigma_K4_c)
print("alpha c: ", alpha_K4_c)
print("alpha c mean: ", alpha_K4_c / alpha_K4_c.sum())
alpha_K4_cc = get_alpha_from_Normal(mu_K4_cc, Sigma_K4_cc)
print("alpha cc: ", alpha_K4_cc)
print("alpha cc mean: ", alpha_K4_cc/alpha_K4_cc.sum())

samples_K4 = mvnorm(mu_K4, Sigma_K4).rvs(10000)
samples_K4_sm = np.exp(samples_K4) / np.exp(samples_K4).sum(1).reshape(-1, 1)
print("softmax mean: ", samples_K4_sm.mean(0))
# Out:
# mu_K4_c:  [ 6.6 -0.4  1.6 -0.4 -7.4]
# Sigma_K4_c:  [[112. -28. -28. -28. -28.]
#  [-28. 112. -28. -28. -28.]
#  [-28. -28. 112. -28. -28.]
#  [-28. -28. -28. 112. -28.]
#  [-28. -28. -28. -28. 112.]]
# alpha c:  [430.3436   0.3978   2.905    0.3978   0.0057]
# alpha c mean:  [0.9915 0.0009 0.0067 0.0009 0.    ]
# alpha cc:  [1.01   0.8119 0.8559 0.8119 0.7097]
# alpha cc mean:  [0.2405 0.1933 0.2038 0.1933 0.169 ]
# softmax mean:  [0.3795 0.1747 0.2134 0.1667 0.0658]

# %%
mu_K5 = np.array([7, 0, 0, 0, 0, 7, 0, 0, 0, -7])
Sigma_K5 = 140 * np.eye(10)

mu_K5_c = correct_mu(mu_K5, Sigma_K5)
Sigma_K5_c = correct_Sigma(mu_K5, Sigma_K5)
print("mu_K5_c: ", mu_K5_c)
print("Sigma_K5_c: ", Sigma_K5_c)

mu_K5_cc, Sigma_K5_cc = mu_sigma_cc(mu_K5_c, Sigma_K5_c)

alpha_K5_c = get_alpha_from_Normal(mu_K5_c, Sigma_K5_c)
print("alpha c: ", alpha_K5_c)
print("alpha c mean: ", alpha_K5_c/alpha_K5_c.sum())
alpha_K5_cc = get_alpha_from_Normal(mu_K5_cc, Sigma_K5_cc)
print("alpha cc: ", alpha_K5_cc)
print("alpha cc mean: ", alpha_K5_cc/alpha_K5_cc.sum())

samples_K5 = mvnorm(mu_K5, Sigma_K5).rvs(10000)
samples_K5_sm = np.exp(samples_K5) / np.exp(samples_K5).sum(1).reshape(-1, 1)
print("softmax mean: ", samples_K5_sm.mean(0))
# Out:
# mu_K5_c:  [ 6.3 -0.7 -0.7 -0.7 -0.7  6.3 -0.7 -0.7 -0.7 -7.7]
# Sigma_K5_c:  [[126. -14. -14. -14. -14. -14. -14. -14. -14. -14.]
#  [-14. 126. -14. -14. -14. -14. -14. -14. -14. -14.]
#  [-14. -14. 126. -14. -14. -14. -14. -14. -14. -14.]
#  [-14. -14. -14. 126. -14. -14. -14. -14. -14. -14.]
#  [-14. -14. -14. -14. 126. -14. -14. -14. -14. -14.]
#  [-14. -14. -14. -14. -14. 126. -14. -14. -14. -14.]
#  [-14. -14. -14. -14. -14. -14. 126. -14. -14. -14.]
#  [-14. -14. -14. -14. -14. -14. -14. 126. -14. -14.]
#  [-14. -14. -14. -14. -14. -14. -14. -14. 126. -14.]
#  [-14. -14. -14. -14. -14. -14. -14. -14. -14. 126.]]
# alpha c:  [96.0605  0.0939  0.0939  0.0939  0.0939 96.0605  0.0939  0.0939  0.0939
#   0.0064]
# alpha c mean:  [0.4983 0.0005 0.0005 0.0005 0.0005 0.4983 0.0005 0.0005 0.0005 0.    ]
# alpha cc:  [0.9861 0.9    0.9    0.9    0.9    0.9861 0.9    0.9    0.9    0.8539]
# alpha cc mean:  [0.108  0.0986 0.0986 0.0986 0.0986 0.108  0.0986 0.0986 0.0986 0.0936]
# softmax mean:  [0.2031 0.0842 0.0796 0.0812 0.0797 0.2076 0.0812 0.0829 0.0757 0.0247]

# %%
break
# Out:
#   File "/tmp/ipykernel_2533/668683560.py", line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %% [markdown]
# # make the plots

# %% [markdown]
# ## Plot 1: show the plots for 3 matrices

# %%
#Tests for the paper

num_samples = 100000
nlevels=200
subdiv=5

MUs_3s = [[0,0,0],
       [-1,-1,2],
       [-2,1,1]]
MUs_3s_vis = np.around(MUs_3s, 2)
SIGMAs_3s = [5*np.eye(3),
          0.1*np.array([[ 9.5938,  1.4385,  2.5147],
         [ 1.4385,  9.5551,  2.5534],
         [ 2.5147,  2.5534,  8.4789]]),
         0.1*np.array([[17.7842,  1.4664,  2.7132],
         [ 1.4664, 17.7394,  2.7580],
         [ 2.7132,  2.7580, 16.4925]])]
SIGMAs_3s_vis = np.around(SIGMAs_3s, 2)

ALPHAs_3s = [get_alpha_from_Normal(m,s) for m,s in zip(MUs_3s, SIGMAs_3s)]
ALPHAs_3s_vis = np.around(ALPHAs_3s, 2)

cols = ['Softmax(Gaussian) histogram', 'Dirichlet LaplaceBridge pdf']
rows = ['mu: {}; \n Sigma: {}; \n alpha: {}'.format(m, s, a) for m,s,a in zip(MUs_3s_vis, SIGMAs_3s_vis, ALPHAs_3s_vis)]

plt.rcParams["font.family"] = "Times New Roman"
fig, axs = plt.subplots(nrows=len(MUs_3s), ncols=2, sharex=False, figsize=(11, 15))

for idx, (mu, Sigma, alpha) in enumerate(zip(MUs_3s, SIGMAs_3s, ALPHAs_3s)):
    

    #VALUES
    #softmax(samples)
    gaussian_samples = multivariate_normal.rvs(mean=mu, cov=Sigma, size=num_samples)
    softmax_gaussian_samples = np.array([softmax_transform(x) for x in gaussian_samples])
    #dirichlet_samples
    dirichlet_samples = dirichlet.rvs(alpha, size=num_samples)

    #PLOTS
    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    xys = np.array([xy2bc(xy) for xy in zip(trimesh.x, trimesh.y)])
    #plot softmax(Gaussian) samples
    counts_n = np.zeros(len(xys))
    for x in softmax_gaussian_samples:
        counts_n[argmin_norm(x, xys)] += 1

    pvals_n = counts_n/num_samples

    cs = axs[idx][0].tricontourf(trimesh, pvals_n, nlevels)
    for c in cs.collections:
        c.set_rasterized(True)
    axs[idx][0].axis('equal')
    axs[idx][0].set_xlim(0, 1)
    axs[idx][0].set_ylim(0, 0.75**0.5)
    axs[idx][0].axis('off')
    
    #"""
    #plot Dirichlet McKay pdf
    dist_McKay = Dirichlet(alpha)
    pvals_McKay = [dist_McKay.pdf(xy2bc(xy)) for xy in zip(trimesh.x, trimesh.y)]

    cs = axs[idx][1].tricontourf(trimesh, pvals_McKay, nlevels)
    for c in cs.collections:
        c.set_rasterized(True)
    axs[idx][1].axis('equal')
    axs[idx][1].set_xlim(0, 1)
    axs[idx][1].set_ylim(0, 0.75**0.5)
    axs[idx][1].axis('off')
    #"""
        

pad_top =  0 # in points

pad_y = 75
pad_left = -210

for ax, col in zip(axs[0], cols):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, pad_top),
                xycoords='axes fraction', textcoords='offset points',
                size=22, ha='center', va='baseline')
   
        
fig.tight_layout()
plt.savefig('figures/comparison3D_3samples.pdf')
#plt.savefig('figures/comparison3D_3samples.png')
plt.show()

# %%
#Tests for the paper

##### save figures individually

num_samples = 100000
nlevels=200
subdiv=5

MUs_3s = [[0,0,0],
       [-1,-1,2],
       [-2,1,1]]
MUs_3s_vis = np.around(MUs_3s, 2)
SIGMAs_3s = [5*np.eye(3),
          0.1*np.array([[ 9.5938,  1.4385,  2.5147],
         [ 1.4385,  9.5551,  2.5534],
         [ 2.5147,  2.5534,  8.4789]]),
         0.1*np.array([[17.7842,  1.4664,  2.7132],
         [ 1.4664, 17.7394,  2.7580],
         [ 2.7132,  2.7580, 16.4925]])]

SIGMAs_3s_corrected = [s - s.mean() for s in SIGMAs_3s]
SIGMAs_3s_vis = np.around(SIGMAs_3s, 2)

ALPHAs_3s = [get_alpha_from_Normal(m,s) for m,s in zip(MUs_3s, SIGMAs_3s_corrected)]
ALPHAs_3s_vis = np.around(ALPHAs_3s, 2)
print(ALPHAs_3s)

matplotlib.rcParams['font.family'] = "serif"
matplotlib.rcParams['font.serif'] = 'Times'
matplotlib.rcParams['text.usetex'] = True

for idx, (mu, Sigma, alpha) in enumerate(zip(MUs_3s, SIGMAs_3s, ALPHAs_3s)):
    

    #VALUES
    #softmax(samples)
    gaussian_samples = multivariate_normal.rvs(mean=mu, cov=Sigma, size=num_samples)
    softmax_gaussian_samples = np.array([softmax_transform(x) for x in gaussian_samples])
    #dirichlet_samples
    dirichlet_samples = dirichlet.rvs(alpha, size=num_samples)

    #PLOTS
    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    xys = np.array([xy2bc(xy) for xy in zip(trimesh.x, trimesh.y)])
    
    #plot softmax(Gaussian) samples
    counts_n = np.zeros(len(xys))
    for x in softmax_gaussian_samples:
        counts_n[argmin_norm(x, xys)] += 1

    pvals_n = counts_n/num_samples

    cs = plt.tricontourf(trimesh, pvals_n, nlevels, cmap=new_coolwarm)
    for c in cs.collections:
        c.set_rasterized(True)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.tight_layout()
    plt.margins(0,0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    #plt.savefig('figures/3samples_Gaussian_coolwarm_{}.png'.format(idx), bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    
    #"""
    #plot Dirichlet McKay pdf
    dist_McKay = Dirichlet(alpha)
    trimesh = refiner.refine_triangulation(subdiv=4)
    pvals_McKay = [dist_McKay.pdf(xy2bc(xy)) for xy in zip(trimesh.x, trimesh.y)]

    cs = plt.tricontourf(trimesh, pvals_McKay, nlevels, cmap=new_coolwarm)
    for c in cs.collections:
        c.set_rasterized(True)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.tight_layout()
    plt.margins(0,0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    #plt.savefig('figures/3samples_Dirichlet_coolwarm_{}.png'.format(idx), bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    #"""
# Out:
# [[0.20000000000000004, 0.20000000000000004, 0.20000000000000004], [1.1049088616044094, 1.113393937230126, 12.383568367683885], [0.43535377620870785, 2.6754110534918962, 3.039153407412016]]

# %%
#Tests for the paper

##### save figures individually

num_samples = 100000
nlevels=200
subdiv=5

MUs_3s = np.array([[0,0,0],
       [-1,-1,2],
       [-2,1,1]])
MUs_3s_vis = np.around(MUs_3s, 2)
SIGMAs_3s = [5*np.eye(3),
          0.1*np.array([[ 9.5938,  1.4385,  2.5147],
         [ 1.4385,  9.5551,  2.5534],
         [ 2.5147,  2.5534,  8.4789]]),
         0.1*np.array([[17.7842,  1.4664,  2.7132],
         [ 1.4664, 17.7394,  2.7580],
         [ 2.7132,  2.7580, 16.4925]])]

mus_sigmas = list(zip(MUs_3s, SIGMAs_3s))
# adapt to mean 0 for sigma and mu
MUs_3s = [m - m.mean() for m in MUs_3s]
SIGMAs_3s_corrected = [correct_Sigma(m, s) for m, s in mus_sigmas]
MUs_3s_corrected = [correct_mu(m, s) for m, s in mus_sigmas]
print("mus corrected: ", MUs_3s_corrected)
print("sigmas corrected: ", SIGMAs_3s_corrected)

SIGMAs_3s_vis = np.around(SIGMAs_3s, 2)

ALPHAs_3s = [get_alpha_from_Normal_full(m,s) for m,s in zip(MUs_3s_corrected, SIGMAs_3s_corrected)]
print("alphas: ", ALPHAs_3s)
ALPHAs_3s_vis = np.around(ALPHAs_3s, 2)

matplotlib.rcParams['font.family'] = "serif"
matplotlib.rcParams['font.serif'] = 'Times'
matplotlib.rcParams['text.usetex'] = True

for idx, (mu, Sigma, alpha) in enumerate(zip(MUs_3s, SIGMAs_3s, ALPHAs_3s)):
    

    #VALUES
    #softmax(samples)
    gaussian_samples = multivariate_normal.rvs(mean=mu, cov=Sigma, size=num_samples)
    softmax_gaussian_samples = np.array([softmax_transform(x) for x in gaussian_samples])
    #dirichlet_samples
    dirichlet_samples = dirichlet.rvs(alpha, size=num_samples)

    #PLOTS
    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    xys = np.array([xy2bc(xy) for xy in zip(trimesh.x, trimesh.y)])
    #plot softmax(Gaussian) samples
    counts_n = np.zeros(len(xys))
    for x in softmax_gaussian_samples:
        counts_n[argmin_norm(x, xys)] += 1

    pvals_n = counts_n/num_samples

    cs = plt.tricontourf(trimesh, pvals_n, nlevels, cmap=new_coolwarm)
    for c in cs.collections:
        c.set_rasterized(True)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.tight_layout()
    plt.margins(0,0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    #plt.savefig('figures/3samples_Gaussian_coolwarm_{}.png'.format(idx), bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    
    #"""
    #plot Dirichlet McKay pdf
    dist_McKay = Dirichlet(alpha)
    trimesh = refiner.refine_triangulation(subdiv=4)
    pvals_McKay = [dist_McKay.pdf(xy2bc(xy)) for xy in zip(trimesh.x, trimesh.y)]

    cs = plt.tricontourf(trimesh, pvals_McKay, nlevels, cmap=new_coolwarm)
    for c in cs.collections:
        c.set_rasterized(True)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.tight_layout()
    plt.margins(0,0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    #plt.savefig('figures/3samples_Dirichlet_coolwarm_{}.png'.format(idx), bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    #"""
# Out:
# mus corrected:  [array([0., 0., 0.]), array([-1., -1.,  2.]), array([-2.,  1.,  1.])]
# sigmas corrected:  [array([[ 3.33333333, -1.66666667, -1.66666667],
#        [-1.66666667,  3.33333333, -1.66666667],
#        [-1.66666667, -1.66666667,  3.33333333]]), array([[ 0.50781333, -0.30771667, -0.20009667],
#        [-0.30771667,  0.50394333, -0.19622667],
#        [-0.20009667, -0.19622667,  0.39632333]]), array([[ 1.04629222, -0.58548778, -0.46080444],
#        [-0.58548778,  1.04181222, -0.45632444],
#        [-0.46080444, -0.45632444,  0.91712889]])]
# alphas:  [array([0.2, 0.2, 0.2]), array([ 1.04728038,  1.0541227 , 12.38435563]), array([0.43953564, 2.19065935, 3.01659686])]

# %%
#[[0.20000000000000004, 0.20000000000000004, 0.20000000000000004],
#[1.1049088616044094, 1.1133939372301258, 12.383568367683885], 
#[0.4353547008581983, 2.675416760242385, 3.0391386795715323]]

#full
#[array([0.2, 0.2, 0.2]),
#array([ 1.04728038,  1.0541227 , 12.38435563]),
#array([0.43953564, 2.19065935, 3.01659686])]

# %% [markdown]
# ## Plot 2: show that increasing uncertainty in the Normal also increases uncertainty in the Dirichlet

# %%
#Tests for the paper

num_samples = 100000
nlevels=200
subdiv=5

MUs_unc = [[1, -2, 1],
           [1, -2, 1],
           [1, -2, 1]]
MUs_unc_vis = np.around(MUs_unc, 2)
SIGMAs_unc = [10*np.eye(3),
              1*np.eye(3), 
              0.1*np.eye(3)]
SIGMAs_unc_vis = np.around(SIGMAs_unc, 2)

ALPHAs_unc = [get_alpha_from_Normal(m,s) for m,s in zip(MUs_unc, SIGMAs_unc)]
ALPHAs_unc_vis = np.around(ALPHAs_unc, 2)

cols = ['Softmax(Gaussian) histogram', 'Dirichlet LaplaceBridge pdf']
rows = ['mu: {}; \n Sigma: {}; \n alpha: {}'.format(m, s, a) for m,s,a in zip(MUs_unc_vis, SIGMAs_unc_vis, ALPHAs_unc_vis)]

plt.rcParams["font.family"] = "Times New Roman"
fig, axs = plt.subplots(nrows=len(MUs_unc), ncols=2, sharex=False, figsize=(11, 15))

for idx, (mu, Sigma, alpha) in enumerate(zip(MUs_unc, SIGMAs_unc, ALPHAs_unc)):
    
    if idx == 0: subdiv=4
    else: subdiv=5
    #VALUES
    #softmax(samples)
    gaussian_samples = multivariate_normal.rvs(mean=mu, cov=Sigma, size=num_samples)
    softmax_gaussian_samples = np.array([softmax_transform(x) for x in gaussian_samples])
    #dirichlet_samples
    dirichlet_samples = dirichlet.rvs(alpha, size=num_samples)

    #PLOTS
    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    xys = np.array([xy2bc(xy) for xy in zip(trimesh.x, trimesh.y)])
    #plot softmax(Gaussian) samples
    counts_n = np.zeros(len(xys))
    for x in softmax_gaussian_samples:
        counts_n[argmin_norm(x, xys)] += 1

    pvals_n = counts_n/num_samples

    cs = axs[idx][0].tricontourf(trimesh, pvals_n, nlevels)
    for c in cs.collections:
        c.set_rasterized(True)
    axs[idx][0].axis('equal')
    axs[idx][0].set_xlim(0, 1)
    axs[idx][0].set_ylim(0, 0.75**0.5)
    axs[idx][0].axis('off')
    
    #"""
    #plot Dirichlet McKay pdf
    dist_McKay = Dirichlet(alpha)
    pvals_McKay = [dist_McKay.pdf(xy2bc(xy)) for xy in zip(trimesh.x, trimesh.y)]

    cs = axs[idx][1].tricontourf(trimesh, pvals_McKay, nlevels)
    for c in cs.collections:
        c.set_rasterized(True)
    axs[idx][1].axis('equal')
    axs[idx][1].set_xlim(0, 1)
    axs[idx][1].set_ylim(0, 0.75**0.5)
    axs[idx][1].axis('off')
    #"""
        

pad_top =  0 # in points

pad_y = 95
pad_left = -230

for ax, col in zip(axs[0], cols):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, pad_top),
                xycoords='axes fraction', textcoords='offset points',
                size=22, ha='center', va='baseline')
        
fig.tight_layout()
plt.savefig('figures/comparison3D_Uncertainty.pdf')
#plt.savefig('figures/comparison3D_Uncertainty.png')
plt.show()

# %%
#Tests for the paper

#### individual images

num_samples = 100000
nlevels=200
subdiv=5

MUs_unc = [[1, -2, 1],
           [1, -2, 1],
           [1, -2, 1]]
MUs_unc_vis = np.around(MUs_unc, 2)
SIGMAs_unc = [10*np.eye(3),
              1*np.eye(3), 
              0.1*np.eye(3)]
SIGMAs_unc_vis = np.around(SIGMAs_unc, 2)

ALPHAs_unc = [get_alpha_from_Normal(m,s) for m,s in zip(MUs_unc, SIGMAs_unc)]
ALPHAs_unc_vis = np.around(ALPHAs_unc, 2)

matplotlib.rcParams['font.family'] = "serif"
matplotlib.rcParams['font.serif'] = 'Times'
matplotlib.rcParams['text.usetex'] = True

for idx, (mu, Sigma, alpha) in enumerate(zip(MUs_unc, SIGMAs_unc, ALPHAs_unc)):
    

    #VALUES
    #softmax(samples)
    gaussian_samples = multivariate_normal.rvs(mean=mu, cov=Sigma, size=num_samples)
    softmax_gaussian_samples = np.array([softmax_transform(x) for x in gaussian_samples])
    #dirichlet_samples
    dirichlet_samples = dirichlet.rvs(alpha, size=num_samples)

    #PLOTS
    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    xys = np.array([xy2bc(xy) for xy in zip(trimesh.x, trimesh.y)])
    #plot softmax(Gaussian) samples
    counts_n = np.zeros(len(xys))
    for x in softmax_gaussian_samples:
        counts_n[argmin_norm(x, xys)] += 1

    pvals_n = counts_n/num_samples

    cs = plt.tricontourf(trimesh, pvals_n, nlevels, cmap=new_coolwarm)
    for c in cs.collections:
        c.set_rasterized(True)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.tight_layout()
    plt.margins(0,0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.savefig('figures/Uncertainty_Gaussian_coolwarm_{}.png'.format(idx), bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    
    #"""
    #plot Dirichlet McKay pdf
    dist_McKay = Dirichlet(alpha)
    pvals_McKay = [dist_McKay.pdf(xy2bc(xy)) for xy in zip(trimesh.x, trimesh.y)]

    cs = plt.tricontourf(trimesh, pvals_McKay, nlevels, cmap=new_coolwarm)
    for c in cs.collections:
        c.set_rasterized(True)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.tight_layout()
    plt.margins(0,0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.savefig('figures/Uncertainty_Dirichlet_coolwarm_{}.png'.format(idx), bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    #"""

# %% [markdown]
# ## Plot 3: show that similar MAP is not same distribution

# %%
#Tests for the paper

num_samples = 100000
nlevels=200
subdiv=5

MUs_sMAP = [get_mu_from_Dirichlet([1,1,5]),
            get_mu_from_Dirichlet([10,10,50])]
MUs_sMAP_vis = np.around(MUs_sMAP, 2)
SIGMAs_sMAP = [get_Sigma_from_Dirichlet([1,1,5]),
               get_Sigma_from_Dirichlet([10,10,50])]
SIGMAs_sMAP_vis = np.around(SIGMAs_sMAP, 2)

ALPHAs_sMAP = [get_alpha_from_Normal(m,s) for m,s in zip(MUs_sMAP, SIGMAs_sMAP)]
ALPHAs_sMAP_vis = np.around(ALPHAs_sMAP, 2)

cols = ['Softmax(Gaussian) histogram', 'Dirichlet LaplaceBridge pdf']
rows = ['mu: {}; \n Sigma: {}; \n alpha: {}'.format(m, s, a) for m,s,a in zip(MUs_sMAP_vis, SIGMAs_sMAP_vis, ALPHAs_sMAP_vis)]

fig, axs = plt.subplots(nrows=len(MUs_sMAP), ncols=2, sharex=False, figsize=(11, 11))

for idx, (mu, Sigma, alpha) in enumerate(zip(MUs_sMAP, SIGMAs_sMAP, ALPHAs_sMAP)):
    

    #VALUES
    #softmax(samples)
    gaussian_samples = multivariate_normal.rvs(mean=mu, cov=Sigma, size=num_samples)
    softmax_gaussian_samples = np.array([softmax_transform(x) for x in gaussian_samples])
    #dirichlet_samples
    dirichlet_samples = dirichlet.rvs(alpha, size=num_samples)

    #PLOTS
    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    xys = np.array([xy2bc(xy) for xy in zip(trimesh.x, trimesh.y)])
    #plot softmax(Gaussian) samples
    counts_n = np.zeros(len(xys))
    for x in softmax_gaussian_samples:
        counts_n[argmin_norm(x, xys)] += 1

    pvals_n = counts_n/num_samples

    cs = axs[idx][0].tricontourf(trimesh, pvals_n, nlevels, cmap=new_bupu)
    for c in cs.collections:
        c.set_rasterized(True)
    axs[idx][0].axis('equal')
    axs[idx][0].set_xlim(0, 1)
    axs[idx][0].set_ylim(0, 0.75**0.5)
    axs[idx][0].axis('off')
    
    #"""
    #plot Dirichlet McKay pdf
    dist_McKay = Dirichlet(alpha)
    pvals_McKay = [dist_McKay.pdf(xy2bc(xy)) for xy in zip(trimesh.x, trimesh.y)]

    cs = axs[idx][1].tricontourf(trimesh, pvals_McKay, nlevels, cmap=new_bupu)
    for c in cs.collections:
        c.set_rasterized(True)
    axs[idx][1].axis('equal')
    axs[idx][1].set_xlim(0, 1)
    axs[idx][1].set_ylim(0, 0.75**0.5)
    axs[idx][1].axis('off')
    #"""
        

pad_top =  0 # in points

pad_y = 95
pad_left = -230

for ax, col in zip(axs[0], cols):
    ax.annotate(col, xy=(0.5, 1), xytext=(0, pad_top),
                xycoords='axes fraction', textcoords='offset points',
                size=22, ha='center', va='baseline')
        
fig.tight_layout()
plt.savefig('figures/comparison3D_sMAP_new_bupu.pdf')
#plt.savefig('figures/comparison3D_sMAP.png')
plt.show()

# %%
#Tests for the paper

##### single images

num_samples = 100000
nlevels=200
subdiv=5

MUs_sMAP = [get_mu_from_Dirichlet([1,1,5]),
            get_mu_from_Dirichlet([10,10,50])]
MUs_sMAP_vis = np.around(MUs_sMAP, 2)
SIGMAs_sMAP = [get_Sigma_from_Dirichlet([1,1,5]),
               get_Sigma_from_Dirichlet([10,10,50])]
SIGMAs_sMAP_vis = np.around(SIGMAs_sMAP, 2)

ALPHAs_sMAP = [get_alpha_from_Normal(m,s) for m,s in zip(MUs_sMAP, SIGMAs_sMAP)]
ALPHAs_sMAP_vis = np.around(ALPHAs_sMAP, 2)

matplotlib.rcParams['font.family'] = "serif"
matplotlib.rcParams['font.serif'] = 'Times'
matplotlib.rcParams['text.usetex'] = True

for idx, (mu, Sigma, alpha) in enumerate(zip(MUs_sMAP, SIGMAs_sMAP, ALPHAs_sMAP)):
    

    #VALUES
    #softmax(samples)
    gaussian_samples = multivariate_normal.rvs(mean=mu, cov=Sigma, size=num_samples)
    softmax_gaussian_samples = np.array([softmax_transform(x) for x in gaussian_samples])
    #dirichlet_samples
    dirichlet_samples = dirichlet.rvs(alpha, size=num_samples)

    #PLOTS
    refiner = tri.UniformTriRefiner(triangle)
    trimesh = refiner.refine_triangulation(subdiv=subdiv)
    xys = np.array([xy2bc(xy) for xy in zip(trimesh.x, trimesh.y)])
    #plot softmax(Gaussian) samples
    counts_n = np.zeros(len(xys))
    for x in softmax_gaussian_samples:
        counts_n[argmin_norm(x, xys)] += 1

    pvals_n = counts_n/num_samples

    cs = plt.tricontourf(trimesh, pvals_n, nlevels, cmap=new_coolwarm)
    for c in cs.collections:
        c.set_rasterized(True)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.tight_layout()
    plt.margins(0,0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.savefig('figures/sMAP_Gaussian_coolwarm_{}.png'.format(idx), bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    
    #"""
    #plot Dirichlet McKay pdf
    dist_McKay = Dirichlet(alpha)
    pvals_McKay = [dist_McKay.pdf(xy2bc(xy)) for xy in zip(trimesh.x, trimesh.y)]

    cs = plt.tricontourf(trimesh, pvals_McKay, nlevels, cmap=new_coolwarm)
    for c in cs.collections:
        c.set_rasterized(True)
    plt.axis('equal')
    plt.xlim(0, 1)
    plt.ylim(0, 0.75**0.5)
    plt.axis('off')
    plt.tight_layout()
    plt.margins(0,0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.savefig('figures/sMAP_Dirichlet_coolwarm_{}.png'.format(idx), bbox_inches = 'tight', pad_inches = 0)
    plt.show()
    #"""
