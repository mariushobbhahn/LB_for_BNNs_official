# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # MNIST

# %%
df = pd.read_csv("MNIST_results.csv")
print(df.columns)
df
# Out:
# Index(['Unnamed: 0', 'MAP_MMC_in', 'MAP_MMC_FMNIST', 'MAP_MMC_notMNIST',
#        'MAP_MMC_KMNIST', 'MAP_AUROC_FMNIST', 'MAP_AUROC_notMNIST',
#        'MAP_AUROC_KMNIST', 'MAP_NLL_in', 'MAP_NLL_FMNIST',
#        ...
#        'KFAC_PROBIT_NLL_notMNIST', 'KFAC_PROBIT_NLL_KMNIST',
#        'KFAC_PROBIT_ECE_in', 'KFAC_PROBIT_ECE_FMNIST',
#        'KFAC_PROBIT_ECE_notMNIST', 'KFAC_PROBIT_ECE_KMNIST',
#        'KFAC_PROBIT_Brier_in', 'KFAC_PROBIT_Brier_FMNIST',
#        'KFAC_PROBIT_Brier_notMNIST', 'KFAC_PROBIT_Brier_KMNIST'],
#       dtype='object', length=172)
#    Unnamed: 0  MAP_MMC_in  MAP_MMC_FMNIST  MAP_MMC_notMNIST  MAP_MMC_KMNIST  \
# 0           0    0.985782        0.663287          0.774449        0.722817
# 1           1    0.985782        0.663287          0.774449        0.722817
# 2           2    0.985782        0.663287          0.774449        0.722817
# 3           3    0.985782        0.663287          0.774449        0.722817
# ...

# %% [markdown]
# # compare diag

# %%
#pd.set_option("display.precision", 4)
#pd.set_option('precision', 3)
pd.options.display.float_format = '{:,.3f}'.format

# %%
data_MNIST = np.array([
    #["MNIST", "MNIST", "MNIST", "MNIST"],
    #["MNIST", "FMNIST", "notMNIST", "KMNIST"],
    [df['Diag_samples_MMC_in'].mean(), df['Diag_samples_MMC_FMNIST'].mean(),
     df['Diag_samples_MMC_notMNIST'].mean(), df['Diag_samples_MMC_KMNIST'].mean()],
    [0, df['Diag_samples_AUROC_FMNIST'].mean(), df['Diag_samples_AUROC_notMNIST'].mean(),
     df['Diag_samples_AUROC_KMNIST'].mean()],
    [df['Diag_samples_NLL_in'].mean(), df['Diag_samples_NLL_FMNIST'].mean(),
     df['Diag_samples_NLL_notMNIST'].mean(), df['Diag_samples_NLL_KMNIST'].mean()],
    [df['Diag_samples_ECE_in'].mean(), df['Diag_samples_ECE_FMNIST'].mean(),
     df['Diag_samples_ECE_notMNIST'].mean(), df['Diag_samples_ECE_KMNIST'].mean()],
    [df['Diag_samples_Brier_in'].mean(), df['Diag_samples_Brier_FMNIST'].mean(),
     df['Diag_samples_Brier_notMNIST'].mean(), df['Diag_samples_Brier_KMNIST'].mean()],
    [df['Diag_LB_MMC_in'].mean(), df['Diag_LB_MMC_FMNIST'].mean(), 
     df['Diag_LB_MMC_notMNIST'].mean(), df['Diag_LB_MMC_KMNIST'].mean()], 
    [0, df['Diag_LB_AUROC_FMNIST'].mean(), df['Diag_LB_AUROC_notMNIST'].mean(),
     df['Diag_LB_AUROC_KMNIST'].mean()],
    [df['Diag_LB_NLL_in'].mean(), df['Diag_LB_NLL_FMNIST'].mean(), 
     df['Diag_LB_NLL_notMNIST'].mean(), df['Diag_LB_NLL_KMNIST'].mean()], 
    [df['Diag_LB_ECE_in'].mean(), df['Diag_LB_ECE_FMNIST'].mean(), 
     df['Diag_LB_ECE_notMNIST'].mean(), df['Diag_LB_ECE_KMNIST'].mean()], 
    [df['Diag_LB_Brier_in'].mean(), df['Diag_LB_Brier_FMNIST'].mean(), 
     df['Diag_LB_Brier_notMNIST'].mean(), df['Diag_LB_Brier_KMNIST'].mean()], 
    [df['Diag_LB_norm_MMC_in'].mean(), df['Diag_LB_norm_MMC_FMNIST'].mean(), 
     df['Diag_LB_norm_MMC_notMNIST'].mean(), df['Diag_LB_norm_MMC_KMNIST'].mean()], 
    [0, df['Diag_LB_norm_AUROC_FMNIST'].mean(), df['Diag_LB_norm_AUROC_notMNIST'].mean(),
     df['Diag_LB_norm_AUROC_KMNIST'].mean()],
    [df['Diag_LB_norm_NLL_in'].mean(), df['Diag_LB_norm_NLL_FMNIST'].mean(), 
     df['Diag_LB_norm_NLL_notMNIST'].mean(), df['Diag_LB_norm_NLL_KMNIST'].mean()], 
    [df['Diag_LB_norm_ECE_in'].mean(), df['Diag_LB_norm_ECE_FMNIST'].mean(), 
     df['Diag_LB_norm_ECE_notMNIST'].mean(), df['Diag_LB_norm_ECE_KMNIST'].mean()], 
    [df['Diag_LB_norm_Brier_in'].mean(), df['Diag_LB_norm_Brier_FMNIST'].mean(), 
     df['Diag_LB_norm_Brier_notMNIST'].mean(), df['Diag_LB_norm_Brier_KMNIST'].mean()], 
    [df['Diag_PROBIT_MMC_in'].mean(), df['Diag_PROBIT_MMC_FMNIST'].mean(), 
     df['Diag_PROBIT_MMC_notMNIST'].mean(), df['Diag_PROBIT_MMC_KMNIST'].mean()], 
    [0, df['Diag_PROBIT_AUROC_FMNIST'].mean(), df['Diag_PROBIT_AUROC_notMNIST'].mean(),
     df['Diag_PROBIT_AUROC_KMNIST'].mean()], 
    [df['Diag_PROBIT_NLL_in'].mean(), df['Diag_PROBIT_NLL_FMNIST'].mean(), 
     df['Diag_PROBIT_NLL_notMNIST'].mean(), df['Diag_PROBIT_NLL_KMNIST'].mean()],  
    [df['Diag_PROBIT_ECE_in'].mean(), df['Diag_PROBIT_ECE_FMNIST'].mean(), 
     df['Diag_PROBIT_ECE_notMNIST'].mean(), df['Diag_PROBIT_ECE_KMNIST'].mean()],  
    [df['Diag_PROBIT_Brier_in'].mean(), df['Diag_PROBIT_Brier_FMNIST'].mean(), 
     df['Diag_PROBIT_Brier_notMNIST'].mean(), df['Diag_PROBIT_Brier_KMNIST'].mean()], 
#     [df['Diag_SODPP_MMC_in'].mean(), df['Diag_SODPP_MMC_FMNIST'].mean(), 
#      df['Diag_SODPP_MMC_notMNIST'].mean(), df['Diag_SODPP_MMC_KMNIST'].mean()], 
#     [0, df['Diag_SODPP_AUROC_FMNIST'].mean(), df['Diag_SODPP_AUROC_notMNIST'].mean(),
#      df['Diag_SODPP_AUROC_KMNIST'].mean()],
]).T

df_MNIST_diag = pd.DataFrame(data_MNIST, columns=[
    #"In", "Out",
    "Diag_samples_MMC", "Diag_samples_auroc", "Diag_samples_NLL", "Diag_samples_ECE", "Diag_samples_Brier",
    "Diag_LB_MMC", "Diag_LB_auroc", "Diag_LB_NLL", "Diag_LB_ECE", "Diag_LB_Brier",
    "Diag_LB_norm_MMC", "Diag_LB_norm_auroc", "Diag_LB_norm_NLL", "Diag_LB_norm_ECE", "Diag_LB_norm_Brier",
    "Diag_PROBIT_MMC", "Diag_PROBIT_auroc", "Diag_PROBIT_NLL", "Diag_PROBIT_ECE", "Diag_PROBIT_Brier",
    #"Diag_SODPP_MMC", "Diag_SODPP_auroc"
])
df_MNIST_diag
# Out:
#    Diag_samples_MMC  Diag_samples_auroc  Diag_samples_NLL  Diag_samples_ECE  \
# 0             0.955               0.000             0.062             0.036
# 1             0.536               0.975             3.959             0.464
# 2             0.546               0.965             4.299             0.396
# 3             0.521               0.974             4.890             0.429
#
#    Diag_samples_Brier  Diag_LB_MMC  Diag_LB_auroc  Diag_LB_NLL  Diag_LB_ECE  \
# 0               0.002        0.981          0.000        0.044        0.012
# 1               0.121        0.565          0.981        3.660        0.478
# 2               0.115        0.735          0.930        5.663        0.600
# 3               0.120        0.711          0.949        5.748        0.617
#
#    Diag_LB_Brier  Diag_LB_norm_MMC  Diag_LB_norm_auroc  Diag_LB_norm_NLL  \
# 0          0.002             0.944               0.000             0.078
# ...

# %%
# pd.set_option('precision', 3)
print(df_MNIST_diag.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrrrrrrrrrrrrrrrr}
# \toprule
#  Diag\_samples\_MMC &  Diag\_samples\_auroc &  Diag\_samples\_NLL &  Diag\_samples\_ECE &  Diag\_samples\_Brier &  Diag\_LB\_MMC &  Diag\_LB\_auroc &  Diag\_LB\_NLL &  Diag\_LB\_ECE &  Diag\_LB\_Brier &  Diag\_LB\_norm\_MMC &  Diag\_LB\_norm\_auroc &  Diag\_LB\_norm\_NLL &  Diag\_LB\_norm\_ECE &  Diag\_LB\_norm\_Brier &  Diag\_PROBIT\_MMC &  Diag\_PROBIT\_auroc &  Diag\_PROBIT\_NLL &  Diag\_PROBIT\_ECE &  Diag\_PROBIT\_Brier \\
# \midrule
#             0.955 &               0.000 &             0.062 &             0.036 &               0.002 &        0.981 &          0.000 &        0.044 &        0.012 &          0.002 &             0.944 &               0.000 &             0.078 &             0.045 &               0.003 &            0.967 &              0.000 &            0.050 &            0.024 &              0.002 \\
# ...

# %% [markdown]
# # KFAC

# %%
data_MNIST_kron = np.array([
    #["MNIST", "MNIST", "MNIST", "MNIST"],
    #["MNIST", "FMNIST", "notMNIST", "KMNIST"],
    [df['KFAC_samples_MMC_in'].mean(), df['KFAC_samples_MMC_FMNIST'].mean(),
     df['KFAC_samples_MMC_notMNIST'].mean(), df['KFAC_samples_MMC_KMNIST'].mean()],
    [0, df['KFAC_samples_AUROC_FMNIST'].mean(), df['KFAC_samples_AUROC_notMNIST'].mean(),
     df['KFAC_samples_AUROC_KMNIST'].mean()],
    [df['KFAC_samples_NLL_in'].mean(), df['KFAC_samples_NLL_FMNIST'].mean(),
     df['KFAC_samples_NLL_notMNIST'].mean(), df['KFAC_samples_NLL_KMNIST'].mean()],
    [df['KFAC_samples_ECE_in'].mean(), df['KFAC_samples_ECE_FMNIST'].mean(),
     df['KFAC_samples_ECE_notMNIST'].mean(), df['KFAC_samples_ECE_KMNIST'].mean()],
    [df['KFAC_samples_Brier_in'].mean(), df['KFAC_samples_Brier_FMNIST'].mean(),
     df['KFAC_samples_Brier_notMNIST'].mean(), df['KFAC_samples_Brier_KMNIST'].mean()],
    [df['KFAC_LB_MMC_in'].mean(), df['KFAC_LB_MMC_FMNIST'].mean(), 
     df['KFAC_LB_MMC_notMNIST'].mean(), df['KFAC_LB_MMC_KMNIST'].mean()], 
    [0, df['KFAC_LB_AUROC_FMNIST'].mean(), df['KFAC_LB_AUROC_notMNIST'].mean(),
     df['KFAC_LB_AUROC_KMNIST'].mean()],
    [df['KFAC_LB_NLL_in'].mean(), df['KFAC_LB_NLL_FMNIST'].mean(), 
     df['KFAC_LB_NLL_notMNIST'].mean(), df['KFAC_LB_NLL_KMNIST'].mean()], 
    [df['KFAC_LB_ECE_in'].mean(), df['KFAC_LB_ECE_FMNIST'].mean(), 
     df['KFAC_LB_ECE_notMNIST'].mean(), df['KFAC_LB_ECE_KMNIST'].mean()], 
    [df['KFAC_LB_Brier_in'].mean(), df['KFAC_LB_Brier_FMNIST'].mean(), 
     df['KFAC_LB_Brier_notMNIST'].mean(), df['KFAC_LB_Brier_KMNIST'].mean()], 
    [df['KFAC_LB_norm_MMC_in'].mean(), df['KFAC_LB_norm_MMC_FMNIST'].mean(), 
     df['KFAC_LB_norm_MMC_notMNIST'].mean(), df['KFAC_LB_norm_MMC_KMNIST'].mean()], 
    [0, df['KFAC_LB_norm_AUROC_FMNIST'].mean(), df['KFAC_LB_norm_AUROC_notMNIST'].mean(),
     df['KFAC_LB_norm_AUROC_KMNIST'].mean()],
    [df['KFAC_LB_norm_NLL_in'].mean(), df['KFAC_LB_norm_NLL_FMNIST'].mean(), 
     df['KFAC_LB_norm_NLL_notMNIST'].mean(), df['KFAC_LB_norm_NLL_KMNIST'].mean()], 
    [df['KFAC_LB_norm_ECE_in'].mean(), df['KFAC_LB_norm_ECE_FMNIST'].mean(), 
     df['KFAC_LB_norm_ECE_notMNIST'].mean(), df['KFAC_LB_norm_ECE_KMNIST'].mean()], 
    [df['KFAC_LB_norm_Brier_in'].mean(), df['KFAC_LB_norm_Brier_FMNIST'].mean(), 
     df['KFAC_LB_norm_Brier_notMNIST'].mean(), df['KFAC_LB_norm_Brier_KMNIST'].mean()], 
    [df['KFAC_PROBIT_MMC_in'].mean(), df['KFAC_PROBIT_MMC_FMNIST'].mean(), 
     df['KFAC_PROBIT_MMC_notMNIST'].mean(), df['KFAC_PROBIT_MMC_KMNIST'].mean()], 
    [0, df['KFAC_PROBIT_AUROC_FMNIST'].mean(), df['KFAC_PROBIT_AUROC_notMNIST'].mean(),
     df['KFAC_PROBIT_AUROC_KMNIST'].mean()], 
    [df['KFAC_PROBIT_NLL_in'].mean(), df['KFAC_PROBIT_NLL_FMNIST'].mean(), 
     df['KFAC_PROBIT_NLL_notMNIST'].mean(), df['KFAC_PROBIT_NLL_KMNIST'].mean()],  
    [df['KFAC_PROBIT_ECE_in'].mean(), df['KFAC_PROBIT_ECE_FMNIST'].mean(), 
     df['KFAC_PROBIT_ECE_notMNIST'].mean(), df['KFAC_PROBIT_ECE_KMNIST'].mean()],  
    [df['KFAC_PROBIT_Brier_in'].mean(), df['KFAC_PROBIT_Brier_FMNIST'].mean(), 
     df['KFAC_PROBIT_Brier_notMNIST'].mean(), df['KFAC_PROBIT_Brier_KMNIST'].mean()], 
]).T

df_MNIST_kron = pd.DataFrame(data_MNIST_kron, columns=[
    #"In", "Out",
    "KFAC_samples_MMC", "KFAC_samples_auroc", "KFAC_samples_NLL", "KFAC_samples_ECE", "KFAC_samples_Brier",
    "KFAC_LB_MMC", "KFAC_LB_auroc", "KFAC_LB_NLL", "KFAC_LB_ECE", "KFAC_LB_Brier",
    "KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc", "KFAC_LB_norm_NLL", "KFAC_LB_norm_ECE", "KFAC_LB_norm_Brier",
    "KFAC_PROBIT_MMC", "KFAC_PROBIT_auroc", "KFAC_PROBIT_NLL", "KFAC_PROBIT_ECE", "KFAC_PROBIT_Brier",
    #"Diag_SODPP_MMC", "Diag_SODPP_auroc"
])
df_MNIST_kron
# Out:
#    KFAC_samples_MMC  KFAC_samples_auroc  KFAC_samples_NLL  KFAC_samples_ECE  \
# 0             0.961               0.000             0.056             0.030
# 1             0.460               0.987             3.568             0.390
# 2             0.504               0.974             3.972             0.366
# 3             0.471               0.985             4.531             0.374
#
#    KFAC_samples_Brier  KFAC_LB_MMC  KFAC_LB_auroc  KFAC_LB_NLL  KFAC_LB_ECE  \
# 0               0.002        0.985          0.000        0.034        0.012
# 1               0.112        0.630          0.977        3.878        0.553
# 2               0.112        0.757          0.912        6.012        0.634
# 3               0.114        0.712          0.956        6.047        0.619
#
#    KFAC_LB_Brier  KFAC_LB_norm_MMC  KFAC_LB_norm_auroc  KFAC_LB_norm_NLL  \
# 0          0.002             0.975               0.000             0.043
# ...

# %%
print(df_MNIST_kron.to_latex(index=False))
# Out:
# \begin{tabular}{rrrrrrrrrrrrrrrrrrrr}
# \toprule
#  KFAC\_samples\_MMC &  KFAC\_samples\_auroc &  KFAC\_samples\_NLL &  KFAC\_samples\_ECE &  KFAC\_samples\_Brier &  KFAC\_LB\_MMC &  KFAC\_LB\_auroc &  KFAC\_LB\_NLL &  KFAC\_LB\_ECE &  KFAC\_LB\_Brier &  KFAC\_LB\_norm\_MMC &  KFAC\_LB\_norm\_auroc &  KFAC\_LB\_norm\_NLL &  KFAC\_LB\_norm\_ECE &  KFAC\_LB\_norm\_Brier &  KFAC\_PROBIT\_MMC &  KFAC\_PROBIT\_auroc &  KFAC\_PROBIT\_NLL &  KFAC\_PROBIT\_ECE &  KFAC\_PROBIT\_Brier \\
# \midrule
#             0.961 &               0.000 &             0.056 &             0.030 &               0.002 &        0.985 &          0.000 &        0.034 &        0.012 &          0.002 &             0.975 &               0.000 &             0.043 &             0.018 &               0.002 &            0.105 &              0.000 &            2.258 &            0.883 &              0.089 \\
# ...

# %%
df_MNIST_kron[["KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc", "KFAC_LB_norm_NLL", "KFAC_LB_norm_ECE", "KFAC_LB_norm_Brier",
    "KFAC_PROBIT_MMC", "KFAC_PROBIT_auroc", "KFAC_PROBIT_NLL", "KFAC_PROBIT_ECE", "KFAC_PROBIT_Brier"]]
# Out:
#    KFAC_LB_norm_MMC  KFAC_LB_norm_auroc  KFAC_LB_norm_NLL  KFAC_LB_norm_ECE  \
# 0             0.975               0.000             0.043             0.018
# 1             0.444               0.990             2.871             0.364
# 2             0.409               0.986             2.854             0.294
# 3             0.414               0.991             3.162             0.328
#
#    KFAC_LB_norm_Brier  KFAC_PROBIT_MMC  KFAC_PROBIT_auroc  KFAC_PROBIT_NLL  \
# 0               0.002            0.105              0.000            2.258
# 1               0.111            0.102              0.955            2.302
# 2               0.106            0.103              0.922            2.300
# 3               0.110            0.102              0.962            2.304
#
#    KFAC_PROBIT_ECE  KFAC_PROBIT_Brier
# 0            0.883              0.089
# 1            0.032              0.090
# 2            0.043              0.090
# 3            0.012              0.090

# %% [markdown]
# # CIFAR10

# %%
df_CIFAR10 = pd.read_csv("CIFAR10_results.csv")
print(df_CIFAR10.columns)
df_CIFAR10
# Out:
# Index(['Unnamed: 0', 'MAP_MMC_in', 'MAP_MMC_CIFAR100', 'MAP_MMC_SVHN',
#        'MAP_AUROC_CIFAR100', 'MAP_AUROC_SVHN', 'MAP_NLL_in',
#        'MAP_NLL_CIFAR100', 'MAP_NLL_SVHN', 'MAP_ECE_in',
#        ...
#        'KFAC_PROBIT_AUROC_SVHN', 'KFAC_PROBIT_NLL_in',
#        'KFAC_PROBIT_NLL_CIFAR100', 'KFAC_PROBIT_NLL_SVHN',
#        'KFAC_PROBIT_ECE_in', 'KFAC_PROBIT_ECE_CIFAR100',
#        'KFAC_PROBIT_ECE_SVHN', 'KFAC_PROBIT_Brier_in',
#        'KFAC_PROBIT_Brier_CIFAR100', 'KFAC_PROBIT_Brier_SVHN'],
#       dtype='object', length=127)
#    Unnamed: 0  MAP_MMC_in  MAP_MMC_CIFAR100  MAP_MMC_SVHN  MAP_AUROC_CIFAR100  \
# 0           0       0.977             0.818         0.777               0.874
# 1           1       0.977             0.818         0.777               0.874
# 2           2       0.977             0.818         0.777               0.874
# 3           3       0.977             0.818         0.777               0.874
# ...

# %%
data_CIFAR10 = np.array([
    [df_CIFAR10['Diag_samples_MMC_in'].mean(), df_CIFAR10['Diag_samples_MMC_CIFAR100'].mean(),
     df_CIFAR10['Diag_samples_MMC_SVHN'].mean()],
    [0, df_CIFAR10['Diag_samples_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_samples_AUROC_SVHN'].mean()],
    [df_CIFAR10['Diag_samples_NLL_in'].mean(), df_CIFAR10['Diag_samples_NLL_CIFAR100'].mean(),
     df_CIFAR10['Diag_samples_NLL_SVHN'].mean()],
    [df_CIFAR10['Diag_samples_ECE_in'].mean(), df_CIFAR10['Diag_samples_ECE_CIFAR100'].mean(),
     df_CIFAR10['Diag_samples_ECE_SVHN'].mean()],
    [df_CIFAR10['Diag_samples_Brier_in'].mean(), df_CIFAR10['Diag_samples_Brier_CIFAR100'].mean(),
     df_CIFAR10['Diag_samples_Brier_SVHN'].mean()],
    [df_CIFAR10['Diag_LB_MMC_in'].mean(), df_CIFAR10['Diag_LB_MMC_CIFAR100'].mean(),
     df_CIFAR10['Diag_LB_MMC_SVHN'].mean()],
    [0, df_CIFAR10['Diag_LB_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_LB_AUROC_SVHN'].mean()],
    [df_CIFAR10['Diag_LB_NLL_in'].mean(), df_CIFAR10['Diag_LB_NLL_CIFAR100'].mean(),
     df_CIFAR10['Diag_LB_NLL_SVHN'].mean()],
    [df_CIFAR10['Diag_LB_ECE_in'].mean(), df_CIFAR10['Diag_LB_ECE_CIFAR100'].mean(),
     df_CIFAR10['Diag_LB_ECE_SVHN'].mean()],
    [df_CIFAR10['Diag_LB_Brier_in'].mean(), df_CIFAR10['Diag_LB_Brier_CIFAR100'].mean(),
     df_CIFAR10['Diag_LB_Brier_SVHN'].mean()],
    [df_CIFAR10['Diag_LB_norm_MMC_in'].mean(), df_CIFAR10['Diag_LB_norm_MMC_CIFAR100'].mean(),
     df_CIFAR10['Diag_LB_norm_MMC_SVHN'].mean()],
    [0, df_CIFAR10['Diag_LB_norm_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_LB_norm_AUROC_SVHN'].mean()],
    [df_CIFAR10['Diag_LB_norm_NLL_in'].mean(), df_CIFAR10['Diag_LB_norm_NLL_CIFAR100'].mean(),
     df_CIFAR10['Diag_LB_norm_NLL_SVHN'].mean()],
    [df_CIFAR10['Diag_LB_norm_ECE_in'].mean(), df_CIFAR10['Diag_LB_norm_ECE_CIFAR100'].mean(),
     df_CIFAR10['Diag_LB_norm_ECE_SVHN'].mean()],
    [df_CIFAR10['Diag_LB_norm_Brier_in'].mean(), df_CIFAR10['Diag_LB_norm_Brier_CIFAR100'].mean(),
     df_CIFAR10['Diag_LB_norm_Brier_SVHN'].mean()],
    [df_CIFAR10['Diag_PROBIT_MMC_in'].mean(), df_CIFAR10['Diag_PROBIT_MMC_CIFAR100'].mean(),
     df_CIFAR10['Diag_PROBIT_MMC_SVHN'].mean()],
    [0, df_CIFAR10['Diag_PROBIT_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_PROBIT_AUROC_SVHN'].mean()],
    [df_CIFAR10['Diag_PROBIT_NLL_in'].mean(), df_CIFAR10['Diag_PROBIT_NLL_CIFAR100'].mean(),
     df_CIFAR10['Diag_PROBIT_NLL_SVHN'].mean()],
    [df_CIFAR10['Diag_PROBIT_ECE_in'].mean(), df_CIFAR10['Diag_PROBIT_ECE_CIFAR100'].mean(),
     df_CIFAR10['Diag_PROBIT_ECE_SVHN'].mean()],
    [df_CIFAR10['Diag_PROBIT_Brier_in'].mean(), df_CIFAR10['Diag_PROBIT_Brier_CIFAR100'].mean(),
     df_CIFAR10['Diag_PROBIT_Brier_SVHN'].mean()],
#     [df_CIFAR10['Diag_EMK_MMC_in'].mean(), df_CIFAR10['Diag_EMK_MMC_CIFAR100'].mean(),
#      df_CIFAR10['Diag_EMK_MMC_SVHN'].mean()],
#     [0, df_CIFAR10['Diag_EMK_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_EMK_AUROC_SVHN'].mean()],
#     [df_CIFAR10['Diag_SODPP_MMC_in'].mean(), df_CIFAR10['Diag_SODPP_MMC_CIFAR100'].mean(),
#      df_CIFAR10['Diag_SODPP_MMC_SVHN'].mean()],
#     [0, df_CIFAR10['Diag_SODPP_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_SODPP_AUROC_SVHN'].mean()]
]).T

df_diag_CIFAR10 = pd.DataFrame(data_CIFAR10, columns=[
    "Diag_samples_MMC", "Diag_samples_auroc", "Diag_samples_NLL", "Diag_samples_ECE", "Diag_samples_Brier",
    "Diag_LB_MMC", "Diag_LB_auroc", "Diag_LB_NLL", "Diag_LB_ECE", "Diag_LB_Brier",
    "Diag_LB_norm_MMC", "Diag_LB_norm_auroc", "Diag_LB_norm_NLL", "Diag_LB_norm_ECE", "Diag_LB_norm_Brier",
    "Diag_PROBIT_MMC", "Diag_PROBIT_auroc", "Diag_PROBIT_NLL", "Diag_PROBIT_ECE", "Diag_PROBIT_Brier"
])
df_diag_CIFAR10
# Out:
#    Diag_samples_MMC  Diag_samples_auroc  Diag_samples_NLL  Diag_samples_ECE  \
# 0             0.746               0.000             0.376             0.205
# 1             0.484               0.887             2.978             0.379
# 2             0.418               0.948             2.917             0.309
#
#    Diag_samples_Brier  Diag_LB_MMC  Diag_LB_auroc  Diag_LB_NLL  Diag_LB_ECE  \
# 0               0.013        0.974          0.000        0.192        0.025
# 1               0.111        0.796          0.859        5.251        0.691
# 2               0.106        0.766          0.928        5.002        0.652
#
#    Diag_LB_Brier  Diag_LB_norm_MMC  Diag_LB_norm_auroc  Diag_LB_norm_NLL  \
# 0          0.008             0.517               0.000             0.727
# 1          0.150             0.319               0.883             2.590
# 2          0.145             0.273               0.948             2.457
#
# ...

# %%
data_CIFAR10_K = np.array([
    [df_CIFAR10['KFAC_samples_MMC_in'].mean(), df_CIFAR10['KFAC_samples_MMC_CIFAR100'].mean(),
     df_CIFAR10['KFAC_samples_MMC_SVHN'].mean()],
    [0, df_CIFAR10['KFAC_samples_AUROC_CIFAR100'].mean(), df_CIFAR10['KFAC_samples_AUROC_SVHN'].mean()],
    [df_CIFAR10['KFAC_samples_NLL_in'].mean(), df_CIFAR10['KFAC_samples_NLL_CIFAR100'].mean(),
     df_CIFAR10['KFAC_samples_NLL_SVHN'].mean()],
    [df_CIFAR10['KFAC_samples_ECE_in'].mean(), df_CIFAR10['KFAC_samples_ECE_CIFAR100'].mean(),
     df_CIFAR10['KFAC_samples_ECE_SVHN'].mean()],
    [df_CIFAR10['KFAC_samples_Brier_in'].mean(), df_CIFAR10['KFAC_samples_Brier_CIFAR100'].mean(),
     df_CIFAR10['KFAC_samples_Brier_SVHN'].mean()],
    [df_CIFAR10['KFAC_LB_MMC_in'].mean(), df_CIFAR10['KFAC_LB_MMC_CIFAR100'].mean(),
     df_CIFAR10['KFAC_LB_MMC_SVHN'].mean()],
    [0, df_CIFAR10['KFAC_LB_AUROC_CIFAR100'].mean(), df_CIFAR10['KFAC_LB_AUROC_SVHN'].mean()],
    [df_CIFAR10['KFAC_LB_NLL_in'].mean(), df_CIFAR10['KFAC_LB_NLL_CIFAR100'].mean(),
     df_CIFAR10['KFAC_LB_NLL_SVHN'].mean()],
    [df_CIFAR10['KFAC_LB_ECE_in'].mean(), df_CIFAR10['KFAC_LB_ECE_CIFAR100'].mean(),
     df_CIFAR10['KFAC_LB_ECE_SVHN'].mean()],
    [df_CIFAR10['KFAC_LB_Brier_in'].mean(), df_CIFAR10['KFAC_LB_Brier_CIFAR100'].mean(),
     df_CIFAR10['KFAC_LB_Brier_SVHN'].mean()],
    [df_CIFAR10['KFAC_LB_norm_MMC_in'].mean(), df_CIFAR10['KFAC_LB_norm_MMC_CIFAR100'].mean(),
     df_CIFAR10['KFAC_LB_norm_MMC_SVHN'].mean()],
    [0, df_CIFAR10['KFAC_LB_norm_AUROC_CIFAR100'].mean(), df_CIFAR10['KFAC_LB_norm_AUROC_SVHN'].mean()],
    [df_CIFAR10['KFAC_LB_norm_NLL_in'].mean(), df_CIFAR10['KFAC_LB_norm_NLL_CIFAR100'].mean(),
     df_CIFAR10['KFAC_LB_norm_NLL_SVHN'].mean()],
    [df_CIFAR10['KFAC_LB_norm_ECE_in'].mean(), df_CIFAR10['KFAC_LB_norm_ECE_CIFAR100'].mean(),
     df_CIFAR10['KFAC_LB_norm_ECE_SVHN'].mean()],
    [df_CIFAR10['KFAC_LB_norm_Brier_in'].mean(), df_CIFAR10['KFAC_LB_norm_Brier_CIFAR100'].mean(),
     df_CIFAR10['KFAC_LB_norm_Brier_SVHN'].mean()],
    [df_CIFAR10['KFAC_PROBIT_MMC_in'].mean(), df_CIFAR10['KFAC_PROBIT_MMC_CIFAR100'].mean(),
     df_CIFAR10['KFAC_PROBIT_MMC_SVHN'].mean()],
    [0, df_CIFAR10['KFAC_PROBIT_AUROC_CIFAR100'].mean(), df_CIFAR10['KFAC_PROBIT_AUROC_SVHN'].mean()],
    [df_CIFAR10['KFAC_PROBIT_NLL_in'].mean(), df_CIFAR10['KFAC_PROBIT_NLL_CIFAR100'].mean(),
     df_CIFAR10['KFAC_PROBIT_NLL_SVHN'].mean()],
    [df_CIFAR10['KFAC_PROBIT_ECE_in'].mean(), df_CIFAR10['KFAC_PROBIT_ECE_CIFAR100'].mean(),
     df_CIFAR10['KFAC_PROBIT_ECE_SVHN'].mean()],
    [df_CIFAR10['KFAC_PROBIT_Brier_in'].mean(), df_CIFAR10['KFAC_PROBIT_Brier_CIFAR100'].mean(),
     df_CIFAR10['KFAC_PROBIT_Brier_SVHN'].mean()],
#     [df_CIFAR10['Diag_EMK_MMC_in'].mean(), df_CIFAR10['Diag_EMK_MMC_CIFAR100'].mean(),
#      df_CIFAR10['Diag_EMK_MMC_SVHN'].mean()],
#     [0, df_CIFAR10['Diag_EMK_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_EMK_AUROC_SVHN'].mean()],
#     [df_CIFAR10['Diag_SODPP_MMC_in'].mean(), df_CIFAR10['Diag_SODPP_MMC_CIFAR100'].mean(),
#      df_CIFAR10['Diag_SODPP_MMC_SVHN'].mean()],
#     [0, df_CIFAR10['Diag_SODPP_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_SODPP_AUROC_SVHN'].mean()]
]).T

df_CIFAR10_K = pd.DataFrame(data_CIFAR10_K, columns=[
    "KFAC_samples_MMC", "KFAC_samples_auroc", "KFAC_samples_NLL", "KFAC_samples_ECE", "KFAC_samples_Brier",
    "KFAC_LB_MMC", "KFAC_LB_auroc", "KFAC_LB_NLL", "KFAC_LB_ECE", "KFAC_LB_Brier",
    "KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc", "KFAC_LB_norm_NLL", "KFAC_LB_norm_ECE", "KFAC_LB_norm_Brier",
    "KFAC_PROBIT_MMC", "KFAC_PROBIT_auroc", "KFAC_PROBIT_NLL", "KFAC_PROBIT_ECE", "KFAC_PROBIT_Brier"
])
df_CIFAR10_K
# Out:
#    KFAC_samples_MMC  KFAC_samples_auroc  KFAC_samples_NLL  KFAC_samples_ECE  \
# 0             0.944               0.000             0.172             0.015
# 1             0.683               0.878             4.579             0.577
# 2             0.558               0.955             3.798             0.447
#
#    KFAC_samples_Brier  KFAC_LB_MMC  KFAC_LB_auroc  KFAC_LB_NLL  KFAC_LB_ECE  \
# 0               0.008        0.969          0.000        0.189        0.022
# 1               0.136        0.775          0.855        4.864        0.670
# 2               0.121        0.749          0.924        4.723        0.635
#
#    KFAC_LB_Brier  KFAC_LB_norm_MMC  KFAC_LB_norm_auroc  KFAC_LB_norm_NLL  \
# 0          0.008             0.941               0.000             0.195
# 1          0.148             0.662               0.866             3.871
# 2          0.142             0.441               0.965             2.837
#
# ...

# %% [markdown]
# # SVHN

# %%
df_SVHN = pd.read_csv("SVHN_results.csv")
print(df_SVHN.columns)
df_SVHN
# Out:
# Index(['Unnamed: 0', 'MAP_MMC_in', 'MAP_MMC_CIFAR100', 'MAP_MMC_CIFAR10',
#        'MAP_AUROC_CIFAR100', 'MAP_AUROC_CIFAR10', 'MAP_NLL_in',
#        'MAP_NLL_CIFAR100', 'MAP_NLL_CIFAR10', 'MAP_ECE_in', 'MAP_ECE_CIFAR100',
#        'MAP_ECE_CIFAR10', 'Diag_samples_MMC_in', 'Diag_samples_MMC_CIFAR100',
#        'Diag_samples_MMC_CIFAR10', 'Diag_samples_AUROC_CIFAR100',
#        'Diag_samples_AUROC_CIFAR10', 'Diag_samples_NLL_in',
#        'Diag_samples_NLL_CIFAR100', 'Diag_samples_NLL_CIFAR10',
#        'Diag_samples_ECE_in', 'Diag_samples_ECE_CIFAR100',
#        'Diag_samples_ECE_CIFAR10', 'KFAC_samples_MMC_in',
#        'KFAC_samples_MMC_CIFAR100', 'KFAC_samples_MMC_CIFAR10',
#        'KFAC_samples_AUROC_CIFAR100', 'KFAC_samples_AUROC_CIFAR10',
#        'KFAC_samples_NLL_in', 'KFAC_samples_NLL_CIFAR100',
#        'KFAC_samples_NLL_CIFAR10', 'KFAC_samples_ECE_in',
#        'KFAC_samples_ECE_CIFAR100', 'KFAC_samples_ECE_CIFAR10',
# ...

# %%
data_SVHN = np.array([
    [df_SVHN['Diag_samples_MMC_in'].mean(), df_SVHN['Diag_samples_MMC_CIFAR100'].mean(),
     df_SVHN['Diag_samples_MMC_CIFAR10'].mean()],
    [0, df_SVHN['Diag_samples_AUROC_CIFAR100'].mean(), df_SVHN['Diag_samples_AUROC_CIFAR10'].mean()],
    [df_SVHN['Diag_samples_NLL_in'].mean(), df_SVHN['Diag_samples_NLL_CIFAR100'].mean(),
     df_SVHN['Diag_samples_NLL_CIFAR10'].mean()],
    [df_SVHN['Diag_samples_ECE_in'].mean(), df_SVHN['Diag_samples_ECE_CIFAR100'].mean(),
     df_SVHN['Diag_samples_ECE_CIFAR10'].mean()],
    [df_SVHN['Diag_LB_MMC_in'].mean(), df_SVHN['Diag_LB_MMC_CIFAR100'].mean(),
     df_SVHN['Diag_LB_MMC_CIFAR10'].mean()],
    [0, df_SVHN['Diag_LB_AUROC_CIFAR100'].mean(), df_SVHN['Diag_LB_AUROC_CIFAR10'].mean()],
    [df_SVHN['Diag_LB_NLL_in'].mean(), df_SVHN['Diag_LB_NLL_CIFAR100'].mean(),
     df_SVHN['Diag_LB_NLL_CIFAR10'].mean()],
    [df_SVHN['Diag_LB_ECE_in'].mean(), df_SVHN['Diag_LB_ECE_CIFAR100'].mean(),
     df_SVHN['Diag_LB_ECE_CIFAR10'].mean()],
    [df_SVHN['Diag_LB_norm_MMC_in'].mean(), df_SVHN['Diag_LB_norm_MMC_CIFAR100'].mean(),
     df_SVHN['Diag_LB_norm_MMC_CIFAR10'].mean()],
    [0, df_SVHN['Diag_LB_norm_AUROC_CIFAR100'].mean(), df_SVHN['Diag_LB_norm_AUROC_CIFAR10'].mean()],
    [df_SVHN['Diag_LB_norm_NLL_in'].mean(), df_SVHN['Diag_LB_norm_NLL_CIFAR100'].mean(),
     df_SVHN['Diag_LB_norm_NLL_CIFAR10'].mean()],
    [df_SVHN['Diag_LB_norm_ECE_in'].mean(), df_SVHN['Diag_LB_norm_ECE_CIFAR100'].mean(),
     df_SVHN['Diag_LB_norm_ECE_CIFAR10'].mean()],
    [df_SVHN['Diag_PROBIT_MMC_in'].mean(), df_SVHN['Diag_PROBIT_MMC_CIFAR100'].mean(),
     df_SVHN['Diag_PROBIT_MMC_CIFAR10'].mean()],
    [0, df_SVHN['Diag_PROBIT_AUROC_CIFAR100'].mean(), df_SVHN['Diag_PROBIT_AUROC_CIFAR10'].mean()],
    [df_SVHN['Diag_PROBIT_NLL_in'].mean(), df_SVHN['Diag_PROBIT_NLL_CIFAR100'].mean(),
     df_SVHN['Diag_PROBIT_NLL_CIFAR10'].mean()],
    [df_SVHN['Diag_PROBIT_ECE_in'].mean(), df_SVHN['Diag_PROBIT_ECE_CIFAR100'].mean(),
     df_SVHN['Diag_PROBIT_ECE_CIFAR10'].mean()],
#     [df_SVHN['Diag_EMK_MMC_in'].mean(), df_SVHN['Diag_EMK_MMC_CIFAR100'].mean(),
#      df_SVHN['Diag_EMK_MMC_CIFAR10'].mean()],
#     [0, df_SVHN['Diag_EMK_AUROC_CIFAR100'].mean(), df_SVHN['Diag_EMK_AUROC_CIFAR10'].mean()],
#     [df_SVHN['Diag_SODPP_MMC_in'].mean(), df_SVHN['Diag_SODPP_MMC_CIFAR100'].mean(),
#      df_SVHN['Diag_SODPP_MMC_CIFAR10'].mean()],
#     [0, df_SVHN['Diag_SODPP_AUROC_CIFAR100'].mean(), df_SVHN['Diag_SODPP_AUROC_CIFAR10'].mean()]
]).T

df_diag_SVHN = pd.DataFrame(data_SVHN, columns=[
    "Diag_samples_MMC", "Diag_samples_auroc", "Diag_samples_NLL", "Diag_samples_ECE",
    "Diag_LB_MMC", "Diag_LB_auroc", "Diag_LB_NLL", "Diag_LB_ECE",
    "Diag_LB_norm_MMC", "Diag_LB_norm_auroc", "Diag_LB_norm_NLL", "Diag_LB_norm_ECE",
    "Diag_PROBIT_MMC", "Diag_PROBIT_auroc", "Diag_PROBIT_NLL", "Diag_PROBIT_ECE"
])
df_diag_SVHN
# Out:
#    Diag_samples_MMC  Diag_samples_auroc  Diag_samples_NLL  Diag_samples_ECE  \
# 0             0.984               0.000             0.018             0.016
# 1             0.687               0.957             4.644             0.615
# 2             0.689               0.958             4.742             0.600
#
#    Diag_LB_MMC  Diag_LB_auroc  Diag_LB_NLL  Diag_LB_ECE  Diag_LB_norm_MMC  \
# 0        0.995          0.000        0.007        0.008             0.988
# 1        0.739          0.962        4.726        0.667             0.750
# 2        0.749          0.960        4.770        0.659             0.751
#
#    Diag_LB_norm_auroc  Diag_LB_norm_NLL  Diag_LB_norm_ECE  Diag_PROBIT_MMC  \
# 0               0.000             0.014             0.012            0.987
# 1               0.944             4.459             0.679            0.710
# 2               0.947             4.350             0.662            0.712
#
#    Diag_PROBIT_auroc  Diag_PROBIT_NLL  Diag_PROBIT_ECE
# ...

# %%
data_SVHN_K = np.array([
    [df_SVHN['KFAC_samples_MMC_in'].mean(), df_SVHN['KFAC_samples_MMC_CIFAR100'].mean(),
     df_SVHN['KFAC_samples_MMC_CIFAR10'].mean()],
    [0, df_SVHN['KFAC_samples_AUROC_CIFAR100'].mean(), df_SVHN['KFAC_samples_AUROC_CIFAR10'].mean()],
    [df_SVHN['KFAC_samples_NLL_in'].mean(), df_SVHN['KFAC_samples_NLL_CIFAR100'].mean(),
     df_SVHN['KFAC_samples_NLL_CIFAR10'].mean()],
    [df_SVHN['KFAC_samples_ECE_in'].mean(), df_SVHN['KFAC_samples_ECE_CIFAR100'].mean(),
     df_SVHN['KFAC_samples_ECE_CIFAR10'].mean()],
    [df_SVHN['KFAC_LB_MMC_in'].mean(), df_SVHN['KFAC_LB_MMC_CIFAR100'].mean(),
     df_SVHN['KFAC_LB_MMC_CIFAR10'].mean()],
    [0, df_SVHN['KFAC_LB_AUROC_CIFAR100'].mean(), df_SVHN['KFAC_LB_AUROC_CIFAR10'].mean()],
    [df_SVHN['KFAC_LB_NLL_in'].mean(), df_SVHN['KFAC_LB_NLL_CIFAR100'].mean(),
     df_SVHN['KFAC_LB_NLL_CIFAR10'].mean()],
    [df_SVHN['KFAC_LB_ECE_in'].mean(), df_SVHN['KFAC_LB_ECE_CIFAR100'].mean(),
     df_SVHN['KFAC_LB_ECE_CIFAR10'].mean()],
    [df_SVHN['KFAC_LB_norm_MMC_in'].mean(), df_SVHN['KFAC_LB_norm_MMC_CIFAR100'].mean(),
     df_SVHN['KFAC_LB_norm_MMC_CIFAR10'].mean()],
    [0, df_SVHN['KFAC_LB_norm_AUROC_CIFAR100'].mean(), df_SVHN['KFAC_LB_norm_AUROC_CIFAR10'].mean()],
    [df_SVHN['KFAC_LB_norm_NLL_in'].mean(), df_SVHN['KFAC_LB_norm_NLL_CIFAR100'].mean(),
     df_SVHN['KFAC_LB_norm_NLL_CIFAR10'].mean()],
    [df_SVHN['KFAC_LB_norm_ECE_in'].mean(), df_SVHN['KFAC_LB_norm_ECE_CIFAR100'].mean(),
     df_SVHN['KFAC_LB_norm_ECE_CIFAR10'].mean()],
    [df_SVHN['KFAC_PROBIT_MMC_in'].mean(), df_SVHN['KFAC_PROBIT_MMC_CIFAR100'].mean(),
     df_SVHN['KFAC_PROBIT_MMC_CIFAR10'].mean()],
    [0, df_SVHN['KFAC_PROBIT_AUROC_CIFAR100'].mean(), df_SVHN['KFAC_PROBIT_AUROC_CIFAR10'].mean()],
    [df_SVHN['KFAC_PROBIT_NLL_in'].mean(), df_SVHN['KFAC_PROBIT_NLL_CIFAR100'].mean(),
     df_SVHN['KFAC_PROBIT_NLL_CIFAR10'].mean()],
    [df_SVHN['KFAC_PROBIT_ECE_in'].mean(), df_SVHN['KFAC_PROBIT_ECE_CIFAR100'].mean(),
     df_SVHN['KFAC_PROBIT_ECE_CIFAR10'].mean()],
#     [df_SVHN['Diag_EMK_MMC_in'].mean(), df_SVHN['Diag_EMK_MMC_CIFAR100'].mean(),
#      df_SVHN['Diag_EMK_MMC_CIFAR10'].mean()],
#     [0, df_SVHN['Diag_EMK_AUROC_CIFAR100'].mean(), df_SVHN['Diag_EMK_AUROC_CIFAR10'].mean()],
#     [df_SVHN['Diag_SODPP_MMC_in'].mean(), df_SVHN['Diag_SODPP_MMC_CIFAR100'].mean(),
#      df_SVHN['Diag_SODPP_MMC_CIFAR10'].mean()],
#     [0, df_SVHN['Diag_SODPP_AUROC_CIFAR100'].mean(), df_SVHN['Diag_SODPP_AUROC_CIFAR10'].mean()]
]).T

df_SVHN_K = pd.DataFrame(data_SVHN_K, columns=[
    "KFAC_samples_MMC", "KFAC_samples_auroc", "KFAC_samples_NLL", "KFAC_samples_ECE",
    "KFAC_LB_MMC", "KFAC_LB_auroc", "KFAC_LB_NLL", "KFAC_LB_ECE",
    "KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc", "KFAC_LB_norm_NLL", "KFAC_LB_norm_ECE",
    "KFAC_PROBIT_MMC", "KFAC_PROBIT_auroc", "KFAC_PROBIT_NLL", "KFAC_PROBIT_ECE"
])
df_SVHN_K
# Out:
#    KFAC_samples_MMC  KFAC_samples_auroc  KFAC_samples_NLL  KFAC_samples_ECE  \
# 0             0.983               0.000             0.020             0.019
# 1             0.655               0.959             4.462             0.583
# 2             0.657               0.960             4.571             0.567
#
#    KFAC_LB_MMC  KFAC_LB_auroc  KFAC_LB_NLL  KFAC_LB_ECE  KFAC_LB_norm_MMC  \
# 0        0.994          0.000        0.008        0.009             0.985
# 1        0.730          0.962        4.665        0.659             0.644
# 2        0.740          0.959        4.663        0.651             0.646
#
#    KFAC_LB_norm_auroc  KFAC_LB_norm_NLL  KFAC_LB_norm_ECE  KFAC_PROBIT_MMC  \
# 0               0.000             0.019             0.017            0.905
# 1               0.953             4.127             0.575            0.537
# 2               0.955             3.939             0.556            0.538
#
#    KFAC_PROBIT_auroc  KFAC_PROBIT_NLL  KFAC_PROBIT_ECE
# ...

# %% [markdown]
# # CIFAR100

# %%
df_CIFAR100 = pd.read_csv("CIFAR100_results.csv")
print(df_CIFAR100.columns)
df_CIFAR100
# Out:
# Index(['Unnamed: 0', 'MAP_MMC_in', 'MAP_MMC_CIFAR10', 'MAP_MMC_SVHN',
#        'MAP_AUROC_CIFAR10', 'MAP_AUROC_SVHN', 'MAP_NLL_in', 'MAP_NLL_CIFAR10',
#        'MAP_NLL_SVHN', 'MAP_ECE_in', 'MAP_ECE_CIFAR10', 'MAP_ECE_SVHN',
#        'Diag_samples_MMC_in', 'Diag_samples_MMC_CIFAR10',
#        'Diag_samples_MMC_SVHN', 'Diag_samples_AUROC_CIFAR10',
#        'Diag_samples_AUROC_SVHN', 'Diag_samples_NLL_in',
#        'Diag_samples_NLL_CIFAR10', 'Diag_samples_NLL_SVHN',
#        'Diag_samples_ECE_in', 'Diag_samples_ECE_CIFAR10',
#        'Diag_samples_ECE_SVHN', 'KFAC_samples_MMC_in',
#        'KFAC_samples_MMC_CIFAR10', 'KFAC_samples_MMC_SVHN',
#        'KFAC_samples_AUROC_CIFAR10', 'KFAC_samples_AUROC_SVHN',
#        'KFAC_samples_NLL_in', 'KFAC_samples_NLL_CIFAR10',
#        'KFAC_samples_NLL_SVHN', 'KFAC_samples_ECE_in',
#        'KFAC_samples_ECE_CIFAR10', 'KFAC_samples_ECE_SVHN', 'Diag_LB_MMC_in',
#        'Diag_LB_MMC_CIFAR10', 'Diag_LB_MMC_SVHN', 'Diag_LB_AUROC_CIFAR10',
# ...

# %%
data_CIFAR100 = np.array([
    [df_CIFAR100['Diag_samples_MMC_in'].mean(), df_CIFAR100['Diag_samples_MMC_CIFAR10'].mean(),
     df_CIFAR100['Diag_samples_MMC_SVHN'].mean()],
    [0, df_CIFAR100['Diag_samples_AUROC_CIFAR10'].mean(), df_CIFAR100['Diag_samples_AUROC_SVHN'].mean()],
    [df_CIFAR100['Diag_samples_NLL_in'].mean(), df_CIFAR100['Diag_samples_NLL_CIFAR10'].mean(),
     df_CIFAR100['Diag_samples_NLL_SVHN'].mean()],
    [df_CIFAR100['Diag_samples_ECE_in'].mean(), df_CIFAR100['Diag_samples_ECE_CIFAR10'].mean(),
     df_CIFAR100['Diag_samples_ECE_SVHN'].mean()],
    [df_CIFAR100['Diag_LB_MMC_in'].mean(), df_CIFAR100['Diag_LB_MMC_CIFAR10'].mean(),
     df_CIFAR100['Diag_LB_MMC_SVHN'].mean()],
    [0, df_CIFAR100['Diag_LB_AUROC_CIFAR10'].mean(), df_CIFAR100['Diag_LB_AUROC_SVHN'].mean()],
    [df_CIFAR100['Diag_LB_NLL_in'].mean(), df_CIFAR100['Diag_LB_NLL_CIFAR10'].mean(),
     df_CIFAR100['Diag_LB_NLL_SVHN'].mean()],
    [df_CIFAR100['Diag_LB_ECE_in'].mean(), df_CIFAR100['Diag_LB_ECE_CIFAR10'].mean(),
     df_CIFAR100['Diag_LB_ECE_SVHN'].mean()],
    [df_CIFAR100['Diag_LB_norm_MMC_in'].mean(), df_CIFAR100['Diag_LB_norm_MMC_CIFAR10'].mean(),
     df_CIFAR100['Diag_LB_norm_MMC_SVHN'].mean()],
    [0, df_CIFAR100['Diag_LB_norm_AUROC_CIFAR10'].mean(), df_CIFAR100['Diag_LB_norm_AUROC_SVHN'].mean()],
    [df_CIFAR100['Diag_LB_norm_NLL_in'].mean(), df_CIFAR100['Diag_LB_norm_NLL_CIFAR10'].mean(),
     df_CIFAR100['Diag_LB_norm_NLL_SVHN'].mean()],
    [df_CIFAR100['Diag_LB_norm_ECE_in'].mean(), df_CIFAR100['Diag_LB_norm_ECE_CIFAR10'].mean(),
     df_CIFAR100['Diag_LB_norm_ECE_SVHN'].mean()],
    [df_CIFAR100['Diag_PROBIT_MMC_in'].mean(), df_CIFAR100['Diag_PROBIT_MMC_CIFAR10'].mean(),
     df_CIFAR100['Diag_PROBIT_MMC_SVHN'].mean()],
    [0, df_CIFAR100['Diag_PROBIT_AUROC_CIFAR10'].mean(), df_CIFAR100['Diag_PROBIT_AUROC_SVHN'].mean()],
    [df_CIFAR100['Diag_PROBIT_NLL_in'].mean(), df_CIFAR100['Diag_PROBIT_NLL_CIFAR10'].mean(),
     df_CIFAR100['Diag_PROBIT_NLL_SVHN'].mean()],
    [df_CIFAR100['Diag_PROBIT_ECE_in'].mean(), df_CIFAR100['Diag_PROBIT_ECE_CIFAR10'].mean(),
     df_CIFAR100['Diag_PROBIT_ECE_SVHN'].mean()],
]).T

df_diag_CIFAR100 = pd.DataFrame(data_CIFAR100, columns=[
    "Diag_samples_MMC", "Diag_samples_auroc", "Diag_samples_NLL", "Diag_samples_ECE",
    "Diag_LB_MMC", "Diag_LB_auroc", "Diag_LB_NLL", "Diag_LB_ECE",
    "Diag_LB_norm_MMC", "Diag_LB_norm_auroc", "Diag_LB_norm_NLL", "Diag_LB_norm_ECE",
    "Diag_PROBIT_MMC", "Diag_PROBIT_auroc", "Diag_PROBIT_NLL", "Diag_PROBIT_ECE"
])
df_diag_CIFAR100
# Out:
#    Diag_samples_MMC  Diag_samples_auroc  Diag_samples_NLL  Diag_samples_ECE  \
# 0             0.776               0.000             0.894             0.037
# 1             0.480               0.788             6.667             0.474
# 2             0.472               0.795             6.712             0.470
#
#    Diag_LB_MMC  Diag_LB_auroc  Diag_LB_NLL  Diag_LB_ECE  Diag_LB_norm_MMC  \
# 0        0.632          0.000        1.321        0.149             0.942
# 1        0.245          0.791        5.215        0.239             0.841
# 2        0.209          0.815        5.073        0.207             0.846
#
#    Diag_LB_norm_auroc  Diag_LB_norm_NLL  Diag_LB_norm_ECE  Diag_PROBIT_MMC  \
# 0               0.000             1.575             0.171            0.778
# 1               0.757            13.129             0.834            0.476
# 2               0.748            12.833             0.842            0.468
#
#    Diag_PROBIT_auroc  Diag_PROBIT_NLL  Diag_PROBIT_ECE
# ...

# %%
data_CIFAR100_K = np.array([
    [df_CIFAR100['KFAC_samples_MMC_in'].mean(), df_CIFAR100['KFAC_samples_MMC_CIFAR10'].mean(),
     df_CIFAR100['KFAC_samples_MMC_SVHN'].mean()],
    [0, df_CIFAR100['KFAC_samples_AUROC_CIFAR10'].mean(), df_CIFAR100['KFAC_samples_AUROC_SVHN'].mean()],
    [df_CIFAR100['KFAC_samples_NLL_in'].mean(), df_CIFAR100['KFAC_samples_NLL_CIFAR10'].mean(),
     df_CIFAR100['KFAC_samples_NLL_SVHN'].mean()],
    [df_CIFAR100['KFAC_samples_ECE_in'].mean(), df_CIFAR100['KFAC_samples_ECE_CIFAR10'].mean(),
     df_CIFAR100['KFAC_samples_ECE_SVHN'].mean()],
    [df_CIFAR100['KFAC_LB_MMC_in'].mean(), df_CIFAR100['KFAC_LB_MMC_CIFAR10'].mean(),
     df_CIFAR100['KFAC_LB_MMC_SVHN'].mean()],
    [0, df_CIFAR100['KFAC_LB_AUROC_CIFAR10'].mean(), df_CIFAR100['KFAC_LB_AUROC_SVHN'].mean()],
    [df_CIFAR100['KFAC_LB_NLL_in'].mean(), df_CIFAR100['KFAC_LB_NLL_CIFAR10'].mean(),
     df_CIFAR100['KFAC_LB_NLL_SVHN'].mean()],
    [df_CIFAR100['KFAC_LB_ECE_in'].mean(), df_CIFAR100['KFAC_LB_ECE_CIFAR10'].mean(),
     df_CIFAR100['KFAC_LB_ECE_SVHN'].mean()],
    [df_CIFAR100['KFAC_LB_norm_MMC_in'].mean(), df_CIFAR100['KFAC_LB_norm_MMC_CIFAR10'].mean(),
     df_CIFAR100['KFAC_LB_norm_MMC_SVHN'].mean()],
    [0, df_CIFAR100['KFAC_LB_norm_AUROC_CIFAR10'].mean(), df_CIFAR100['KFAC_LB_norm_AUROC_SVHN'].mean()],
    [df_CIFAR100['KFAC_LB_norm_NLL_in'].mean(), df_CIFAR100['KFAC_LB_norm_NLL_CIFAR10'].mean(),
     df_CIFAR100['KFAC_LB_norm_NLL_SVHN'].mean()],
    [df_CIFAR100['KFAC_LB_norm_ECE_in'].mean(), df_CIFAR100['KFAC_LB_norm_ECE_CIFAR10'].mean(),
     df_CIFAR100['KFAC_LB_norm_ECE_SVHN'].mean()],
    [df_CIFAR100['KFAC_PROBIT_MMC_in'].mean(), df_CIFAR100['KFAC_PROBIT_MMC_CIFAR10'].mean(),
     df_CIFAR100['KFAC_PROBIT_MMC_SVHN'].mean()],
    [0, df_CIFAR100['KFAC_PROBIT_AUROC_CIFAR10'].mean(), df_CIFAR100['KFAC_PROBIT_AUROC_SVHN'].mean()],
    [df_CIFAR100['KFAC_PROBIT_NLL_in'].mean(), df_CIFAR100['KFAC_PROBIT_NLL_CIFAR10'].mean(),
     df_CIFAR100['KFAC_PROBIT_NLL_SVHN'].mean()],
    [df_CIFAR100['KFAC_PROBIT_ECE_in'].mean(), df_CIFAR100['KFAC_PROBIT_ECE_CIFAR10'].mean(),
     df_CIFAR100['KFAC_PROBIT_ECE_SVHN'].mean()],
]).T

df_KFAC_CIFAR100 = pd.DataFrame(data_CIFAR100_K, columns=[
    "KFAC_samples_MMC", "KFAC_samples_auroc", "KFAC_samples_NLL", "KFAC_samples_ECE",
    "KFAC_LB_MMC", "KFAC_LB_auroc", "KFAC_LB_NLL", "KFAC_LB_ECE",
    "KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc", "KFAC_LB_norm_NLL", "KFAC_LB_norm_ECE",
    "KFAC_PROBIT_MMC", "KFAC_PROBIT_auroc", "KFAC_PROBIT_NLL", "KFAC_PROBIT_ECE"
])
df_KFAC_CIFAR100
# Out:
#    KFAC_samples_MMC  KFAC_samples_auroc  KFAC_samples_NLL  KFAC_samples_ECE  \
# 0             0.776               0.000             0.889             0.034
# 1             0.485               0.787             6.709             0.479
# 2             0.472               0.798             6.740             0.469
#
#    KFAC_LB_MMC  KFAC_LB_auroc  KFAC_LB_NLL  KFAC_LB_ECE  KFAC_LB_norm_MMC  \
# 0        0.589          0.000        1.437        0.179             0.949
# 1        0.207          0.790        5.151        0.202             0.863
# 2        0.185          0.807        5.029        0.183             0.853
#
#    KFAC_LB_norm_auroc  KFAC_LB_norm_NLL  KFAC_LB_norm_ECE  KFAC_PROBIT_MMC  \
# 0               0.000             1.755             0.179            0.755
# 1               0.749            14.254             0.855            0.454
# 2               0.761            13.261             0.849            0.441
#
#    KFAC_PROBIT_auroc  KFAC_PROBIT_NLL  KFAC_PROBIT_ECE
# ...

# %% [markdown]
# # create one big table with all results for OOD detection

# %%
columns_d = ["Diag_samples_ECE", "Diag_samples_auroc", "Diag_LB_ECE", "Diag_LB_auroc", "Diag_LB_norm_ECE", "Diag_LB_norm_auroc"]
columns_k = ["KFAC_samples_ECE", "KFAC_samples_auroc", "KFAC_LB_ECE", "KFAC_LB_auroc", "KFAC_LB_norm_ECE", "KFAC_LB_norm_auroc"]

# %%
# check ECE and AUROC for all combinations that are actually OOD
MNIST_df_diag_kfac = pd.concat([df_MNIST_diag[columns_d], df_MNIST_kron[columns_k]], axis=1)
CIFAR10_df_diag_kfac = pd.concat([df_diag_CIFAR10[columns_d], df_CIFAR10_K[columns_k]], axis=1)
SVHN_df_diag_kfac = pd.concat([df_diag_SVHN[columns_d], df_SVHN_K[columns_k]], axis=1)
CIFAR100_df_diag_kfac = pd.concat([df_diag_CIFAR100[columns_d], df_KFAC_CIFAR100[columns_k]], axis=1)

# concat rows
all_df = pd.concat([MNIST_df_diag_kfac, CIFAR10_df_diag_kfac, SVHN_df_diag_kfac, CIFAR100_df_diag_kfac], axis=0).reset_index()

# add named columns
name_columns = pd.DataFrame({
    "Train":["MNIST", "MNIST", "MNIST", "MNIST", "CIFAR10", "CIFAR10", "CIFAR10", 
             "SVHN", "SVHN", "SVHN", "CIFAR100", "CIFAR100", "CIFAR100"],
    "Test":["MNIST", "FMNIST", "notMNIST", "KMNIST", "CIFAR10", "CIFAR100", "SVHN", 
             "SVHN", "CIFAR100", "CIFAR10", "CIFAR100", "CIFAR10", "SVHN"]
})

# combine all
all_df = pd.concat([name_columns, all_df], axis=1).drop(['index'], axis=1)
# drop in dist rows
all_df = all_df.drop([0, 4, 7, 10])
all_df
# Out:
#        Train      Test  Diag_samples_ECE  Diag_samples_auroc  Diag_LB_ECE  \
# 1      MNIST    FMNIST             0.464               0.975        0.478
# 2      MNIST  notMNIST             0.396               0.965        0.600
# 3      MNIST    KMNIST             0.429               0.974        0.617
# 5    CIFAR10  CIFAR100             0.379               0.887        0.691
# 6    CIFAR10      SVHN             0.309               0.948        0.652
# 8       SVHN  CIFAR100             0.615               0.957        0.667
# 9       SVHN   CIFAR10             0.600               0.958        0.659
# 11  CIFAR100   CIFAR10             0.474               0.788        0.239
# 12  CIFAR100      SVHN             0.470               0.795        0.207
#
#     Diag_LB_auroc  Diag_LB_norm_ECE  Diag_LB_norm_auroc  KFAC_samples_ECE  \
# 1           0.981             0.498               0.951             0.390
# 2           0.930             0.360               0.955             0.366
# ...

# %%
print(all_df.to_latex(index=False))
# Out:
# \begin{tabular}{llrrrrrrrrrrrr}
# \toprule
#    Train &     Test &  Diag\_samples\_ECE &  Diag\_samples\_auroc &  Diag\_LB\_ECE &  Diag\_LB\_auroc &  Diag\_LB\_norm\_ECE &  Diag\_LB\_norm\_auroc &  KFAC\_samples\_ECE &  KFAC\_samples\_auroc &  KFAC\_LB\_ECE &  KFAC\_LB\_auroc &  KFAC\_LB\_norm\_ECE &  KFAC\_LB\_norm\_auroc \\
# \midrule
#    MNIST &   FMNIST &             0.464 &               0.975 &        0.478 &          0.981 &             0.498 &               0.951 &             0.390 &               0.987 &        0.553 &          0.977 &             0.364 &               0.990 \\
#    MNIST & notMNIST &             0.396 &               0.965 &        0.600 &          0.930 &             0.360 &               0.955 &             0.366 &               0.974 &        0.634 &          0.912 &             0.294 &               0.986 \\
# ...

# %% [markdown]
# ## Create the LB vs PROBIT comparison table KFAC

# %%
columns_k = ["KFAC_PROBIT_MMC", "KFAC_PROBIT_auroc", "KFAC_PROBIT_NLL", "KFAC_PROBIT_ECE", "KFAC_PROBIT_Brier",
             "KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc", "KFAC_LB_norm_NLL", "KFAC_LB_norm_ECE", "KFAC_LB_norm_Brier"]

MNIST_df_kfac = df_MNIST_kron[columns_k]
CIFAR10_df_kfac = df_CIFAR10_K[columns_k]

probit_vs_lb_df = pd.concat([MNIST_df_kfac, CIFAR10_df_kfac], axis=0).reset_index()

# add named columns
name_columns = pd.DataFrame({
    "Train":["MNIST", "MNIST", "MNIST", "MNIST", "CIFAR10", "CIFAR10", "CIFAR10"],
    "Test":["MNIST", "FMNIST", "notMNIST", "KMNIST", "CIFAR10", "CIFAR100", "SVHN"]
})

probit_vs_lb_df = pd.concat([name_columns, probit_vs_lb_df], axis=1).drop(['index'], axis=1)
probit_vs_lb_df
# Out:
#      Train      Test  KFAC_PROBIT_MMC  KFAC_PROBIT_auroc  KFAC_PROBIT_NLL  \
# 0    MNIST     MNIST            0.105              0.000            2.258
# 1    MNIST    FMNIST            0.102              0.955            2.302
# 2    MNIST  notMNIST            0.103              0.922            2.300
# 3    MNIST    KMNIST            0.102              0.962            2.304
# 4  CIFAR10   CIFAR10            0.548              0.000            0.661
# 5  CIFAR10  CIFAR100            0.358              0.896            2.652
# 6  CIFAR10      SVHN            0.307              0.956            2.567
#
#    KFAC_PROBIT_ECE  KFAC_PROBIT_Brier  KFAC_LB_norm_MMC  KFAC_LB_norm_auroc  \
# 0            0.883              0.089             0.975               0.000
# 1            0.032              0.090             0.444               0.990
# 2            0.043              0.090             0.409               0.986
# ...

# %%
print(probit_vs_lb_df.to_latex(index=False))
# Out:
# \begin{tabular}{llrrrrrrrrrr}
# \toprule
#   Train &     Test &  KFAC\_PROBIT\_MMC &  KFAC\_PROBIT\_auroc &  KFAC\_PROBIT\_NLL &  KFAC\_PROBIT\_ECE &  KFAC\_PROBIT\_Brier &  KFAC\_LB\_norm\_MMC &  KFAC\_LB\_norm\_auroc &  KFAC\_LB\_norm\_NLL &  KFAC\_LB\_norm\_ECE &  KFAC\_LB\_norm\_Brier \\
# \midrule
#   MNIST &    MNIST &            0.105 &              0.000 &            2.258 &            0.883 &              0.089 &             0.975 &               0.000 &             0.043 &             0.018 &               0.002 \\
#   MNIST &   FMNIST &            0.102 &              0.955 &            2.302 &            0.032 &              0.090 &             0.444 &               0.990 &             2.871 &             0.364 &               0.111 \\
#   MNIST & notMNIST &            0.103 &              0.922 &            2.300 &            0.043 &              0.090 &             0.409 &               0.986 &             2.854 &             0.294 &               0.106 \\
# ...

# %% [markdown]
# ## Create the LB vs PROBIT comparison table diag

# %%
columns_d = ["Diag_PROBIT_MMC", "Diag_PROBIT_auroc", "Diag_PROBIT_NLL", "Diag_PROBIT_ECE", "Diag_PROBIT_Brier",
             "Diag_LB_norm_MMC", "Diag_LB_norm_auroc", "Diag_LB_norm_NLL", "Diag_LB_norm_ECE", "Diag_LB_norm_Brier"]

MNIST_df_diag = df_MNIST_diag[columns_d]
CIFAR10_df_diag = df_diag_CIFAR10[columns_d]

probit_vs_lb_df_d = pd.concat([MNIST_df_diag, CIFAR10_df_diag], axis=0).reset_index()

# add named columns
name_columns = pd.DataFrame({
    "Train":["MNIST", "MNIST", "MNIST", "MNIST", "CIFAR10", "CIFAR10", "CIFAR10"],
    "Test":["MNIST", "FMNIST", "notMNIST", "KMNIST", "CIFAR10", "CIFAR100", "SVHN"]
})

probit_vs_lb_df_d = pd.concat([name_columns, probit_vs_lb_df_d], axis=1).drop(['index'], axis=1)
probit_vs_lb_df_d
# Out:
#      Train      Test  Diag_PROBIT_MMC  Diag_PROBIT_auroc  Diag_PROBIT_NLL  \
# 0    MNIST     MNIST            0.967              0.000            0.050
# 1    MNIST    FMNIST            0.597              0.971            3.827
# 2    MNIST  notMNIST            0.616              0.958            3.839
# 3    MNIST    KMNIST            0.580              0.969            4.276
# 4  CIFAR10   CIFAR10            0.869              0.000            0.237
# 5  CIFAR10  CIFAR100            0.589              0.882            3.334
# 6  CIFAR10      SVHN            0.510              0.946            3.097
#
#    Diag_PROBIT_ECE  Diag_PROBIT_Brier  Diag_LB_norm_MMC  Diag_LB_norm_auroc  \
# 0            0.024              0.002             0.944               0.000
# 1            0.523              0.128             0.589               0.951
# 2            0.488              0.123             0.492               0.955
# ...

# %%
print(probit_vs_lb_df_d.to_latex(index=False))
# Out:
# \begin{tabular}{llrrrrrrrrrr}
# \toprule
#   Train &     Test &  Diag\_PROBIT\_MMC &  Diag\_PROBIT\_auroc &  Diag\_PROBIT\_NLL &  Diag\_PROBIT\_ECE &  Diag\_PROBIT\_Brier &  Diag\_LB\_norm\_MMC &  Diag\_LB\_norm\_auroc &  Diag\_LB\_norm\_NLL &  Diag\_LB\_norm\_ECE &  Diag\_LB\_norm\_Brier \\
# \midrule
#   MNIST &    MNIST &            0.967 &              0.000 &            0.050 &            0.024 &              0.002 &             0.944 &               0.000 &             0.078 &             0.045 &               0.003 \\
#   MNIST &   FMNIST &            0.597 &              0.971 &            3.827 &            0.523 &              0.128 &             0.589 &               0.951 &             3.538 &             0.498 &               0.124 \\
#   MNIST & notMNIST &            0.616 &              0.958 &            3.839 &            0.488 &              0.123 &             0.492 &               0.955 &             3.070 &             0.360 &               0.111 \\
# ...

# %% [markdown]
# # Compare to all layer

# %%
df_MNIST_all = pd.read_csv("MNIST_results_all_layers.csv")
print(df_MNIST_all.columns)
df_MNIST_all
# Out:
# Index(['Unnamed: 0', 'MAP_MMC_in', 'MAP_MMC_FMNIST', 'MAP_MMC_notMNIST',
#        'MAP_MMC_KMNIST', 'MAP_AUROC_FMNIST', 'MAP_AUROC_notMNIST',
#        'MAP_AUROC_KMNIST', 'MAP_NLL_in', 'MAP_NLL_FMNIST',
#        ...
#        'KFAC_PROBIT_NLL_notMNIST', 'KFAC_PROBIT_NLL_KMNIST',
#        'KFAC_PROBIT_ECE_in', 'KFAC_PROBIT_ECE_FMNIST',
#        'KFAC_PROBIT_ECE_notMNIST', 'KFAC_PROBIT_ECE_KMNIST',
#        'KFAC_PROBIT_Brier_in', 'KFAC_PROBIT_Brier_FMNIST',
#        'KFAC_PROBIT_Brier_notMNIST', 'KFAC_PROBIT_Brier_KMNIST'],
#       dtype='object', length=172)
#    Unnamed: 0  MAP_MMC_in  MAP_MMC_FMNIST  MAP_MMC_notMNIST  MAP_MMC_KMNIST  \
# 0           0       0.986           0.663             0.774           0.723
# 1           1       0.986           0.663             0.774           0.723
# 2           2       0.986           0.663             0.774           0.723
# 3           3       0.986           0.663             0.774           0.723
# ...

# %%
data_MNIST_all = np.array([
    #["MNIST", "MNIST", "MNIST", "MNIST"],
    #["MNIST", "FMNIST", "notMNIST", "KMNIST"],
    [df_MNIST_all['Diag_samples_MMC_in'].mean(), df_MNIST_all['Diag_samples_MMC_FMNIST'].mean(),
     df_MNIST_all['Diag_samples_MMC_notMNIST'].mean(), df_MNIST_all['Diag_samples_MMC_KMNIST'].mean()],
    [0, df_MNIST_all['Diag_samples_AUROC_FMNIST'].mean(), df_MNIST_all['Diag_samples_AUROC_notMNIST'].mean(),
     df_MNIST_all['Diag_samples_AUROC_KMNIST'].mean()],
    [df_MNIST_all['Diag_samples_NLL_in'].mean(), df_MNIST_all['Diag_samples_NLL_FMNIST'].mean(),
     df_MNIST_all['Diag_samples_NLL_notMNIST'].mean(), df_MNIST_all['Diag_samples_NLL_KMNIST'].mean()],
    [df_MNIST_all['Diag_samples_ECE_in'].mean(), df_MNIST_all['Diag_samples_ECE_FMNIST'].mean(),
     df_MNIST_all['Diag_samples_ECE_notMNIST'].mean(), df_MNIST_all['Diag_samples_ECE_KMNIST'].mean()],
    [df_MNIST_all['Diag_samples_Brier_in'].mean(), df_MNIST_all['Diag_samples_Brier_FMNIST'].mean(),
     df_MNIST_all['Diag_samples_Brier_notMNIST'].mean(), df_MNIST_all['Diag_samples_Brier_KMNIST'].mean()],
    [df_MNIST_all['Diag_LB_MMC_in'].mean(), df_MNIST_all['Diag_LB_MMC_FMNIST'].mean(), 
     df_MNIST_all['Diag_LB_MMC_notMNIST'].mean(), df_MNIST_all['Diag_LB_MMC_KMNIST'].mean()], 
    [0, df_MNIST_all['Diag_LB_AUROC_FMNIST'].mean(), df_MNIST_all['Diag_LB_AUROC_notMNIST'].mean(),
     df_MNIST_all['Diag_LB_AUROC_KMNIST'].mean()],
    [df_MNIST_all['Diag_LB_NLL_in'].mean(), df_MNIST_all['Diag_LB_NLL_FMNIST'].mean(), 
     df_MNIST_all['Diag_LB_NLL_notMNIST'].mean(), df_MNIST_all['Diag_LB_NLL_KMNIST'].mean()], 
    [df_MNIST_all['Diag_LB_ECE_in'].mean(), df_MNIST_all['Diag_LB_ECE_FMNIST'].mean(), 
     df_MNIST_all['Diag_LB_ECE_notMNIST'].mean(), df_MNIST_all['Diag_LB_ECE_KMNIST'].mean()], 
    [df_MNIST_all['Diag_LB_Brier_in'].mean(), df_MNIST_all['Diag_LB_Brier_FMNIST'].mean(), 
     df_MNIST_all['Diag_LB_Brier_notMNIST'].mean(), df_MNIST_all['Diag_LB_Brier_KMNIST'].mean()], 
    [df_MNIST_all['Diag_LB_norm_MMC_in'].mean(), df_MNIST_all['Diag_LB_norm_MMC_FMNIST'].mean(), 
     df_MNIST_all['Diag_LB_norm_MMC_notMNIST'].mean(), df_MNIST_all['Diag_LB_norm_MMC_KMNIST'].mean()], 
    [0, df_MNIST_all['Diag_LB_norm_AUROC_FMNIST'].mean(), df_MNIST_all['Diag_LB_norm_AUROC_notMNIST'].mean(),
     df_MNIST_all['Diag_LB_norm_AUROC_KMNIST'].mean()],
    [df_MNIST_all['Diag_LB_norm_NLL_in'].mean(), df_MNIST_all['Diag_LB_norm_NLL_FMNIST'].mean(), 
     df_MNIST_all['Diag_LB_norm_NLL_notMNIST'].mean(), df_MNIST_all['Diag_LB_norm_NLL_KMNIST'].mean()], 
    [df_MNIST_all['Diag_LB_norm_ECE_in'].mean(), df_MNIST_all['Diag_LB_norm_ECE_FMNIST'].mean(), 
     df_MNIST_all['Diag_LB_norm_ECE_notMNIST'].mean(), df_MNIST_all['Diag_LB_norm_ECE_KMNIST'].mean()], 
    [df_MNIST_all['Diag_LB_norm_Brier_in'].mean(), df_MNIST_all['Diag_LB_norm_Brier_FMNIST'].mean(), 
     df_MNIST_all['Diag_LB_norm_Brier_notMNIST'].mean(), df_MNIST_all['Diag_LB_norm_Brier_KMNIST'].mean()], 
    [df_MNIST_all['Diag_PROBIT_MMC_in'].mean(), df_MNIST_all['Diag_PROBIT_MMC_FMNIST'].mean(), 
     df_MNIST_all['Diag_PROBIT_MMC_notMNIST'].mean(), df_MNIST_all['Diag_PROBIT_MMC_KMNIST'].mean()], 
    [0, df_MNIST_all['Diag_PROBIT_AUROC_FMNIST'].mean(), df_MNIST_all['Diag_PROBIT_AUROC_notMNIST'].mean(),
     df_MNIST_all['Diag_PROBIT_AUROC_KMNIST'].mean()], 
    [df_MNIST_all['Diag_PROBIT_NLL_in'].mean(), df_MNIST_all['Diag_PROBIT_NLL_FMNIST'].mean(), 
     df_MNIST_all['Diag_PROBIT_NLL_notMNIST'].mean(), df_MNIST_all['Diag_PROBIT_NLL_KMNIST'].mean()],  
    [df_MNIST_all['Diag_PROBIT_ECE_in'].mean(), df_MNIST_all['Diag_PROBIT_ECE_FMNIST'].mean(), 
     df_MNIST_all['Diag_PROBIT_ECE_notMNIST'].mean(), df_MNIST_all['Diag_PROBIT_ECE_KMNIST'].mean()],  
    [df_MNIST_all['Diag_PROBIT_Brier_in'].mean(), df_MNIST_all['Diag_PROBIT_Brier_FMNIST'].mean(), 
     df_MNIST_all['Diag_PROBIT_Brier_notMNIST'].mean(), df_MNIST_all['Diag_PROBIT_Brier_KMNIST'].mean()], 
#     [df['Diag_SODPP_MMC_in'].mean(), df['Diag_SODPP_MMC_FMNIST'].mean(), 
#      df['Diag_SODPP_MMC_notMNIST'].mean(), df['Diag_SODPP_MMC_KMNIST'].mean()], 
#     [0, df['Diag_SODPP_AUROC_FMNIST'].mean(), df['Diag_SODPP_AUROC_notMNIST'].mean(),
#      df['Diag_SODPP_AUROC_KMNIST'].mean()],
]).T

df_MNIST_all_diag = pd.DataFrame(data_MNIST_all, columns=[
    #"In", "Out",
    "Diag_samples_MMC", "Diag_samples_auroc", "Diag_samples_NLL", "Diag_samples_ECE", "Diag_samples_Brier",
    "Diag_LB_MMC", "Diag_LB_auroc", "Diag_LB_NLL", "Diag_LB_ECE", "Diag_LB_Brier",
    "Diag_LB_norm_MMC", "Diag_LB_norm_auroc", "Diag_LB_norm_NLL", "Diag_LB_norm_ECE", "Diag_LB_norm_Brier",
    "Diag_PROBIT_MMC", "Diag_PROBIT_auroc", "Diag_PROBIT_NLL", "Diag_PROBIT_ECE", "Diag_PROBIT_Brier",
    #"Diag_SODPP_MMC", "Diag_SODPP_auroc"
])
df_MNIST_all_diag
# Out:
#    Diag_samples_MMC  Diag_samples_auroc  Diag_samples_NLL  Diag_samples_ECE  \
# 0             0.855               0.000             0.179             0.134
# 1             0.392               0.980             3.054             0.317
# 2             0.431               0.960             3.281             0.280
# 3             0.401               0.976             3.769             0.309
#
#    Diag_samples_Brier  Diag_LB_MMC  Diag_LB_auroc  Diag_LB_NLL  Diag_LB_ECE  \
# 0               0.006        0.975          0.000        0.053        0.015
# 1               0.105        0.396          0.990        3.022        0.322
# 2               0.103        0.694          0.924        5.207        0.566
# 3               0.108        0.651          0.955        4.973        0.557
#
#    Diag_LB_Brier  Diag_LB_norm_MMC  Diag_LB_norm_auroc  Diag_LB_norm_NLL  \
# 0          0.002             0.656               0.000             0.484
# ...

# %%
data_MNIST_all_kron = np.array([
    #["MNIST", "MNIST", "MNIST", "MNIST"],
    #["MNIST", "FMNIST", "notMNIST", "KMNIST"],
    [df_MNIST_all['KFAC_samples_MMC_in'].mean(), df_MNIST_all['KFAC_samples_MMC_FMNIST'].mean(),
     df_MNIST_all['KFAC_samples_MMC_notMNIST'].mean(), df_MNIST_all['KFAC_samples_MMC_KMNIST'].mean()],
    [0, df_MNIST_all['KFAC_samples_AUROC_FMNIST'].mean(), df_MNIST_all['KFAC_samples_AUROC_notMNIST'].mean(),
     df_MNIST_all['KFAC_samples_AUROC_KMNIST'].mean()],
    [df_MNIST_all['KFAC_samples_NLL_in'].mean(), df_MNIST_all['KFAC_samples_NLL_FMNIST'].mean(),
     df_MNIST_all['KFAC_samples_NLL_notMNIST'].mean(), df_MNIST_all['KFAC_samples_NLL_KMNIST'].mean()],
    [df_MNIST_all['KFAC_samples_ECE_in'].mean(), df_MNIST_all['KFAC_samples_ECE_FMNIST'].mean(),
     df_MNIST_all['KFAC_samples_ECE_notMNIST'].mean(), df_MNIST_all['KFAC_samples_ECE_KMNIST'].mean()],
    [df_MNIST_all['KFAC_samples_Brier_in'].mean(), df_MNIST_all['KFAC_samples_Brier_FMNIST'].mean(),
     df_MNIST_all['KFAC_samples_Brier_notMNIST'].mean(), df_MNIST_all['KFAC_samples_Brier_KMNIST'].mean()],
    [df_MNIST_all['KFAC_LB_MMC_in'].mean(), df_MNIST_all['KFAC_LB_MMC_FMNIST'].mean(), 
     df_MNIST_all['KFAC_LB_MMC_notMNIST'].mean(), df_MNIST_all['KFAC_LB_MMC_KMNIST'].mean()], 
    [0, df_MNIST_all['KFAC_LB_AUROC_FMNIST'].mean(), df_MNIST_all['KFAC_LB_AUROC_notMNIST'].mean(),
     df_MNIST_all['KFAC_LB_AUROC_KMNIST'].mean()],
    [df_MNIST_all['KFAC_LB_NLL_in'].mean(), df_MNIST_all['KFAC_LB_NLL_FMNIST'].mean(), 
     df_MNIST_all['KFAC_LB_NLL_notMNIST'].mean(), df_MNIST_all['KFAC_LB_NLL_KMNIST'].mean()], 
    [df_MNIST_all['KFAC_LB_ECE_in'].mean(), df_MNIST_all['KFAC_LB_ECE_FMNIST'].mean(), 
     df_MNIST_all['KFAC_LB_ECE_notMNIST'].mean(), df_MNIST_all['KFAC_LB_ECE_KMNIST'].mean()], 
    [df_MNIST_all['KFAC_LB_Brier_in'].mean(), df_MNIST_all['KFAC_LB_Brier_FMNIST'].mean(), 
     df_MNIST_all['KFAC_LB_Brier_notMNIST'].mean(), df_MNIST_all['KFAC_LB_Brier_KMNIST'].mean()], 
    [df_MNIST_all['KFAC_LB_norm_MMC_in'].mean(), df_MNIST_all['KFAC_LB_norm_MMC_FMNIST'].mean(), 
     df_MNIST_all['KFAC_LB_norm_MMC_notMNIST'].mean(), df_MNIST_all['KFAC_LB_norm_MMC_KMNIST'].mean()], 
    [0, df_MNIST_all['KFAC_LB_norm_AUROC_FMNIST'].mean(), df_MNIST_all['KFAC_LB_norm_AUROC_notMNIST'].mean(),
     df_MNIST_all['KFAC_LB_norm_AUROC_KMNIST'].mean()],
    [df_MNIST_all['KFAC_LB_norm_NLL_in'].mean(), df_MNIST_all['KFAC_LB_norm_NLL_FMNIST'].mean(), 
     df_MNIST_all['KFAC_LB_norm_NLL_notMNIST'].mean(), df_MNIST_all['KFAC_LB_norm_NLL_KMNIST'].mean()], 
    [df_MNIST_all['KFAC_LB_norm_ECE_in'].mean(), df_MNIST_all['KFAC_LB_norm_ECE_FMNIST'].mean(), 
     df_MNIST_all['KFAC_LB_norm_ECE_notMNIST'].mean(), df_MNIST_all['KFAC_LB_norm_ECE_KMNIST'].mean()], 
    [df_MNIST_all['KFAC_LB_norm_Brier_in'].mean(), df_MNIST_all['KFAC_LB_norm_Brier_FMNIST'].mean(), 
     df_MNIST_all['KFAC_LB_norm_Brier_notMNIST'].mean(), df_MNIST_all['KFAC_LB_norm_Brier_KMNIST'].mean()], 
    [df_MNIST_all['KFAC_PROBIT_MMC_in'].mean(), df_MNIST_all['KFAC_PROBIT_MMC_FMNIST'].mean(), 
     df_MNIST_all['KFAC_PROBIT_MMC_notMNIST'].mean(), df_MNIST_all['KFAC_PROBIT_MMC_KMNIST'].mean()], 
    [0, df_MNIST_all['KFAC_PROBIT_AUROC_FMNIST'].mean(), df_MNIST_all['KFAC_PROBIT_AUROC_notMNIST'].mean(),
     df_MNIST_all['KFAC_PROBIT_AUROC_KMNIST'].mean()], 
    [df_MNIST_all['KFAC_PROBIT_NLL_in'].mean(), df_MNIST_all['KFAC_PROBIT_NLL_FMNIST'].mean(), 
     df_MNIST_all['KFAC_PROBIT_NLL_notMNIST'].mean(), df_MNIST_all['KFAC_PROBIT_NLL_KMNIST'].mean()],  
    [df_MNIST_all['KFAC_PROBIT_ECE_in'].mean(), df_MNIST_all['KFAC_PROBIT_ECE_FMNIST'].mean(), 
     df_MNIST_all['KFAC_PROBIT_ECE_notMNIST'].mean(), df_MNIST_all['KFAC_PROBIT_ECE_KMNIST'].mean()],  
    [df_MNIST_all['KFAC_PROBIT_Brier_in'].mean(), df_MNIST_all['KFAC_PROBIT_Brier_FMNIST'].mean(), 
     df_MNIST_all['KFAC_PROBIT_Brier_notMNIST'].mean(), df_MNIST_all['KFAC_PROBIT_Brier_KMNIST'].mean()], 
]).T

df_MNIST_all_kron = pd.DataFrame(data_MNIST_all_kron, columns=[
    #"In", "Out",
    "KFAC_samples_MMC", "KFAC_samples_auroc", "KFAC_samples_NLL", "KFAC_samples_ECE", "KFAC_samples_Brier",
    "KFAC_LB_MMC", "KFAC_LB_auroc", "KFAC_LB_NLL", "KFAC_LB_ECE", "KFAC_LB_Brier",
    "KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc", "KFAC_LB_norm_NLL", "KFAC_LB_norm_ECE", "KFAC_LB_norm_Brier",
    "KFAC_PROBIT_MMC", "KFAC_PROBIT_auroc", "KFAC_PROBIT_NLL", "KFAC_PROBIT_ECE", "KFAC_PROBIT_Brier",
    #"Diag_SODPP_MMC", "Diag_SODPP_auroc"
])
df_MNIST_all_kron
# Out:
#    KFAC_samples_MMC  KFAC_samples_auroc  KFAC_samples_NLL  KFAC_samples_ECE  \
# 0             0.872               0.000             0.160             0.117
# 1             0.359               0.985             2.964             0.288
# 2             0.432               0.958             3.340             0.282
# 3             0.374               0.981             3.626             0.279
#
#    KFAC_samples_Brier  KFAC_LB_MMC  KFAC_LB_auroc  KFAC_LB_NLL  KFAC_LB_ECE  \
# 0               0.005        0.985          0.000        0.034        0.011
# 1               0.102        0.603          0.980        3.828        0.528
# 2               0.104        0.754          0.915        6.029        0.629
# 3               0.105        0.710          0.958        6.020        0.615
#
#    KFAC_LB_Brier  KFAC_LB_norm_MMC  KFAC_LB_norm_auroc  KFAC_LB_norm_NLL  \
# 0          0.002             0.854               0.000             0.194
# ...

# %%
MNIST_all_df_diag_kfac = pd.concat([df_MNIST_all_diag[columns_d], df_MNIST_all_kron[columns_k]], axis=1)

# %%
# concat rows
all_last_vs_full_df = pd.concat([MNIST_df_diag_kfac, MNIST_all_df_diag_kfac], axis=0).reset_index()

# add named columns
name_columns = pd.DataFrame({
    "Train":["MNIST", "MNIST", "MNIST", "MNIST", "MNIST", "MNIST", "MNIST", "MNIST"],
    "Test":["MNIST", "FMNIST", "notMNIST", "KMNIST", "MNIST", "FMNIST", "notMNIST", "KMNIST"]
})

# combine all
all_df = pd.concat([name_columns, all_df], axis=1).drop(['index'], axis=1)
# drop in dist rows
all_df = all_df.drop([0, 4, 7, 10])
all_df
