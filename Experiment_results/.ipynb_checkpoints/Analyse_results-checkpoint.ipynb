# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # MNIST

# %%
df = pd.read_csv("MNIST_results.csv")
print(df.columns)
df
# Out:
# Index(['Unnamed: 0', 'MAP_MMC_in', 'MAP_MMC_FMNIST', 'MAP_MMC_notMNIST',
#        'MAP_MMC_KMNIST', 'MAP_AUROC_FMNIST', 'MAP_AUROC_notMNIST',
#        'MAP_AUROC_KMNIST', 'Diag_samples_MMC_in', 'Diag_samples_MMC_FMNIST',
#        'Diag_samples_MMC_notMNIST', 'Diag_samples_MMC_KMNIST',
#        'Diag_samples_AUROC_FMNIST', 'Diag_samples_AUROC_notMNIST',
#        'Diag_samples_AUROC_KMNIST', 'KFAC_samples_MMC_in',
#        'KFAC_samples_MMC_FMNIST', 'KFAC_samples_MMC_notMNIST',
#        'KFAC_samples_MMC_KMNIST', 'KFAC_samples_AUROC_FMNIST',
#        'KFAC_samples_AUROC_notMNIST', 'KFAC_samples_AUROC_KMNIST',
#        'Diag_LB_MMC_in', 'Diag_LB_MMC_FMNIST', 'Diag_LB_MMC_notMNIST',
#        'Diag_LB_MMC_KMNIST', 'Diag_LB_AUROC_FMNIST', 'Diag_LB_AUROC_notMNIST',
#        'Diag_LB_AUROC_KMNIST', 'KFAC_LB_MMC_in', 'KFAC_LB_MMC_FMNIST',
#        'KFAC_LB_MMC_notMNIST', 'KFAC_LB_MMC_KMNIST', 'KFAC_LB_AUROC_FMNIST',
#        'KFAC_LB_AUROC_notMNIST', 'KFAC_LB_AUROC_KMNIST', 'Diag_LB_norm_MMC_in',
#        'Diag_LB_norm_MMC_FMNIST', 'Diag_LB_norm_MMC_notMNIST',
#        'Diag_LB_norm_MMC_KMNIST', 'Diag_LB_norm_AUROC_FMNIST',
#        'Diag_LB_norm_AUROC_notMNIST', 'Diag_LB_norm_AUROC_KMNIST',
#        'KFAC_LB_norm_MMC_in', 'KFAC_LB_norm_MMC_FMNIST',
#        'KFAC_LB_norm_MMC_notMNIST', 'KFAC_LB_norm_MMC_KMNIST',
#        'KFAC_LB_norm_AUROC_FMNIST', 'KFAC_LB_norm_AUROC_notMNIST',
#        'KFAC_LB_norm_AUROC_KMNIST', 'Diag_EMK_MMC_in', 'Diag_EMK_MMC_FMNIST',
#        'Diag_EMK_MMC_notMNIST', 'Diag_EMK_MMC_KMNIST', 'Diag_EMK_AUROC_FMNIST',
#        'Diag_EMK_AUROC_notMNIST', 'Diag_EMK_AUROC_KMNIST', 'KFAC_EMK_MMC_in',
#        'KFAC_EMK_MMC_FMNIST', 'KFAC_EMK_MMC_notMNIST', 'KFAC_EMK_MMC_KMNIST',
#        'KFAC_EMK_AUROC_FMNIST', 'KFAC_EMK_AUROC_notMNIST',
#        'KFAC_EMK_AUROC_KMNIST', 'Diag_SODPP_MMC_in', 'Diag_SODPP_MMC_FMNIST',
#        'Diag_SODPP_MMC_notMNIST', 'Diag_SODPP_MMC_KMNIST',
#        'Diag_SODPP_AUROC_FMNIST', 'Diag_SODPP_AUROC_notMNIST',
#        'Diag_SODPP_AUROC_KMNIST', 'KFAC_SODPP_MMC_in', 'KFAC_SODPP_MMC_FMNIST',
#        'KFAC_SODPP_MMC_notMNIST', 'KFAC_SODPP_MMC_KMNIST',
#        'KFAC_SODPP_AUROC_FMNIST', 'KFAC_SODPP_AUROC_notMNIST',
#        'KFAC_SODPP_AUROC_KMNIST'],
#       dtype='object')
#    Unnamed: 0  MAP_MMC_in  MAP_MMC_FMNIST  MAP_MMC_notMNIST  MAP_MMC_KMNIST  \
# 0           0    0.985782        0.663287          0.774449        0.722817
# 1           1    0.985782        0.663287          0.774449        0.722817
# 2           2    0.985782        0.663287          0.774449        0.722817
# 3           3    0.985782        0.663287          0.774449        0.722817
# 4           4    0.985782        0.663287          0.774449        0.722817
#
#    MAP_AUROC_FMNIST  MAP_AUROC_notMNIST  MAP_AUROC_KMNIST  \
# 0          0.976527            0.914164          0.958988
# 1          0.976527            0.914164          0.958988
# 2          0.976527            0.914164          0.958988
# 3          0.976527            0.914164          0.958988
# 4          0.976527            0.914164          0.958988
#
#    Diag_samples_MMC_in  Diag_samples_MMC_FMNIST  ...  Diag_SODPP_AUROC_FMNIST  \
# 0             0.955020                 0.536265  ...                 0.974015
# 1             0.954795                 0.536329  ...                 0.974015
# 2             0.954862                 0.536443  ...                 0.974015
# 3             0.954914                 0.535972  ...                 0.974015
# 4             0.954772                 0.536541  ...                 0.974015
#
#    Diag_SODPP_AUROC_notMNIST  Diag_SODPP_AUROC_KMNIST  KFAC_SODPP_MMC_in  \
# 0                   0.806167                 0.898824           0.967615
# 1                   0.806167                 0.898824           0.968247
# 2                   0.806167                 0.898824           0.967602
# 3                   0.806167                 0.898824           0.968298
# 4                   0.806167                 0.898824           0.967604
#
#    KFAC_SODPP_MMC_FMNIST  KFAC_SODPP_MMC_notMNIST  KFAC_SODPP_MMC_KMNIST  \
# 0               0.491674                 0.866871               0.707410
# 1               0.491794                 0.867172               0.707591
# 2               0.491707                 0.866990               0.707604
# 3               0.491749                 0.867009               0.707521
# 4               0.491701                 0.866881               0.707476
#
#    KFAC_SODPP_AUROC_FMNIST  KFAC_SODPP_AUROC_notMNIST  KFAC_SODPP_AUROC_KMNIST
# 0                 0.972607                   0.694803                 0.833467
# 1                 0.973545                   0.702355                 0.837604
# 2                 0.972507                   0.694744                 0.833449
# 3                 0.973712                   0.703292                 0.838072
# 4                 0.972613                   0.694668                 0.833711
#
# [5 rows x 78 columns]

# %% [markdown]
# # compare diag

# %%
#pd.set_option("display.precision", 4)
#pd.set_option('precision', 3)
pd.options.display.float_format = '{:,.3f}'.format

# %%
data = np.array([
    #["MNIST", "MNIST", "MNIST", "MNIST"],
    #["MNIST", "FMNIST", "notMNIST", "KMNIST"],
    [df['Diag_samples_MMC_in'].mean(), df['Diag_samples_MMC_FMNIST'].mean(),
     df['Diag_samples_MMC_notMNIST'].mean(), df['Diag_samples_MMC_KMNIST'].mean()],
    [0, df['Diag_samples_AUROC_FMNIST'].mean(), df['Diag_samples_AUROC_notMNIST'].mean(),
     df['Diag_samples_AUROC_KMNIST'].mean()],
    [df['Diag_LB_MMC_in'].mean(), df['Diag_LB_MMC_FMNIST'].mean(), 
     df['Diag_LB_MMC_notMNIST'].mean(), df['Diag_LB_MMC_KMNIST'].mean()], 
    [0, df['Diag_LB_AUROC_FMNIST'].mean(), df['Diag_LB_AUROC_notMNIST'].mean(),
     df['Diag_LB_AUROC_KMNIST'].mean()],
    [df['Diag_LB_norm_MMC_in'].mean(), df['Diag_LB_norm_MMC_FMNIST'].mean(), 
     df['Diag_LB_norm_MMC_notMNIST'].mean(), df['Diag_LB_norm_MMC_KMNIST'].mean()], 
    [0, df['Diag_LB_norm_AUROC_FMNIST'].mean(), df['Diag_LB_norm_AUROC_notMNIST'].mean(),
     df['Diag_LB_norm_AUROC_KMNIST'].mean()],
#     [df['Diag_EMK_MMC_in'].mean(), df['Diag_EMK_MMC_FMNIST'].mean(), 
#      df['Diag_EMK_MMC_notMNIST'].mean(), df['Diag_EMK_MMC_KMNIST'].mean()], 
#     [0, df['Diag_EMK_AUROC_FMNIST'].mean(), df['Diag_EMK_AUROC_notMNIST'].mean(),
#      df['Diag_EMK_AUROC_KMNIST'].mean()],
#     [df['Diag_SODPP_MMC_in'].mean(), df['Diag_SODPP_MMC_FMNIST'].mean(), 
#      df['Diag_SODPP_MMC_notMNIST'].mean(), df['Diag_SODPP_MMC_KMNIST'].mean()], 
#     [0, df['Diag_SODPP_AUROC_FMNIST'].mean(), df['Diag_SODPP_AUROC_notMNIST'].mean(),
#      df['Diag_SODPP_AUROC_KMNIST'].mean()],
]).T

df_diag = pd.DataFrame(data, columns=[
    #"In", "Out",
    "Diag_samples_MMC", "Diag_samples_auroc",
    "Diag_LB_MMC", "Diag_LB_auroc",
    "Diag_LB_norm_MMC", "Diag_LB_norm_auroc",
    #"Diag_EMK_MMC", "Diag_EMK_auroc",
    #"Diag_SODPP_MMC", "Diag_SODPP_auroc"
])
df_diag
# Out:
#    Diag_samples_MMC  Diag_samples_auroc  Diag_LB_MMC  Diag_LB_auroc  \
# 0             0.955               0.000        0.981          0.000
# 1             0.536               0.975        0.565          0.981
# 2             0.546               0.965        0.735          0.930
# 3             0.521               0.974        0.711          0.949
#
#    Diag_LB_norm_MMC  Diag_LB_norm_auroc
# 0             0.944               0.000
# 1             0.589               0.951
# 2             0.492               0.955
# 3             0.484               0.970

# %%
# pd.set_option('precision', 3)
# print(df_diag.to_latex(index=False))

# %% [markdown]
# # KFAC

# %%
data_kron = np.array([
    #["MNIST", "MNIST", "MNIST", "MNIST"],
    #["MNIST", "FMNIST", "notMNIST", "KMNIST"],
    [df['KFAC_samples_MMC_in'].mean(), df['KFAC_samples_MMC_FMNIST'].mean(),
     df['KFAC_samples_MMC_notMNIST'].mean(), df['KFAC_samples_MMC_KMNIST'].mean()],
    [0, df['KFAC_samples_AUROC_FMNIST'].mean(), df['KFAC_samples_AUROC_notMNIST'].mean(),
     df['KFAC_samples_AUROC_KMNIST'].mean()],
    [df['KFAC_LB_MMC_in'].mean(), df['KFAC_LB_MMC_FMNIST'].mean(), 
     df['KFAC_LB_MMC_notMNIST'].mean(), df['KFAC_LB_MMC_KMNIST'].mean()], 
    [0, df['KFAC_LB_AUROC_FMNIST'].mean(), df['KFAC_LB_AUROC_notMNIST'].mean(),
     df['KFAC_LB_AUROC_KMNIST'].mean()],
    [df['KFAC_LB_norm_MMC_in'].mean(), df['KFAC_LB_norm_MMC_FMNIST'].mean(), 
     df['KFAC_LB_norm_MMC_notMNIST'].mean(), df['KFAC_LB_norm_MMC_KMNIST'].mean()], 
    [0, df['KFAC_LB_norm_AUROC_FMNIST'].mean(), df['KFAC_LB_norm_AUROC_notMNIST'].mean(),
     df['KFAC_LB_norm_AUROC_KMNIST'].mean()],
#     [df['KFAC_EMK_MMC_in'].mean(), df['KFAC_EMK_MMC_FMNIST'].mean(), 
#      df['KFAC_EMK_MMC_notMNIST'].mean(), df['KFAC_EMK_MMC_KMNIST'].mean()], 
#     [0, df['KFAC_EMK_AUROC_FMNIST'].mean(), df['KFAC_EMK_AUROC_notMNIST'].mean(),
#      df['KFAC_EMK_AUROC_KMNIST'].mean()],
#     [df['KFAC_SODPP_MMC_in'].mean(), df['KFAC_SODPP_MMC_FMNIST'].mean(), 
#      df['KFAC_SODPP_MMC_notMNIST'].mean(), df['KFAC_SODPP_MMC_KMNIST'].mean()], 
#     [0, df['KFAC_SODPP_AUROC_FMNIST'].mean(), df['KFAC_SODPP_AUROC_notMNIST'].mean(),
#      df['KFAC_SODPP_AUROC_KMNIST'].mean()],
]).T

df_kron = pd.DataFrame(data_kron, columns=[
    #"In", "Out",
    "KFAC_samples_MMC", "KFAC_samples_auroc",
    "KFAC_LB_MMC", "KFAC_LB_auroc",
    "KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc",
#     "KFAC_EMK_MMC", "KFAC_EMK_auroc",
#     "KFAC_SODPP_MMC", "KFAC_SODPP_auroc"
])
df_kron
# Out:
#    KFAC_samples_MMC  KFAC_samples_auroc  KFAC_LB_MMC  KFAC_LB_auroc  \
# 0             0.961               0.000        0.985          0.000
# 1             0.460               0.987        0.630          0.977
# 2             0.504               0.974        0.757          0.912
# 3             0.471               0.985        0.712          0.956
#
#    KFAC_LB_norm_MMC  KFAC_LB_norm_auroc
# 0             0.975               0.000
# 1             0.444               0.990
# 2             0.409               0.986
# 3             0.414               0.991

# %% [markdown]
# # CIFAR10

# %%
df_CIFAR10 = pd.read_csv("CIFAR10_results.csv")
print(df_CIFAR10.columns)
df_CIFAR10
# Out:
# Index(['Unnamed: 0', 'MAP_MMC_in', 'MAP_MMC_CIFAR100', 'MAP_MMC_SVHN',
#        'MAP_AUROC_CIFAR100', 'MAP_AUROC_SVHN', 'Diag_samples_MMC_in',
#        'Diag_samples_MMC_CIFAR100', 'Diag_samples_MMC_SVHN',
#        'Diag_samples_AUROC_CIFAR100', 'Diag_samples_AUROC_SVHN',
#        'KFAC_samples_MMC_in', 'KFAC_samples_MMC_CIFAR100',
#        'KFAC_samples_MMC_SVHN', 'KFAC_samples_AUROC_CIFAR100',
#        'KFAC_samples_AUROC_SVHN', 'Diag_LB_MMC_in', 'Diag_LB_MMC_CIFAR100',
#        'Diag_LB_MMC_SVHN', 'Diag_LB_AUROC_CIFAR100', 'Diag_LB_AUROC_SVHN',
#        'KFAC_LB_MMC_in', 'KFAC_LB_MMC_CIFAR100', 'KFAC_LB_MMC_SVHN',
#        'KFAC_LB_AUROC_CIFAR100', 'KFAC_LB_AUROC_SVHN', 'Diag_LB_norm_MMC_in',
#        'Diag_LB_norm_MMC_CIFAR100', 'Diag_LB_norm_MMC_SVHN',
#        'Diag_LB_norm_AUROC_CIFAR100', 'Diag_LB_norm_AUROC_SVHN',
#        'KFAC_LB_norm_MMC_in', 'KFAC_LB_norm_MMC_CIFAR100',
#        'KFAC_LB_norm_MMC_SVHN', 'KFAC_LB_norm_AUROC_CIFAR100',
#        'KFAC_LB_norm_AUROC_SVHN', 'Diag_EMK_MMC_in', 'Diag_EMK_MMC_CIFAR100',
#        'Diag_EMK_MMC_SVHN', 'Diag_EMK_AUROC_CIFAR100', 'Diag_EMK_AUROC_SVHN',
#        'KFAC_EMK_MMC_in', 'KFAC_EMK_MMC_CIFAR100', 'KFAC_EMK_MMC_SVHN',
#        'KFAC_EMK_AUROC_CIFAR100', 'KFAC_EMK_AUROC_SVHN', 'Diag_SODPP_MMC_in',
#        'Diag_SODPP_MMC_CIFAR100', 'Diag_SODPP_MMC_SVHN',
#        'Diag_SODPP_AUROC_CIFAR100', 'Diag_SODPP_AUROC_SVHN',
#        'KFAC_SODPP_MMC_in', 'KFAC_SODPP_MMC_CIFAR100', 'KFAC_SODPP_MMC_SVHN',
#        'KFAC_SODPP_AUROC_CIFAR100', 'KFAC_SODPP_AUROC_SVHN'],
#       dtype='object')
#    Unnamed: 0  MAP_MMC_in  MAP_MMC_CIFAR100  MAP_MMC_SVHN  MAP_AUROC_CIFAR100  \
# 0           0       0.977             0.818         0.777               0.874
# 1           1       0.977             0.818         0.777               0.874
# 2           2       0.977             0.818         0.777               0.874
# 3           3       0.977             0.818         0.777               0.874
# 4           4       0.977             0.818         0.777               0.874
#
#    MAP_AUROC_SVHN  Diag_samples_MMC_in  Diag_samples_MMC_CIFAR100  \
# 0           0.936                0.743                      0.482
# 1           0.936                0.747                      0.485
# 2           0.936                0.749                      0.486
# 3           0.936                0.746                      0.484
# 4           0.936                0.747                      0.485
#
#    Diag_samples_MMC_SVHN  Diag_samples_AUROC_CIFAR100  ...  Diag_SODPP_MMC_in  \
# 0                  0.417                        0.886  ...              0.950
# 1                  0.419                        0.887  ...              0.950
# 2                  0.419                        0.887  ...              0.950
# 3                  0.418                        0.887  ...              0.950
# 4                  0.419                        0.886  ...              0.950
#
#    Diag_SODPP_MMC_CIFAR100  Diag_SODPP_MMC_SVHN  Diag_SODPP_AUROC_CIFAR100  \
# 0                    0.746                0.824                      0.800
# 1                    0.741                0.811                      0.805
# 2                    0.740                0.806                      0.808
# 3                    0.743                0.820                      0.803
# 4                    0.742                0.813                      0.804
#
#    Diag_SODPP_AUROC_SVHN  KFAC_SODPP_MMC_in  KFAC_SODPP_MMC_CIFAR100  \
# 0                  0.696              0.953                    0.681
# 1                  0.709              0.953                    0.681
# 2                  0.713              0.953                    0.681
# 3                  0.700              0.953                    0.682
# 4                  0.707              0.953                    0.681
#
#    KFAC_SODPP_MMC_SVHN  KFAC_SODPP_AUROC_CIFAR100  KFAC_SODPP_AUROC_SVHN
# 0                0.678                      0.877                  0.866
# 1                0.687                      0.877                  0.854
# 2                0.681                      0.877                  0.862
# 3                0.682                      0.877                  0.861
# 4                0.687                      0.877                  0.853
#
# [5 rows x 56 columns]

# %%
data_CIFAR10 = np.array([
    [df_CIFAR10['Diag_samples_MMC_in'].mean(), df_CIFAR10['Diag_samples_MMC_CIFAR100'].mean(),
     df_CIFAR10['Diag_samples_MMC_SVHN'].mean()],
    [0, df_CIFAR10['Diag_samples_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_samples_AUROC_SVHN'].mean()],
    [df_CIFAR10['Diag_LB_MMC_in'].mean(), df_CIFAR10['Diag_LB_MMC_CIFAR100'].mean(),
     df_CIFAR10['Diag_LB_MMC_SVHN'].mean()],
    [0, df_CIFAR10['Diag_LB_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_LB_AUROC_SVHN'].mean()],
    [df_CIFAR10['Diag_LB_norm_MMC_in'].mean(), df_CIFAR10['Diag_LB_norm_MMC_CIFAR100'].mean(),
     df_CIFAR10['Diag_LB_norm_MMC_SVHN'].mean()],
    [0, df_CIFAR10['Diag_LB_norm_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_LB_norm_AUROC_SVHN'].mean()],
#     [df_CIFAR10['Diag_EMK_MMC_in'].mean(), df_CIFAR10['Diag_EMK_MMC_CIFAR100'].mean(),
#      df_CIFAR10['Diag_EMK_MMC_SVHN'].mean()],
#     [0, df_CIFAR10['Diag_EMK_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_EMK_AUROC_SVHN'].mean()],
#     [df_CIFAR10['Diag_SODPP_MMC_in'].mean(), df_CIFAR10['Diag_SODPP_MMC_CIFAR100'].mean(),
#      df_CIFAR10['Diag_SODPP_MMC_SVHN'].mean()],
#     [0, df_CIFAR10['Diag_SODPP_AUROC_CIFAR100'].mean(), df_CIFAR10['Diag_SODPP_AUROC_SVHN'].mean()]
]).T

df_diag_CIFAR10 = pd.DataFrame(data_CIFAR10, columns=[
    "Diag_samples_MMC", "Diag_samples_auroc",
    "Diag_LB_MMC", "Diag_LB_auroc",
    "Diag_LB_norm_MMC", "Diag_LB_norm_auroc",
#     "Diag_EMK_MMC", "Diag_EMK_auroc",
#     "Diag_SODPP_MMC", "Diag_SODPP_auroc"
])
df_diag_CIFAR10
# Out:
#    Diag_samples_MMC  Diag_samples_auroc  Diag_LB_MMC  Diag_LB_auroc  \
# 0             0.746               0.000        0.974          0.000
# 1             0.484               0.887        0.796          0.859
# 2             0.418               0.948        0.766          0.928
#
#    Diag_LB_norm_MMC  Diag_LB_norm_auroc
# 0             0.517               0.000
# 1             0.319               0.883
# 2             0.273               0.948

# %%
data_CIFAR10_K = np.array([
    [df_CIFAR10['KFAC_samples_MMC_in'].mean(), df_CIFAR10['KFAC_samples_MMC_CIFAR100'].mean(),
     df_CIFAR10['KFAC_samples_MMC_SVHN'].mean()],
    [0, df_CIFAR10['KFAC_samples_AUROC_CIFAR100'].mean(), df_CIFAR10['KFAC_samples_AUROC_SVHN'].mean()],
    [df_CIFAR10['KFAC_LB_MMC_in'].mean(), df_CIFAR10['KFAC_LB_MMC_CIFAR100'].mean(),
     df_CIFAR10['KFAC_LB_MMC_SVHN'].mean()],
    [0, df_CIFAR10['KFAC_LB_AUROC_CIFAR100'].mean(), df_CIFAR10['KFAC_LB_AUROC_SVHN'].mean()],
    [df_CIFAR10['KFAC_LB_norm_MMC_in'].mean(), df_CIFAR10['KFAC_LB_norm_MMC_CIFAR100'].mean(),
     df_CIFAR10['KFAC_LB_norm_MMC_SVHN'].mean()],
    [0, df_CIFAR10['KFAC_LB_norm_AUROC_CIFAR100'].mean(), df_CIFAR10['KFAC_LB_norm_AUROC_SVHN'].mean()],
#     [df_CIFAR10['KFAC_EMK_MMC_in'].mean(), df_CIFAR10['KFAC_EMK_MMC_CIFAR100'].mean(),
#      df_CIFAR10['KFAC_EMK_MMC_SVHN'].mean()],
#     [0, df_CIFAR10['KFAC_EMK_AUROC_CIFAR100'].mean(), df_CIFAR10['KFAC_EMK_AUROC_SVHN'].mean()],
#     [df_CIFAR10['KFAC_SODPP_MMC_in'].mean(), df_CIFAR10['KFAC_SODPP_MMC_CIFAR100'].mean(),
#      df_CIFAR10['KFAC_SODPP_MMC_SVHN'].mean()],
#     [0, df_CIFAR10['KFAC_SODPP_AUROC_CIFAR100'].mean(), df_CIFAR10['KFAC_SODPP_AUROC_SVHN'].mean()]
]).T

df_KFAC_CIFAR10 = pd.DataFrame(data_CIFAR10_K, columns=[
    "KFAC_samples_MMC", "KFAC_samples_auroc",
    "KFAC_LB_MMC", "KFAC_LB_auroc",
    "KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc",
#     "KFAC_EMK_MMC", "KFAC_EMK_auroc",
#     "KFAC_SODPP_MMC", "KFAC_SODPP_auroc"
])
df_KFAC_CIFAR10
# Out:
#    KFAC_samples_MMC  KFAC_samples_auroc  KFAC_LB_MMC  KFAC_LB_auroc  \
# 0             0.944               0.000        0.969          0.000
# 1             0.683               0.878        0.775          0.855
# 2             0.558               0.955        0.749          0.924
#
#    KFAC_LB_norm_MMC  KFAC_LB_norm_auroc
# 0             0.941               0.000
# 1             0.662               0.866
# 2             0.441               0.965

# %% [markdown]
# # SVHN

# %%
df_SVHN = pd.read_csv("SVHN_results.csv")
print(df_SVHN.columns)
df_SVHN
# Out:
# Index(['Unnamed: 0', 'MAP_MMC_in', 'MAP_MMC_CIFAR100', 'MAP_MMC_CIFAR10',
#        'MAP_AUROC_CIFAR100', 'MAP_AUROC_CIFAR10', 'Diag_samples_MMC_in',
#        'Diag_samples_MMC_CIFAR100', 'Diag_samples_MMC_CIFAR10',
#        'Diag_samples_AUROC_CIFAR100', 'Diag_samples_AUROC_CIFAR10',
#        'KFAC_samples_MMC_in', 'KFAC_samples_MMC_CIFAR100',
#        'KFAC_samples_MMC_CIFAR10', 'KFAC_samples_AUROC_CIFAR100',
#        'KFAC_samples_AUROC_CIFAR10', 'Diag_LB_MMC_in', 'Diag_LB_MMC_CIFAR100',
#        'Diag_LB_MMC_CIFAR10', 'Diag_LB_AUROC_CIFAR100',
#        'Diag_LB_AUROC_CIFAR10', 'KFAC_LB_MMC_in', 'KFAC_LB_MMC_CIFAR100',
#        'KFAC_LB_MMC_CIFAR10', 'KFAC_LB_AUROC_CIFAR100',
#        'KFAC_LB_AUROC_CIFAR10', 'Diag_LB_norm_MMC_in',
#        'Diag_LB_norm_MMC_CIFAR100', 'Diag_LB_norm_MMC_CIFAR10',
#        'Diag_LB_norm_AUROC_CIFAR100', 'Diag_LB_norm_AUROC_CIFAR10',
#        'KFAC_LB_norm_MMC_in', 'KFAC_LB_norm_MMC_CIFAR100',
#        'KFAC_LB_norm_MMC_CIFAR10', 'KFAC_LB_norm_AUROC_CIFAR100',
#        'KFAC_LB_norm_AUROC_CIFAR10', 'Diag_EMK_MMC_in',
#        'Diag_EMK_MMC_CIFAR100', 'Diag_EMK_MMC_CIFAR10',
#        'Diag_EMK_AUROC_CIFAR100', 'Diag_EMK_AUROC_CIFAR10', 'KFAC_EMK_MMC_in',
#        'KFAC_EMK_MMC_CIFAR100', 'KFAC_EMK_MMC_CIFAR10',
#        'KFAC_EMK_AUROC_CIFAR100', 'KFAC_EMK_AUROC_CIFAR10',
#        'Diag_SODPP_MMC_in', 'Diag_SODPP_MMC_CIFAR100',
#        'Diag_SODPP_MMC_CIFAR10', 'Diag_SODPP_AUROC_CIFAR100',
#        'Diag_SODPP_AUROC_CIFAR10', 'KFAC_SODPP_MMC_in',
#        'KFAC_SODPP_MMC_CIFAR100', 'KFAC_SODPP_MMC_CIFAR10',
#        'KFAC_SODPP_AUROC_CIFAR100', 'KFAC_SODPP_AUROC_CIFAR10'],
#       dtype='object')
#    Unnamed: 0  MAP_MMC_in  MAP_MMC_CIFAR100  MAP_MMC_CIFAR10  \
# 0           0       0.996             0.788            0.793
# 1           1       0.996             0.788            0.793
# 2           2       0.996             0.788            0.793
# 3           3       0.996             0.788            0.793
# 4           4       0.996             0.788            0.793
#
#    MAP_AUROC_CIFAR100  MAP_AUROC_CIFAR10  Diag_samples_MMC_in  \
# 0               0.961              0.959                0.984
# 1               0.961              0.959                0.984
# 2               0.961              0.959                0.984
# 3               0.961              0.959                0.984
# 4               0.961              0.959                0.984
#
#    Diag_samples_MMC_CIFAR100  Diag_samples_MMC_CIFAR10  \
# 0                      0.687                     0.689
# 1                      0.687                     0.689
# 2                      0.687                     0.690
# 3                      0.687                     0.690
# 4                      0.687                     0.689
#
#    Diag_samples_AUROC_CIFAR100  ...  Diag_SODPP_MMC_in  \
# 0                        0.957  ...              0.990
# 1                        0.957  ...              0.990
# 2                        0.957  ...              0.990
# 3                        0.957  ...              0.990
# 4                        0.958  ...              0.990
#
#    Diag_SODPP_MMC_CIFAR100  Diag_SODPP_MMC_CIFAR10  Diag_SODPP_AUROC_CIFAR100  \
# 0                    0.662                   0.665                      0.961
# 1                    0.662                   0.665                      0.961
# 2                    0.662                   0.665                      0.961
# 3                    0.662                   0.665                      0.961
# 4                    0.662                   0.665                      0.961
#
#    Diag_SODPP_AUROC_CIFAR10  KFAC_SODPP_MMC_in  KFAC_SODPP_MMC_CIFAR100  \
# 0                     0.960              0.989                    0.632
# 1                     0.960              0.989                    0.632
# 2                     0.960              0.989                    0.632
# 3                     0.960              0.989                    0.632
# 4                     0.960              0.989                    0.632
#
#    KFAC_SODPP_MMC_CIFAR10  KFAC_SODPP_AUROC_CIFAR100  KFAC_SODPP_AUROC_CIFAR10
# 0                   0.639                      0.961                     0.961
# 1                   0.639                      0.961                     0.961
# 2                   0.639                      0.961                     0.961
# 3                   0.639                      0.961                     0.961
# 4                   0.639                      0.961                     0.961
#
# [5 rows x 56 columns]

# %%
data_SVHN = np.array([
    [df_SVHN['Diag_samples_MMC_in'].mean(), df_SVHN['Diag_samples_MMC_CIFAR100'].mean(),
     df_SVHN['Diag_samples_MMC_CIFAR10'].mean()],
    [0, df_SVHN['Diag_samples_AUROC_CIFAR100'].mean(), df_SVHN['Diag_samples_AUROC_CIFAR10'].mean()],
    [df_SVHN['Diag_LB_MMC_in'].mean(), df_SVHN['Diag_LB_MMC_CIFAR100'].mean(),
     df_SVHN['Diag_LB_MMC_CIFAR10'].mean()],
    [0, df_SVHN['Diag_LB_AUROC_CIFAR100'].mean(), df_SVHN['Diag_LB_AUROC_CIFAR10'].mean()],
    [df_SVHN['Diag_LB_norm_MMC_in'].mean(), df_SVHN['Diag_LB_norm_MMC_CIFAR100'].mean(),
     df_SVHN['Diag_LB_norm_MMC_CIFAR10'].mean()],
    [0, df_SVHN['Diag_LB_norm_AUROC_CIFAR100'].mean(), df_SVHN['Diag_LB_norm_AUROC_CIFAR10'].mean()],
#     [df_SVHN['Diag_EMK_MMC_in'].mean(), df_SVHN['Diag_EMK_MMC_CIFAR100'].mean(),
#      df_SVHN['Diag_EMK_MMC_CIFAR10'].mean()],
#     [0, df_SVHN['Diag_EMK_AUROC_CIFAR100'].mean(), df_SVHN['Diag_EMK_AUROC_CIFAR10'].mean()],
#     [df_SVHN['Diag_SODPP_MMC_in'].mean(), df_SVHN['Diag_SODPP_MMC_CIFAR100'].mean(),
#      df_SVHN['Diag_SODPP_MMC_CIFAR10'].mean()],
#     [0, df_SVHN['Diag_SODPP_AUROC_CIFAR100'].mean(), df_SVHN['Diag_SODPP_AUROC_CIFAR10'].mean()]
]).T

df_diag_SVHN = pd.DataFrame(data_SVHN, columns=[
    "Diag_samples_MMC", "Diag_samples_auroc",
    "Diag_LB_MMC", "Diag_LB_auroc",
    "Diag_LB_norm_MMC", "Diag_LB_norm_auroc",
#     "Diag_EMK_MMC", "Diag_EMK_auroc",
#     "Diag_SODPP_MMC", "Diag_SODPP_auroc"
])
df_diag_SVHN
# Out:
#    Diag_samples_MMC  Diag_samples_auroc  Diag_LB_MMC  Diag_LB_auroc  \
# 0             0.984               0.000        0.995          0.000
# 1             0.687               0.957        0.739          0.962
# 2             0.689               0.958        0.749          0.960
#
#    Diag_LB_norm_MMC  Diag_LB_norm_auroc
# 0             0.988               0.000
# 1             0.750               0.944
# 2             0.751               0.947

# %%
data_SVHN_K = np.array([
    [df_SVHN['KFAC_samples_MMC_in'].mean(), df_SVHN['KFAC_samples_MMC_CIFAR100'].mean(),
     df_SVHN['KFAC_samples_MMC_CIFAR10'].mean()],
    [0, df_SVHN['KFAC_samples_AUROC_CIFAR100'].mean(), df_SVHN['KFAC_samples_AUROC_CIFAR10'].mean()],
    [df_SVHN['KFAC_LB_MMC_in'].mean(), df_SVHN['KFAC_LB_MMC_CIFAR100'].mean(),
     df_SVHN['KFAC_LB_MMC_CIFAR10'].mean()],
    [0, df_SVHN['KFAC_LB_AUROC_CIFAR100'].mean(), df_SVHN['KFAC_LB_AUROC_CIFAR10'].mean()],
    [df_SVHN['KFAC_LB_norm_MMC_in'].mean(), df_SVHN['KFAC_LB_norm_MMC_CIFAR100'].mean(),
     df_SVHN['KFAC_LB_norm_MMC_CIFAR10'].mean()],
    [0, df_SVHN['KFAC_LB_norm_AUROC_CIFAR100'].mean(), df_SVHN['KFAC_LB_norm_AUROC_CIFAR10'].mean()],
#     [df_SVHN['KFAC_EMK_MMC_in'].mean(), df_SVHN['KFAC_EMK_MMC_CIFAR100'].mean(),
#      df_SVHN['KFAC_EMK_MMC_CIFAR10'].mean()],
#     [0, df_SVHN['KFAC_EMK_AUROC_CIFAR100'].mean(), df_SVHN['KFAC_EMK_AUROC_CIFAR10'].mean()],
#     [df_SVHN['KFAC_SODPP_MMC_in'].mean(), df_SVHN['KFAC_SODPP_MMC_CIFAR100'].mean(),
#      df_SVHN['KFAC_SODPP_MMC_CIFAR10'].mean()],
#     [0, df_SVHN['KFAC_SODPP_AUROC_CIFAR100'].mean(), df_SVHN['KFAC_SODPP_AUROC_CIFAR10'].mean()]
]).T

df_KFAC_SVHN = pd.DataFrame(data_SVHN_K, columns=[
    "KFAC_samples_MMC", "KFAC_samples_auroc",
    "KFAC_LB_MMC", "KFAC_LB_auroc",
    "KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc",
#     "KFAC_EMK_MMC", "KFAC_EMK_auroc",
#     "KFAC_SODPP_MMC", "KFAC_SODPP_auroc"
])
df_KFAC_SVHN
# Out:
#    KFAC_samples_MMC  KFAC_samples_auroc  KFAC_LB_MMC  KFAC_LB_auroc  \
# 0             0.983               0.000        0.994          0.000
# 1             0.655               0.959        0.730          0.962
# 2             0.657               0.960        0.740          0.959
#
#    KFAC_LB_norm_MMC  KFAC_LB_norm_auroc
# 0             0.985               0.000
# 1             0.644               0.953
# 2             0.646               0.955

# %% [markdown]
# # CIFAR100

# %%
df_CIFAR100 = pd.read_csv("CIFAR100_results.csv")
print(df_CIFAR100.columns)
df_CIFAR100
# Out:
# Index(['Unnamed: 0', 'MAP_MMC_in', 'MAP_MMC_CIFAR10', 'MAP_MMC_SVHN',
#        'MAP_AUROC_CIFAR10', 'MAP_AUROC_SVHN', 'Diag_samples_MMC_in',
#        'Diag_samples_MMC_CIFAR10', 'Diag_samples_MMC_SVHN',
#        'Diag_samples_AUROC_CIFAR10', 'Diag_samples_AUROC_SVHN',
#        'KFAC_samples_MMC_in', 'KFAC_samples_MMC_CIFAR10',
#        'KFAC_samples_MMC_SVHN', 'KFAC_samples_AUROC_CIFAR10',
#        'KFAC_samples_AUROC_SVHN', 'Diag_LB_MMC_in', 'Diag_LB_MMC_CIFAR10',
#        'Diag_LB_MMC_SVHN', 'Diag_LB_AUROC_CIFAR10', 'Diag_LB_AUROC_SVHN',
#        'KFAC_LB_MMC_in', 'KFAC_LB_MMC_CIFAR10', 'KFAC_LB_MMC_SVHN',
#        'KFAC_LB_AUROC_CIFAR10', 'KFAC_LB_AUROC_SVHN', 'Diag_LB_norm_MMC_in',
#        'Diag_LB_norm_MMC_CIFAR10', 'Diag_LB_norm_MMC_SVHN',
#        'Diag_LB_norm_AUROC_CIFAR10', 'Diag_LB_norm_AUROC_SVHN',
#        'KFAC_LB_norm_MMC_in', 'KFAC_LB_norm_MMC_CIFAR10',
#        'KFAC_LB_norm_MMC_SVHN', 'KFAC_LB_norm_AUROC_CIFAR10',
#        'KFAC_LB_norm_AUROC_SVHN', 'Diag_EMK_MMC_in', 'Diag_EMK_MMC_CIFAR10',
#        'Diag_EMK_MMC_SVHN', 'Diag_EMK_AUROC_CIFAR10', 'Diag_EMK_AUROC_SVHN',
#        'KFAC_EMK_MMC_in', 'KFAC_EMK_MMC_CIFAR10', 'KFAC_EMK_MMC_SVHN',
#        'KFAC_EMK_AUROC_CIFAR10', 'KFAC_EMK_AUROC_SVHN', 'Diag_SODPP_MMC_in',
#        'Diag_SODPP_MMC_CIFAR10', 'Diag_SODPP_MMC_SVHN',
#        'Diag_SODPP_AUROC_CIFAR10', 'Diag_SODPP_AUROC_SVHN',
#        'KFAC_SODPP_MMC_in', 'KFAC_SODPP_MMC_CIFAR10', 'KFAC_SODPP_MMC_SVHN',
#        'KFAC_SODPP_AUROC_CIFAR10', 'KFAC_SODPP_AUROC_SVHN'],
#       dtype='object')
#    Unnamed: 0  MAP_MMC_in  MAP_MMC_CIFAR10  MAP_MMC_SVHN  MAP_AUROC_CIFAR10  \
# 0           0       0.812            0.533         0.535              0.786
# 1           1       0.812            0.533         0.535              0.786
# 2           2       0.812            0.533         0.535              0.786
# 3           3       0.812            0.533         0.535              0.786
# 4           4       0.812            0.533         0.535              0.786
#
#    MAP_AUROC_SVHN  Diag_samples_MMC_in  Diag_samples_MMC_CIFAR10  \
# 0           0.788                0.776                     0.479
# 1           0.788                0.776                     0.480
# 2           0.788                0.776                     0.480
# 3           0.788                0.776                     0.480
# 4           0.788                0.776                     0.480
#
#    Diag_samples_MMC_SVHN  Diag_samples_AUROC_CIFAR10  ...  Diag_SODPP_MMC_in  \
# 0                  0.472                       0.788  ...              0.774
# 1                  0.472                       0.788  ...              0.774
# 2                  0.472                       0.788  ...              0.774
# 3                  0.472                       0.788  ...              0.774
# 4                  0.472                       0.788  ...              0.774
#
#    Diag_SODPP_MMC_CIFAR10  Diag_SODPP_MMC_SVHN  Diag_SODPP_AUROC_CIFAR10  \
# 0                   0.474                0.465                     0.788
# 1                   0.474                0.466                     0.788
# 2                   0.474                0.465                     0.788
# 3                   0.474                0.466                     0.788
# 4                   0.474                0.465                     0.788
#
#    Diag_SODPP_AUROC_SVHN  KFAC_SODPP_MMC_in  KFAC_SODPP_MMC_CIFAR10  \
# 0                  0.796              0.474                   0.474
# 1                  0.796              0.474                   0.474
# 2                  0.796              0.474                   0.474
# 3                  0.796              0.474                   0.474
# 4                  0.796              0.474                   0.474
#
#    KFAC_SODPP_MMC_SVHN  KFAC_SODPP_AUROC_CIFAR10  KFAC_SODPP_AUROC_SVHN
# 0                0.465                     0.500                  0.509
# 1                0.466                     0.500                  0.509
# 2                0.465                     0.500                  0.510
# 3                0.466                     0.500                  0.509
# 4                0.465                     0.500                  0.510
#
# [5 rows x 56 columns]

# %%
data_CIFAR100 = np.array([
    [df_CIFAR100['Diag_samples_MMC_in'].mean(), df_CIFAR100['Diag_samples_MMC_CIFAR10'].mean(),
     df_CIFAR100['Diag_samples_MMC_SVHN'].mean()],
    [0, df_CIFAR100['Diag_samples_AUROC_CIFAR10'].mean(), df_CIFAR100['Diag_samples_AUROC_SVHN'].mean()],
    [df_CIFAR100['Diag_LB_MMC_in'].mean(), df_CIFAR100['Diag_LB_MMC_CIFAR10'].mean(),
     df_CIFAR100['Diag_LB_MMC_SVHN'].mean()],
    [0, df_CIFAR100['Diag_LB_AUROC_CIFAR10'].mean(), df_CIFAR100['Diag_LB_AUROC_SVHN'].mean()],
    [df_CIFAR100['Diag_LB_norm_MMC_in'].mean(), df_CIFAR100['Diag_LB_norm_MMC_CIFAR10'].mean(),
     df_CIFAR100['Diag_LB_norm_MMC_SVHN'].mean()],
    [0, df_CIFAR100['Diag_LB_norm_AUROC_CIFAR10'].mean(), df_CIFAR100['Diag_LB_norm_AUROC_SVHN'].mean()],
#     [df_CIFAR100['Diag_EMK_MMC_in'].mean(), df_CIFAR10['Diag_EMK_MMC_CIFAR10'].mean(),
#      df_CIFAR100['Diag_EMK_MMC_SVHN'].mean()],
#     [0, df_CIFAR100['Diag_EMK_AUROC_CIFAR10'].mean(), df_CIFAR100['Diag_EMK_AUROC_SVHN'].mean()],
#     [df_CIFAR100['Diag_SODPP_MMC_in'].mean(), df_CIFAR100['Diag_SODPP_MMC_CIFAR10'].mean(),
#      df_CIFAR100['Diag_SODPP_MMC_SVHN'].mean()],
#     [0, df_CIFAR100['Diag_SODPP_AUROC_CIFAR10'].mean(), df_CIFAR100['Diag_SODPP_AUROC_SVHN'].mean()]
]).T

df_diag_CIFAR100 = pd.DataFrame(data_CIFAR100, columns=[
    "Diag_samples_MMC", "Diag_samples_auroc",
    "Diag_LB_MMC", "Diag_LB_auroc",
    "Diag_LB_norm_MMC", "Diag_LB_norm_auroc",
#     "Diag_EMK_MMC", "Diag_EMK_auroc",
#     "Diag_SODPP_MMC", "Diag_SODPP_auroc"
])
df_diag_CIFAR100
# Out:
#    Diag_samples_MMC  Diag_samples_auroc  Diag_LB_MMC  Diag_LB_auroc  \
# 0             0.776               0.000        0.632          0.000
# 1             0.480               0.788        0.245          0.791
# 2             0.472               0.795        0.209          0.815
#
#    Diag_LB_norm_MMC  Diag_LB_norm_auroc
# 0             0.942               0.000
# 1             0.841               0.757
# 2             0.846               0.748

# %%
data_CIFAR100_K = np.array([
    [df_CIFAR100['KFAC_samples_MMC_in'].mean(), df_CIFAR100['KFAC_samples_MMC_CIFAR10'].mean(),
     df_CIFAR100['KFAC_samples_MMC_SVHN'].mean()],
    [0, df_CIFAR100['KFAC_samples_AUROC_CIFAR10'].mean(), df_CIFAR100['KFAC_samples_AUROC_SVHN'].mean()],
    [df_CIFAR100['KFAC_LB_MMC_in'].mean(), df_CIFAR100['KFAC_LB_MMC_CIFAR10'].mean(),
     df_CIFAR100['KFAC_LB_MMC_SVHN'].mean()],
    [0, df_CIFAR100['KFAC_LB_AUROC_CIFAR10'].mean(), df_CIFAR100['KFAC_LB_AUROC_SVHN'].mean()],
    [df_CIFAR100['KFAC_LB_norm_MMC_in'].mean(), df_CIFAR100['KFAC_LB_norm_MMC_CIFAR10'].mean(),
     df_CIFAR100['KFAC_LB_norm_MMC_SVHN'].mean()],
    [0, df_CIFAR100['KFAC_LB_norm_AUROC_CIFAR10'].mean(), df_CIFAR100['KFAC_LB_norm_AUROC_SVHN'].mean()],
#     [df_CIFAR100['KFAC_EMK_MMC_in'].mean(), df_CIFAR100['KFAC_EMK_MMC_CIFAR10'].mean(),
#      df_CIFAR100['KFAC_EMK_MMC_SVHN'].mean()],
#     [0, df_CIFAR100['KFAC_EMK_AUROC_CIFAR10'].mean(), df_CIFAR100['KFAC_EMK_AUROC_SVHN'].mean()],
#     [df_CIFAR100['KFAC_SODPP_MMC_in'].mean(), df_CIFAR100['KFAC_SODPP_MMC_CIFAR10'].mean(),
#      df_CIFAR100['KFAC_SODPP_MMC_SVHN'].mean()],
#     [0, df_CIFAR100['KFAC_SODPP_AUROC_CIFAR10'].mean(), df_CIFAR100['KFAC_SODPP_AUROC_SVHN'].mean()]
]).T

df_KFAC_CIFAR100 = pd.DataFrame(data_CIFAR100_K, columns=[
    "KFAC_samples_MMC", "KFAC_samples_auroc",
    "KFAC_LB_MMC", "KFAC_LB_auroc",
    "KFAC_LB_norm_MMC", "KFAC_LB_norm_auroc",
#     "KFAC_EMK_MMC", "KFAC_EMK_auroc",
#     "KFAC_SODPP_MMC", "KFAC_SODPP_auroc"
])
df_KFAC_CIFAR100
# Out:
#    KFAC_samples_MMC  KFAC_samples_auroc  KFAC_LB_MMC  KFAC_LB_auroc  \
# 0             0.776               0.000        0.589          0.000
# 1             0.485               0.787        0.207          0.790
# 2             0.472               0.798        0.185          0.807
#
#    KFAC_LB_norm_MMC  KFAC_LB_norm_auroc
# 0             0.949               0.000
# 1             0.863               0.749
# 2             0.853               0.761
